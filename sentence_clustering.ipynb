# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudhkashibhatla/sentence_clustering/blob/main/sentence_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer,util
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import DBSCAN
from sentence_transformers.util import community_detection
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
with open('/content/extensionStorage.json', 'r') as f:
    data = json.load(f)

json_names = list(data.keys())
print("Top-level JSON names:", json_names)
json_sizes = {key: len(value) if isinstance(value, dict) else 0 for key, value in data.items()}

sorted_by_keys = dict(sorted(json_sizes.items(), key=lambda item: item[1],reverse = True))
sorted_by_keys
relevant = list(sorted_by_keys.keys())
print(relevant)
relevant = relevant[:4]
relevant = [relevant[0], relevant[-1]]
relevant
for key,value in data.items():
  if key in relevant:
     print(key)
     print(value)
data = {key: value for key, value in data.items() if key in relevant}
data
# Out:
# Top-level JSON names: ['formData', 'formDataCounts', 'https://astrazeneca.wd3.myworkdayjobs.com/en-US/Careers/details/Senior-Clinical-Research-Associate--Sr-CRA------So-Paulo-or-Rio-de-Janeiro-_R-215891', 'https://astrazeneca.wd3.myworkdayjobs.com/en-US/Careers/job/Salesforce---Sao-Paulo/Senior-Clinical-Research-Associate--Sr-CRA------So-Paulo-or-Rio-de-Janeiro-_R-215891/apply', 'https://spgi.wd5.myworkdayjobs.com/en-US/SPGI_Careers/login?redirect=%2Fen-us%2FSPGI_Careers%2Fjob%2FHyderabad-Telangana%2FData-Analyst_310792-1%2Fapply%3Futm_source%3Dlinkedin', 'https://spgi.wd5.myworkdayjobs.com/en-us/SPGI_Careers/job/Hyderabad-Telangana/Data-Analyst_310792-1/apply?utm_source=linkedin', 'https://www.google.com/search?sca_esv=c05c11496cd8066e&sxsrf=AHTn8zoPzyFOHPu_RmvYYYQaM0TGQKso2Q:1739270327433&q=mr+bean&udm=2&fbs=ABzOT_CWdhQLP1FcmU5B0fn3xuWp6IcynRBrzjy_vjxR0KoDMuRqhRxkdGgKzs52-1TZixdYkeUgOjz9KxcNKskor3Wf6jWq0B_xPJBz95EFO4SS0Z3Wte9MK5niNmZV-9csBT4bv-aOHRZvEqA9I05Y8XJJZNgZLjVQhoOnrkwiKG6um1Jni7hjV5wQBghQq_d87hJPUCls49wuQstZ02o9sIZfkL2c0A&sa=X&ved=2ahUKEwiou6PwtruLAxVbTmwGHUTNKuoQtKgLegQICxAB&biw=1920&bih=919&dpr=2', 'https://www.linkedin.com/games/crossclimb/', 'https://www.linkedin.com/jobs/collections/top-applicant/?currentJobId=4148599730', 'https://www.linkedin.com/messaging/thread/2-N2FjOTdkNWUtNjJiMy00YzI1LTkwNTktMDQ3MWI4NDAwMTQxXzAxMA==/']
# ['formData', 'formDataCounts', 'https://www.linkedin.com/games/crossclimb/', 'https://spgi.wd5.myworkdayjobs.com/en-us/SPGI_Careers/job/Hyderabad-Telangana/Data-Analyst_310792-1/apply?utm_source=linkedin', 'https://astrazeneca.wd3.myworkdayjobs.com/en-US/Careers/details/Senior-Clinical-Research-Associate--Sr-CRA------So-Paulo-or-Rio-de-Janeiro-_R-215891', 'https://astrazeneca.wd3.myworkdayjobs.com/en-US/Careers/job/Salesforce---Sao-Paulo/Senior-Clinical-Research-Associate--Sr-CRA------So-Paulo-or-Rio-de-Janeiro-_R-215891/apply', 'https://spgi.wd5.myworkdayjobs.com/en-US/SPGI_Careers/login?redirect=%2Fen-us%2FSPGI_Careers%2Fjob%2FHyderabad-Telangana%2FData-Analyst_310792-1%2Fapply%3Futm_source%3Dlinkedin', 'https://www.google.com/search?sca_esv=c05c11496cd8066e&sxsrf=AHTn8zoPzyFOHPu_RmvYYYQaM0TGQKso2Q:1739270327433&q=mr+bean&udm=2&fbs=ABzOT_CWdhQLP1FcmU5B0fn3xuWp6IcynRBrzjy_vjxR0KoDMuRqhRxkdGgKzs52-1TZixdYkeUgOjz9KxcNKskor3Wf6jWq0B_xPJBz95EFO4SS0Z3Wte9MK5niNmZV-9csBT4bv-aOHRZvEqA9I05Y8XJJZNgZLjVQhoOnrkwiKG6um1Jni7hjV5wQBghQq_d87hJPUCls49wuQstZ02o9sIZfkL2c0A&sa=X&ved=2ahUKEwiou6PwtruLAxVbTmwGHUTNKuoQtKgLegQICxAB&biw=1920&bih=919&dpr=2', 'https://www.linkedin.com/jobs/collections/top-applicant/?currentJobId=4148599730', 'https://www.linkedin.com/messaging/thread/2-N2FjOTdkNWUtNjJiMy00YzI1LTkwNTktMDQ3MWI4NDAwMTQxXzAxMA==/']
# formData
# {'1': '9', '2': '3', '3': '6', '4': '4', '2024': '3', '10715': '57', '\n                    Excercises filter input\n                  ': '', '\n                    Filter field for certifications\n                  ': '', '\n                    Password                ': 'q#Nf8Hz47KjsMPb', ' ': 'discuss particle physics and create a model that stimulates 3d particle interactions and dynamics in c++ using any  librarireas needed along with the math', ' Choose not to reply': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__17976', ' File': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf', ' Male': 'com.taleo.systemcomponent.question.entity.RegulationPossibleAnswer__4205011901', ' No': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19098', ' Not applicable': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19325', ' Yes': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19337', ' Yes - I currently hold a PAN card.': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__46057', '*\n\xa0Address Line 1': 'DAFFODILS APTS,DD COLNY', '*\n\xa0City': 'Hyderabad', '*\n\xa0Country': 'India', '*\n\xa0Degree': 'Bachelor', '*\n\xa0Email Address': 'anirudhkashibhatla@gmail.com', '*\n\xa0In the future, will you require sponsorship from Moody’s to work within the country to which you are applying?': 'No', '*\n\xa0Legal First Name': 'Anirudh', '*\n\xa0Legal Last Name': 'Kashibhatla', '*\n\xa0Primary Contact Number': '+917093615572', '*I have read and agree to the Employee Candidate\xa0Privacy Statement\n': 'on', '*Passcode:': '872554', '11 - 13 LPA': '201132701002', '6months - 2years': '1', ':1gi': 'meenakumarimanyam@gmail.com', ':r0:': '', ':r1:': 'xFRuDg', 'A Pandas Series': '2', 'Access password': 'sample', 'Access up‐to‐date course content': 'on', 'Achievements\n\xa0': 'At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. This ownership of real-time analytics has strengthened my ability to deliver actionable insights in fast-paced environments.\nActively traded a range of ICE,CME,EURONEXT commodity futures, including SRW ,HRW,yEBM, Corn, canola,\nyECO, and soybean oil.\n• Monitored market dynamics using open-source data focusing on supply-demand trends, geopolitical developments,\nand weather-driven factors influencing agricultural prices.\n• Developed and implemented more than 100 hedging strategies, optimized diversification using covariance analysis,\nand applied risk budgeting to mitigate risk and preserve portfolio stability during market volatility.\n• Applied lead-lag relationships, intermarket strategies, and arbitrage opportunities using tools like correlation\nanalysis and statistical tests to identify profitable trades', 'Active backlogs37442': 'No', 'Address :': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 1': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 1\n*': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 1 - Local*': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 1*': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 2*': ', B lane, DD Colony, Amberpet', 'Address line 1 ': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address line 2': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Alternate Email ID37414': 'sr922003@student.nitw.ac.in', 'Anticipated Graduation Date\n\xa0': 'on', 'Are hands on form ...
# https://spgi.wd5.myworkdayjobs.com/en-us/SPGI_Careers/job/Hyderabad-Telangana/Data-Analyst_310792-1/apply?utm_source=linkedin
# {'Company*': '', 'Country Phone Code*': 'India', 'Field of Study': 'Metallurgical Engineering', 'Job Title*': '', 'Location': '', 'Overall Result (GPA)': '7.19', 'Phone Number*': '70936 15572', 'Role Description': '', 'School or University*': '', 'What is your desired annual gross base salary in your local currency?': '800000', 'Yes, I acknowledge that I have read and understand the policy.*': 'on', 'input-24-dateSectionMonth-input': '7', 'input-24-dateSectionYear-input': '2024', 'input-27-dateSectionMonth-input': '1', 'input-27-dateSectionYear-input': '2025', 'input-77-dateSectionYear-input': '2020', 'input-80-dateSectionYear-input': '2024'}
# {'formData': {'1': '9',
#   '2': '3',
#   '3': '6',
#   '4': '4',
#   '2024': '3',
#   '10715': '57',
#   '\n                    Excercises filter input\n                  ': '',
#   '\n                    Filter field for certifications\n                  ': '',
#   '\n                    Password                ': 'q#Nf8Hz47KjsMPb',
#   ' ': 'discuss particle physics and create a model that stimulates 3d particle interactions and dynamics in c++ using any  librarireas needed along with the math',
#   ' Choose not to reply': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__17976',
#   ' File': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   ' Male': 'com.taleo.systemcomponent.question.entity.RegulationPossibleAnswer__4205011901',
#   ' No': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19098',
#   ' Not applicable': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19325',
#   ' Yes': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19337',
#   ' Yes - I currently hold a PAN card.': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__46057',
#   '*\n\xa0Address Line 1': 'DAFFODILS APTS,DD COLNY',
#   '*\n\xa0City': 'Hyderabad',
#   '*\n\xa0Country': 'India',
#   '*\n\xa0Degree': 'Bachelor',
#   '*\n\xa0Email Address': 'anirudhkashibhatla@gmail.com',
#   '*\n\xa0In the future, will you require sponsorship from Moody’s to work within the country to which you are applying?': 'No',
#   '*\n\xa0Legal First Name': 'Anirudh',
#   '*\n\xa0Legal Last Name': 'Kashibhatla',
#   '*\n\xa0Primary Contact Number': '+917093615572',
#   '*I have read and agree to the Employee Candidate\xa0Privacy Statement\n': 'on',
#   '*Passcode:': '872554',
#   '11 - 13 LPA': '201132701002',
#   '6months - 2years': '1',
#   ':1gi': 'meenakumarimanyam@gmail.com',
#   ':r0:': '',
#   ':r1:': 'xFRuDg',
#   'A Pandas Series': '2',
#   'Access password': 'sample',
#   'Access up‐to‐date course content': 'on',
#   'Achievements\n\xa0': 'At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. This ownership of real-time analytics has strengthened my ability to deliver actionable insights in fast-paced environments.\nActively traded a range of ICE,CME,EURONEXT commodity futures, including SRW ,HRW,yEBM, Corn, canola,\nyECO, and soybean oil.\n• Monitored market dynamics using open-source data focusing on supply-demand trends, geopolitical developments,\nand weather-driven factors influencing agricultural prices.\n• Developed and implemented more than 100 hedging strategies, optimized diversification using covariance analysis,\nand applied risk budgeting to mitigate risk and preserve portfolio stability during market volatility.\n• Applied lead-lag relationships, intermarket strategies, and arbitrage opportunities using tools like correlation\nanalysis and statistical tests to identify profitable trades',
#   'Active backlogs37442': 'No',
#   'Address :': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet',
#   'Address Line 1': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet',
#   'Address Line 1\n*': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet',
#   'Address Line 1 - Local*': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet',
#   'Address Line 1*': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet',
#   'Address Line 2*': ', B lane, DD Colony, Amberpet',
#   'Address line 1 ': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet',
#   'Address line 2': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet',
#   'Alternate Email ID37414': 'sr922003@student.nitw.ac.in',
#   'Anticipated Graduation Date\n\xa0': 'on',
#   'Are hands on formulas like VLOOKUP, HLOOKUP, SUMIF, COUNTIF, INDEX-MATCH ?\nAre hands on formulas like VLOOKUP, HLOOKUP, SUMIF, COUNTIF, INDEX-MATCH ?\n ': 'Yes',
#   'Are you a current or former employee or official of a State, Local, or Government Entity or political party, a member of a royal family, or a candidate for political office? *': '38',
#   'Are you a former employee (including as a co-op/intern) of GE Aerospace (formerly GE Aviation), the General Electric Company, or one of either company’s affiliates or subsidiaries?*': 'No',
#   'Are you authorized to work permanently in location in which you are expressing an interest?': 'yes',
#   'Are you available immediately to join?\nAre you available immediately to join?\n ': 'Yes',
#   'Are you comfortable working in a Hybrid mode in the following work timings(02:00 pm to 11:00 pm)?\nAre you comfortable working in a Hybrid mode in the following work timings(02:00 pm to 11:00 pm)?\n ': 'Yes',
#   'Are you comfortable working in our Bengaluru office 3-4 days per week?': 'yes',
#   'Are you currently authorized to work in the Country to which you are applying to work? *': '37',
#   'Are you currently in Pune or willing to relocate to Pune for this role?\nAre you currently in Pune or willing to relocate to Pune for this role?\n ': 'Yes',
#   'Are you currently or have you ever worked at MetLife or its affiliates, whether as an employee or non-employee worker (i.e., independent contractor, consultant, temporary worker, contingent worker, etc.)? *': '468925',
#   'Are you open in relocating to Bangalore?\nAre you open in relocating to Bangalore?\n ': 'Yes',
#   'Are you ready to relocate to Bangalore?\nAre you ready to relocate to Bangalore?\n ': 'Yes',
#   'Are you serving notice period ?\nAre you serving notice period ?\n ': 'No',
#   'Are you willing to work onsite in Bangalore?\nAre you willing to work onsite in Bangalore?\n ': 'Yes',
#   'Area of Study': 'Engineering',
#   'Ascending': 'ascending',
#   'Associate\nFilter by Associate': '3',
#   'Attach': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'Attach File': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'Available To Join (in days)': '0',
#   'Business email': 'anirudhkashibhatla@gmail.com',
#   'By applying, you hereby accept the data processing terms under the Privacy Policy and give consent to processing of the data as part of this job application.': '2',
#   'CGPA': '7.19',
#   'CTC:': '10.2',
#   'Campus ': '-',
#   'Can help you get a job\nFilter by Can help you get a job': 'can_help_you_get_a_job',
#   'Can you meet this requirement? *': '37',
#   'CaptchaInputText': 'SEUEW',
#   'Cell Phone': '07093615572',
#   'Cellular Number\n\xa0\n.\xa0\nRequired': '7093615572',
#   'Choose Files': 'C:\\fakepath\\logo.png',
#   'Choose Password: *': 'Guruji$1',
#   'Choose file': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume_.pdf',
#   'City': 'Hyderabad',
#   'City\n*': 'Hyderabad',
#   'City\nCity': 'hydera',
#   'City\nCity\n ': 'hyderabad',
#   'City\n\xa0': 'Hyderabad',
#   'City\n\xa0\n.\xa0\nRequired': 'Hyderabad ',
#   'City ': 'Hyderabad',
#   'City *\nThis is a required field.': 'Hyderabad',
#   'City - Local*': 'Hyderabad',
#   'City*': 'Hyderabad',
#   'City, state, or zip code': 'india',
#   'Class X Marks (%)37417': '93',
#   'Class Xll Marks (%)37418': '77.3',
#   'Code': '47379623',
#   'Color': '#ff0000',
#   'Comments about the file': 'Resume',
#   'Company': 'Futures First',
#   'Company name*': 'Futures First',
#   'Company*': 'Futures First',
#   'Competency Area :': 'Technologies',
#   'Consent!': 'on',
#   'Contact Number *': '7093615572',
#   'Contact number 1:': '07093615572',
#   'Contact number 2:': '07093615572',
#   'Contact people outside my network': 'on',
#   'Country': 'IN',
#   'Country *': '101',
#   'Country *\nThis is a required field.': 'IN',
#   'Country / Territory Phone Code*': '+917093615572',
#   'Country Phone Code*': '+917093615572',
#   'Country/Region Code:*': 'IN',
#   'Country/Region of Residence:*': 'IN',
#   'Cover Letter': 'C:\\fakepath\\Anirudh_Kashibhatla_CV_.pdf',
#   'Create an optimized resume with keyword insights': 'on',
#   'Current CTC': '1020000',
#   'Current City': 'Hyderabad ',
#   'Current Compensation? *': '1020000',
#   'Current Location': 'Hyderabad',
#   'Current Location *': 'Hyderabad',
#   'Current Location?*': 'Hyderabad',
#   'Current Organisation': 'Futures First',
#   'Current Salary *': '10,20,000',
#   'Current State': 'Telangana ',
#   'Current ctc?': '10.2',
#   'Current employer :': 'FUTURES FIRST',
#   'Current position? *': '38',
#   'Degree Type': 'Engineering',
#   'Description': '- Developed and deployed trading,hedging strategies on 8 Commodity futures products across CME, ICE , Euronext exchanges.\n- Worked with open-source data and in-house data using quantitative and fundamental analysis to create risk - adjusted forecasts.\n- Worked on ',
#   "Do you get leave encashment? If 'Yes', please select the Maximum Number of Leaves you can encash from the below options\nDo you get leave encashment? If 'Yes', please select the Maximum Number of Leaves you can encash from the below options": 'No Leave Encashment',
#   "Do you have a disability (including physical or sensory)? Long term / mental health condition or are you neurodiverse?\nIf you have answered 'Yes' to the above question, share details below —\n\xa0\n.\xa0\nRequired": 'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14322__59370',
#   'Do you have a disability? *': '127',
#   'Do you have an outside business activity or financial interest of greater than 5% in any entity / organization? Outside business activities include any employment, participation, or significant financial interest in a business or organization outside of your (expected) primary position at MetLife. Some examples include: a second job, a business you own, holding a local government position, or holding a board position at a non-profit organization. *': '38',
#   'Do you have any reason to believe that an acceptance of an employment offer from MetLife or its affiliates would breach or violate any non-compete agreement, any non-solicitation agreement, or any other contract or agreement? *': '38',
#   'Do you have any relatives currently working within the HSBC Group?\n\xa0\n.\xa0\nRequired': 'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14680__2',
#   'Do you have experience in Alteryx, VB and SQL?\nDo you have experience in Alteryx, VB and SQL?\n ': 'Yes',
#   'Do you identify as Trans?\n\xa0\n.\xa0\nRequired': 'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14320__59464',
#   'E-mail Address\n\xa0\n.\xa0\nRequired': 'anirudhkashibhatla@gmail.com',
#   'Education Level\n\xa0\n.\xa0\nRequired': '6',
#   'EducationDetails[0].branch': 'Metallurgy',
#   'EducationDetails[0].degree': 'B.tech',
#   'EducationDetails[0].location': 'Warangal',
#   'EducationDetails[0].university': 'NITWarangal',
#   'Email': 'anirudhkashibhatla@gmail.com',
#   'Email *': 'anirudhkashibhatla@gmail.com',
#   'Email Address': 'anirudhkashibhatla@gmail.com',
#   'Email Address ': 'anirudhkashibhatla@gmail.com',
#   'Email Address*': 'anirudhkashibhatla@gmail.com',
#   'Email Address: *': 'anirudhkashibhatla@gmail.com',
#   'Email Address:*': 'anirudhkashibhatla@gmail.com',
#   'Email ID37413': 'anirudhkashibhatla@gmail.com',
#   'Email ID:': 'anirudhkashibhatla@gmail.com',
#   'Email address': 'anirudhkashibhatla@gmail.com',
#   'Email address\n*': 'anirudhkashibhatla@gmail.com',
#   'Email address*': 'anirudhkashibhatla@gmail.com',
#   'Email or Phone': 'anirudhkashibhatla@gmail.com',
#   'Email or mobile phone number': 'anirudhkashibhatla@gmail.com',
#   'Email or phone': 'anirudhkashibhatla@gmail.com',
#   'Email*': 'anirudhkashibhatla@gmail.com',
#   'Employer\n\xa0': 'Futures First',
#   'Employer\n\xa0\n.\xa0\nRequired': '',
#   'End Date *': '2025-01',
#   'End date': '2024-06-01',
#   'End date *': '2025-01-10',
#   'End date month*': '6',
#   'End date year*': '2023',
#   'Enter ID (optional)': '234',
#   'Enter code': '002584',
#   'Enter mobile number': '7093615572',
#   'Entry level\nFilter by Entry level': '2',
#   'Exclude Inactive (FIDE rated only)': 'on',
#   'Expected CTC:': '11',
#   'Expected Compensation? *': '1100000',
#   'Expected Salary *': '10,20,000',
#   'Expected ctc?': '10.2',
#   'ExperienceDetails[0].companyName': 'Futures First',
#   'ExperienceDetails[0].designation': 'Market Analyst',
#   'ExperienceDetails[0].location': 'Hyderabad',
#   'Explore a full library of courses': 'on',
#   'Family Name': 'Kashibhatla',
#   'Family Name\n*': 'Kashibhatla',
#   'Family Name*': 'Kashibhatla ',
#   'Field of Study': 'Metallurgical Engineering',
#   'Field(s) of Study\n\xa0': 'Metallurgical Engineering',
#   'Filter by ID/IP': '',
#   'Filter by ID/IP/Room': '2',
#   'Find jobs where I’d be a top applicant': 'on',
#   'First Location Preference': '890901',
#   'First Name': 'Anirudh',
#   'First Name*': 'Anirudh',
#   'First Name37410': 'Anirudh',
#   'First Name: *': 'Anirudh',
#   'First name ': 'Anirudh',
#   'First name *': 'Anirudh ',
#   'First name:': 'Anirudh',
#   'For purposes of determining whether there may be a conflict of interest please tell us, to the best of your knowledge, is any member of your family or household a current MetLife employee or member of its Board of Directors? (Examples include any child, stepchild, parent, stepparent, spouse, sibling, mother-in-law, father-in-law, son-in-law, daughter-in-law, brother-in-law, or sister-in-law, and any person sharing a household other than a tenant.) *': '38',
#   'From Device *': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'Full Name*': 'Anirudh Kashibhatla',
#   'Full name': 'Anirudh Kashibhatla',
#   'GENDER / GÉNERO': '1',
#   'Gender (as shown on your national ID)\n\xa0\n.\xa0\nRequired': 'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__12040__1',
#   'Gender *': '92',
#   'Gender37412': 'Male',
#   'Github and Leetcode Profile (If Applicable)37632': '-',
#   'Given Name(s)\n*': 'Anirudh',
#   'Given Name(s)*': 'Anirudh ',
#   'Given Name*': 'Anirudh',
#   'Graduation': '1',
#   'Have you previously worked for Mr. Cooper, Nationstar Mortgage, Xome, Champion Mortgage, Centex Home Equity or a subsidiary or an affiliate?*': 'No',
#   'Highest Education Level\n\xa0\n.\xa0\nRequired': 'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__10248__3',
#   'How Did You Hear About Us? *\nThis is a required field.': '36',
#   'How did you hear about this job?': 'LINKEDIN',
#   'How did you hear about this position?\nHow did you hear about this position?\n ': 'Job Portal',
#   'How did you hear about us?*': 'Referral',
#   'How many total paid leaves you get in year in your current organization?\nHow many total paid leaves you get in year in your current organization?': '0-10',
#   'How many years experience as a Data Scientist': '0.5',
#   'How many years of Analyst experience do you currently have?': '1',
#   'How many years of Business Analytics experience do you currently have?': '0.5',
#   'How many years of Merchant management experience do you have ? \nHow many years of Merchant management experience do you have ? \n ': 'No',
#   'How many years of Transaction monitoring experience do you hold? ': '0',
#   'How many years of experience do you have in Quantitative Finance?*': '0.5',
#   'How many years of experience do you have working with investment banks?*': '0',
#   'How many years of experience in Podtfolio Management?': '0.5',
#   'How many years of experience in credit risk?': '0',
#   'How many years of experience you in GenAI?': '0',
#   'How many years of hands-on work experience with NetSuite?': '0',
#   'How many years of professional experience do you have working with coding languages and their application in the field of finance/markets? *': '0.5',
#   'How many years of relevant work experience do you have?\nHow many years of relevant work experience do you have?\n ': '6 months to 1 year',
#   'How many years of work experience do you have with BigSQL?': '0',
#   'How many years of work experience do you have with Communication?': '0',
#   'How many years of work experience do you have with Data Analysis?': '1',
#   'How many years of work experience do you have with Data Science?': '0',
#   'How many years of work experience do you have with Data Visualization?': '',
#   'How many years of work experience do you have with Databases?': '0',
#   'How many years of work experience do you have with Deep Learning?': '0',
#   'How many years of work experience do you have with Generative AI?': '0',
#   'How many years of work experience do you have with Google Cloud Platform (GCP)?': '0',
#   'How many years of work experience do you have with Machine Learning?': '0',
#   'How many years of work experience do you have with Medallion Architecture.': '0',
#   'How many years of work experience do you have with Microsoft Excel?': '1',
#   'How many years of work experience do you have with Mixpanel?': '0',
#   'How many years of work experience do you have with Payment Systems?': '0',
#   'How many years of work experience do you have with Pivot Tables?': '0',
#   'How many years of work experience do you have with Predictive Modeling?': '0',
#   'How many years of work experience do you have with Python (Programming Language)?': '0',
#   'How many years of work experience do you have with Recommender Systems?': '0',
#   'How many years of work experience do you have with SQL?': '0',
#   'How many years of work experience do you have with SWIFT Payments?': '0',
#   'How many years of work experience do you have with Snowflake?': '0',
#   'How many years of work experience do you have with Tableau?': '0',
#   'How soon can you join us, in days?': '7',
#   'I Agree Terms & Conditions': 'on',
#   'I accept': 'on',
#   "I accept AMEX GBT's Recruitment Privacy Statement": 'on',
#   "I acknowledge and agree to Invesco's Recruitment Privacy Notice": 'on',
#   'I acknowledge and understand the Privacy Policy, and I hereby consent to the Applicant Terms.': 'on',
#   'I agree to creating this account to allow me to apply for positions with this Organization.': 'on',
#   'I am fluent in this language.': 'on',
#   'I authorize the use of my responses to these questions to be invited to Diversity Events and I understand that I can withdraw this consent at any time': '1182074',
#   "I authorize the use of my responses to these questions to help with the Company's Diversity and Inclusion program and I understand that I can withdraw this consent at any time": '1182073',
#   'I consent to the Google APIs Terms of Service and the Gemini API Additional Terms of Service and acknowledge that I have read the Google Privacy Policy *': 'on',
#   'I currently work here': 'on',
#   'I have read the Privacy Notice': 'on',
#   'I have read the terms of the privacy policy and consent to the processing of my information': 'on',
#   'I hereby declare that I have not impersonated, or allowed myself to be impersonated by any person for the purposes of this assessment. All work submitted in this assessment will be my own work and does not involve plagiarism or teamwork.': 'on',
#   'Immediately, I am actively applying': 'ACTIVELY_SEEKING',
#   'India\n\xa0': '1',
#   'Influencer on LinkedIn\nFilter by Influencer on LinkedIn': 'influencer_on_linkedin',
#   'Institution\n\xa0\n.\xa0\nRequired': 'National Institute of Technology Warangal',
#   'International Calling Code\nInternational Calling Code\n\xa0\n.\xa0\nRequired': '+91',
#   'International Dialling Code\n\xa0': '7093615572 ',
#   'Internship\nFilter by Internship': '1',
#   'Is your Current location is Bangalore, Hyderabad Or Chennai\nIs your Current location is Bangalore, Hyderabad Or Chennai\n ': 'Yes',
#   'Is your travel to the office, the company provided/ reimbursement basis?\nIs your travel to the office, the company provided/ reimbursement basis?': 'Own Vehicle (non-reimbursable)',
#   'I’d use Premium for my personal goals': 'on',
#   'Job Board\n\xa0\n.\xa0\nRequired': '534324',
#   'Job Function\n\xa0\n.\xa0\nRequired': '',
#   'Job Title\n\xa0': 'Market Analyst',
#   'Job Title and Rank\n\xa0\n.\xa0\nRequired': 'Market Analyst',
#   'Job Title*': 'Market Analyst',
#   'Kindly enter National ID number': '417894747994',
#   'Kindly specify the additional source details below for Employee Referral/ Job Portal/Consultant/Campus/Social media site': 'linkedin',
#   'Last Name': 'Kashibhatla',
#   'Last Name*': 'Kashibhatla',
#   'Last Name37411': 'Kashibhatla',
#   'Last Name: *': 'Kashibhatla',
#   'Last name': 'Kashibhatla',
#   'Last name ': 'Kashibhatla',
#   'Last name *': 'Kashibhatla ',
#   'Learn about hiring trends at companies of interest': 'on',
#   'Legal First Name *': 'Anirudh',
#   'Legal Last Name *': 'Kashibhatla',
#   'Legal first name *': 'Anirudh',
#   'Link 1': 'https://www.linkedin.com/in/anirudhkashibhatla/',
#   'LinkedIn': 'https://www.linkedin.com/in/anirudhkashibhatla/',
#   'LinkedIn Profile': 'https://www.linkedin.com/in/anirudhkashibhatla/',
#   'LinkedIn Profile Link*': 'https://www.linkedin.com/in/anirudhkashibhatla/',
#   'LinkedIn Profile*': 'https://www.linkedin.com/in/anirudhkashibhatla/',
#   'Local Family Name': 'Kashibhatla ',
#   'Local Given Name(s)': 'Anirudh ',
#   'Location': 'Hyderabad, TG, India',
#   'Location (City)*': 'Hyderabad',
#   'Major': 'Metallurgical Engineering',
#   'Mark job as a top choice job': 'on',
#   'Market Analyst at Futures First': 'on',
#   'Marks37420': '71.9',
#   'Message Duration (s)': '234',
#   'Mobile Number\n\xa0\n.\xa0\nRequired': '7093615572',
#   'Mobile Phone number *\nThis is a required field.': '7093615572',
#   'Month': '0',
#   'Name': 'Anirudh Kashibhatla',
#   'Nearest Metropolitan City': 'com.taleo.systemcomponent.olf.entity.NetworkLocation__54300',
#   'No': 'false',
#   'No - Never Applied': '1636107552',
#   'Not Covered': 'on',
#   'Notice Period:': '0',
#   'Notice Period?': '0',
#   'Notice Period? *': '0',
#   'Notice period': '0',
#   'Notice period :': '0',
#   'Notification:': 'on',
#   'Others': '4',
#   'Overall Result (GPA)': '7.19',
#   'PLEASE_LIST_YOUR_PRIMARY_AND_SECONDARY_TECHNICAL_DOMAIN_SKILLS': 'Java,Python,C++,SQL,React,MongoDB,Pandas',
#   'PLEASE_PROVIDE_THE_NAME_OF_YOUR_CURRENT_EMPLOYER_FOLLOWED_BY_A_LIST_OF_PAST_EMPLOYERS': 'Futures First',
#   'Panel Data': '0',
#   'Passwd': 'anirudhbzgh',
#   'Password': '1',
#   'Password (optional)': '1',
#   'Password (optional):': '453',
#   'Phone': '07093615572',
#   'Phone *': '+917093615572',
#   'Phone Device Type\n*': 'Mobile',
#   'Phone Device Type*': 'Mobile',
#   'Phone Number': '07093615572',
#   'Phone Number*': '07093615572',
#   'Phone Number:*': '7093615572',
#   'Phone number': '+917093615572',
#   'Phone number\n*': '7093615572',
#   'Phone number *': '+917093615572',
#   'Phone number*': '7093615572',
#   'Phone*': '7093615572',
#   'Place of Residence\n\xa0\n.\xa0\nRequired': 'India ',
#   'Please confirm your Notice Period (In Days)': '0',
#   'Please enter your WNS Employee ID (Request not to mention "u", just type the Employee ID)': '0',
#   'Please enter your full name:\n\xa0\n.\xa0\nRequired': 'Anirudh Kashibhatla',
#   'Please limit personal note to 300 characters.': 'Data Lemur is great!',
#   'Please mention your current compensation?': '1020000',
#   'Please mention your notice period to join?': '0',
#   'Please provide the URL to your LinkedIn profile.': 'https://www.linkedin.com/in/anirudhkashibhatla/',
#   'Please provide your PAN Card Number\n\xa0\n.\xa0\nRequired': 'JCSPK3366J',
#   'Please select the highest level of education that you have achieved (or on track to achieve in the next 12 months). *': '20',
#   'Please share your current compensation (INR Annual in Lacs - Fixed + Variable)': '1020000',
#   'Please share your expected compensation (INR Annual in Lacs - Fixed + Variable)': '1020000',
#   'Please share your remaining Notice Period': '0',
#   'Please signify your acceptance by checking the box below.*': 'on',
#   'Please supply the URL to your LinkedIn page': 'https://www.linkedin.com/in/anirudhkashibhatla/',
#   'Postal Code': '500013',
#   'Postal Code*': '500013',
#   'Postal code': '500013',
#   'Postal/Zip code ': '500013',
#   'Preferred Contact Number\n\xa0\n.\xa0\nRequired': '7093615572',
#   'Preferred Location': 'Hyderabad',
#   'Prefix\n\xa0': 'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__10080__3',
#   'Price': '100000',
#   'Primary Phone Number\n\xa0\n.\xa0\nRequired': '7093615572',
#   'Proficiency in Coding Languages Known37627': 'Python',
#   'Pronouns': 'Anirudh',
#   'Python and Statistics for Financial Analysis': 'on',
#   'RACE/ETHNICITY / RAZA/ETNICIDAD': '4',
#   'Recruiters only\n\nLimited to people using LinkedIn Recruiter\n\nWhile we take steps not to show recruiters at your current company, we can’t guarantee complete privacy.': 'RECRUITERS',
#   'Region': 'com.taleo.systemcomponent.olf.entity.NetworkLocation__54300',
#   'Relevant Exp:': '0.5',
#   'Resident city :': 'hYDERA',
#   'Resume': 'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf',
#   'Resume *': 'C:\\fakepath\\Anirudh_Kashibhatla_CV_.pdf',
#   'Resume / CV *': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume_.pdf',
#   'Resume37634': 'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf',
#   'Retype Email Address: *': 'anirudhkashibhatla@gmail.com',
#   'Retype Password: *': 'Guruji$1',
#   'Role Description': 'At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. This ownership of real-time analytics has strengthened my ability to deliver actionable insights in fast-paced environments.\nActively traded a range of ICE,CME,EURONEXT commodity futures, including SRW ,HRW,yEBM, Corn, canola,\nyECO, and soybean oil.\n• Monitored market dynamics using open-source data focusing on supply-demand trends, geopolitical developments,\nand weather-driven factors influencing agricultural prices.\n• Developed and implemented more than 100 hedging strategies, optimized diversification using covariance analysis,\nand applied risk budgeting to mitigate risk and preserve portfolio stability during market volatility.\n• Applied lead-lag relationships, intermarket strategies, and arbitrage opportunities using tools like correlation\nanalysis and statistical tests to identify profitable trades',
#   'Roles & Responsibilities': 'At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. ',
#   'Room ID': '1',
#   'Room ID:': '453',
#   'Room Life (seconds)': '10000',
#   'School': 'other',
#   'School (Please use the full name, for example, University of Connecticut)': 'National Institute of Technology Warangal',
#   'School or University*': 'National Institute of Technology Warangal',
#   'School*': 'OTHER',
#   'Second Location Preference': '11267698',
#   'See how I compare to other job applicants': 'on',
#   'See who’s interested in my professional experience': 'on',
#   'Select the file to attach': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'Send an email notification whenever a new position matching this profile is posted.': 'on',
#   'Skills': 'data science',
#   'Source Type\n.\xa0\nRequired': '8',
#   'Specialization (If others, please specify your specialization)37440': 'Metallurgical Engineering',
#   'Specialization37422': 'Others',
#   'Start date': '2020-08-13',
#   'Start date *': '2024-07-22',
#   'Start date year*': '2020',
#   'State / Province': 'TG',
#   'State*': 'IND-TS',
#   'State/Province': '40',
#   'Stay up to date on companies of interest': 'on',
#   'Street Address': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet',
#   'Street Address (line 1)\n\xa0\n.\xa0\nRequired': 'Flat 201, Daffod ils Appt, B61, B lane, DD Colony, Amberpet',
#   'Take expert‐led courses': 'on',
#   'Thickness': '9',
#   'This is a full-time onsite role - 6 days a week - work from office (WFO) based in HSR Layout, Bengaluru - are you OK with that?\nThis is a full-time onsite role - 6 days a week - work from office (WFO) based in HSR Layout, Bengaluru - are you OK with that?\n ': 'Yes',
#   'TimeStamp': '1742915866553',
#   'Title*': 'Market Analyst',
#   'Title:': 'Mr.',
#   'To be eligible for hiring, you need to have work authorization / work permit / resident permit / work visa. Please confirm you are legally eligible to work in the country where this job is located. (Note: IBM will not provide sponsorship for any work permit/visa and/or residence permit required) *': '37',
#   'To develop my professional skills': 'on',
#   'To find and contact new leads': 'on',
#   'To grow my network, business, or reputation': 'on',
#   'Total Experience (in years)': '0.5',
#   'Total Experience working as a Business Analyst?': '0.5',
#   'Total Experience:': '0.5',
#   'Total Years of Experience': '0.5',
#   'Total Years of Experience*': '0.5',
#   'Total years of experience*': '0.5',
#   'True': '0',
#   'Type Your Full Name Here': 'Anirudh Kashibhatla',
#   'Type a message...': '234',
#   'Type to Add Skills': 'data science',
#   'UAN': '102103896453',
#   'UPLOAD RESUME': 'C:\\fakepath\\Anirudh_Kashibhatla_CV _.pdf',
#   'Undergraduate Degree37421': 'B.Tech',
#   'Undergraduate Institute Name37419': 'National Institute of Technology Warangal',
#   'Upload': 'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf',
#   'Upload Media': 'C:\\fakepath\\b8f7fbf246fc1d7ec90ddba93883b6d2.gif',
#   'Upload a file': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume_.pdf',
#   'Upload resume': 'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf',
#   'Upload resume :': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'UserName': 'ffispl/3857',
#   'Verify Email Address': 'anirudhkashibhatla@gmail.com',
#   'Verify New Password': 'Guruji$1',
#   'Verify Password': 'Guruji$1',
#   'Veteran Status - Voluntary': 'string:Not a Veteran',
#   'What domain/industry experience you have\xa0 ( Manufacture / Automotive / Aerospace / Healthcare ) ?': 'Finance',
#   'What is your CGPA (Cumulative Grade Point Average)?*': '7.19',
#   'What is your Current CTC?': '10.2',
#   'What is your Ethnic Group?\n\xa0\n.\xa0\nRequired': 'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__12120__67570',
#   'What is your Expected CTC?': '10.2',
#   'What is your Notice Period?': '0',
#   'What is your Official Notice Period in days?': '0',
#   'What is your Relevant Experience?': '0.5',
#   'What is your current CTC in lakhs (for e.g. 6/ 9/ 11 etc)?': '10.2',
#   'What is your current CTC?': '1020000',
#   'What is your current CTC? (INR)': '1020000',
#   'What is your current annual CTC (in INR)?': '1020000',
#   'What is your current annual CTC, in Lakhs?': '10',
#   'What is your current compensation?': '1020000',
#   'What is your current ctc ?': '10.2',
#   'What is your expected CTC?': '900000',
#   'What is your expected annual CTC (in INR)?': '1020000',
#   'What is your expected annual CTC, in Lakhs?': '10',
#   'What is your expected compensation?': '1020000',
#   'What is your expected ctc?': '10.2',
#   'What is your experience ?': '0.5',
#   'What is your gender identity?\n\xa0\n.\xa0\nRequired': 'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14321__59452',
#   'What is your level of proficiency in English?\nWhat is your level of proficiency in English?\n ': 'Professional',
#   'What is your notice period (in days)?': '0',
#   'What is your notice period ?': '0',
#   'What is your notice period in days (e.g. 0/ 15/ 30/ 45 with 0 meaning immediate joiner) ?': '0',
#   'What is your notice period?': '0',
#   'What is your notice period?\nWhat is your notice period?\n ': 'Available to join immediately',
#   'What is your preferred location to work? (select all that apply to you)\nWhat is your preferred location to work? (select all that apply to you)\n ': 'Bangalore',
#   'What percentage of time are you willing to travel? *': '579',
#   "What's their name or email address?": 'aditya.rama-kamalanath-polepeddi@michelin.com',
#   "What's their name or email address?*": 'aditya.rama-kamalanath-polepeddi@michelin.com',
#   "What's your current CTC? (In Lakhs)": '10',
#   "What's your notice period? (In days) ": '0',
#   'Whats your current CTC?': '1020000',
#   'Whats your expected CTC?': '1020000',
#   'Whats your notice period?': '0',
#   'Which institute/university did you graduate from? *': 'NITW',
#   'Which major investment banks do you have experience working with?*': '0',
#   'Which of the following best describes your sexual orientation?\n\xa0\n.\xa0\nRequired': 'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14360__59514',
#   'Will you now or in the future require MetLife sponsorship or support for a work permit or visa in any capacity? *': '38',
#   'Will you require sponsorship?*': 'NO',
#   'Willing to relocate to Mumbai:\nWilling to relocate to Mumbai:\n ': 'Yes',
#   'Year': '2025',
#   'Year of Graduation': '2024',
#   'Year of Passing37441': '2024',
#   'Years of Experience\n\xa0\n.\xa0\nRequired': '0.5',
#   'Yes': 'on',
#   'Yes, I consent to sharing information with AllianceBernstein.': 'on',
#   'Yes, I have read and consent to the terms and conditions': 'on',
#   'Yes, I have read and consent to the terms and conditions*': 'on',
#   'Yes, I have read and consent to the terms and conditions.': 'on',
#   'Your Name *': 'Anirudh Kashibhatla',
#   'Zip/Postal Code': '500013',
#   'Zip/Postal code*': '500013',
#   'aadhaarConsent.consentStatus': 'Y',
#   'attachCV': 'C:\\fakepath\\Anirudh_Kashibhatla_Sde.pdf',
#   'attachment-input-ember1141': 'C:\\fakepath\\Anirudh_Kashibhatla_CV _.pdf',
#   'attachment-input-ember1147': 'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf',
#   'attachment-input-ember1391': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'attachment-input-ember2841': 'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf',
#   'captcha': '24ASB',
#   'cards[0c0bf90e-d4ac-454a-a268-701db5240562][field0]': 'Yes',
#   'cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field0]': 'Between 9 LPA- 11LPA',
#   'cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field1]': '0',
#   'cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field2]': '10LPA',
#   'cards[61edf07f-a0f9-41cd-8901-24d4cb79eb71][field0]': 'I Agree',
#   'cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field0]': 'No',
#   'cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field1]': 'Yes',
#   'cards[b937576d-7460-40d2-ae79-762f158be671][field0]': 'Yes, by way of citizenship',
#   'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field0]': 'Male',
#   'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field1]': '0.5',
#   'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field2]': 'No',
#   'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field3]': 'Yes',
#   'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field4]': '1020000',
#   'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field5]': '1020000',
#   'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field6]': '0',
#   'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field7]': 'Linkedin',
#   'cat': 'op',
#   'chat-input': 'list steps to start mongdb server backend',
#   'compulsoryDuration': '0453',
#   'confirmPassword': 'Guruji$1234567',
#   'countryCode': 'IN',
#   'ctl00$pageContent$ResumeUpload1$uploadedresume': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'ctl00$pageContent$ctl02$ApplicationQuestions$desiredsalary': '800000inr',
#   'ctl00$pageContent$ctl02$ApplicationQuestions$requiresponsorship': '0',
#   'ctl00$pageContent$qset$ctl06$ch226353$226353': '365393',
#   'ctl00$pageContent$qset$ctl07$ch226354$226354': '10',
#   'ctl00$pageContent$qset$ctl08$ch226355$226355': '8',
#   'ctl00$pageContent$qset$ctl09$ch226356$226356': '365398',
#   'ctl00$pageContent$qset$ctl10$ch226357$226357': 'no',
#   'ctl00$pageContent$qset$ctl11$ch226358$226358': '-',
#   'ctl00$pageContent$qset$ctl12$ch227516$227516': '-',
#   'custom1': 'No',
#   'cut-type': 'adv',
#   'day': '8',
#   'degree': 'BTECH',
#   'doc-name': 'Untitled0.jsx',
#   'edit-amount': '1',
#   'edit-date': '2025-02-14',
#   'edit-key': 'food-nuts',
#   'editor-current-shape': 'on',
#   'education-28--firstYearAttended-dateSectionYear-input': '2020',
#   'education-28--lastYearAttended-dateSectionYear-input': '2024',
#   'education-40--firstYearAttended-dateSectionYear-input': '2020',
#   'education-47--firstYearAttended-dateSectionYear-input': '2020',
#   'education-47--lastYearAttended-dateSectionYear-input': '2024',
#   'education-66--firstYearAttended-dateSectionYear-input': '2020',
#   'education-66--lastYearAttended-dateSectionYear-input': '2024',
#   'education-73--firstYearAttended-dateSectionYear-input': '2020',
#   'education-73--lastYearAttended-dateSectionYear-input': '2024',
#   'education-93--firstYearAttended-dateSectionYear-input': '2020',
#   'education-93--lastYearAttended-dateSectionYear-input': '2024',
#   'email': 'anirudhkashibhatla@gmail.com',
#   'exp-list-item-2': 'on',
#   'exp-list-item-3': 'on',
#   'expMonths': '6',
#   'expYears': '0',
#   'expense-amount': '5273',
#   'expense-description': '53yuiyu',
#   'file': 'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf',
#   'fileData1': 'C:\\fakepath\\1722027181207.jpeg',
#   'file[]': "C:\\fakepath\\Practical Statistics for Data Scientists_ 50+ Essential -- Peter Bruce; Andrew Bruce; Peter Gedeck -- 2, 2020 -- O'Reilly Media -- 9781492072911 -- 7cc7f5be94b748e6ecbe5eff5ff3ee97 -- Anna’s Archive.epub",
#   'fullWidth': 'FDGDFRGDFG',
#   'gender': '1',
#   'html5_1ik3o5vd617m34701csr15cck024': 'C:\\fakepath\\ESLII_print10.pdf',
#   'html5_1ilvke9vb18af1e3178hefr1h4e4': 'C:\\fakepath\\Anirudh_Cover_Letter_JPMG (2).pdf',
#   'html5_1imi9h8vk1vgj14hlhm91c56nhb4': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'income-amount': '-135353',
#   'income-source': 'fggf',
#   'input-101-dateSectionYear-input': '2020',
#   'input-104-dateSectionYear-input': '2024',
#   'input-125-dateSectionYear-input': '2025',
#   'input-21-dateSectionYear-input': '2024',
#   'input-23-dateSectionMonth-input': '7',
#   'input-23-dateSectionYear-input': '2024',
#   'input-24-dateSectionYear-input': '2025',
#   'input-28-dateSectionMonth-input': '7',
#   'input-28-dateSectionYear-input': '2024',
#   'input-31-dateSectionMonth-input': '1',
#   'input-31-dateSectionYear-input': '2025',
#   'input-32-dateSectionYear-input': '2020',
#   'input-35-dateSectionYear-input': '2024',
#   'input-354': 'https://wsdc.nitw.ac.in/home/',
#   'input-42-dateSectionYear-input': '2020',
#   'input-43-dateSectionYear-input': '2020',
#   'input-45-dateSectionYear-input': '2024',
#   'input-46-dateSectionYear-input': '2024',
#   'input-61-dateSectionMonth-input': '1',
#   'input-61-dateSectionYear-input': '2025',
#   'inputDefault': 'algeria',
#   'ipzb1': '',
#   'job_application[answers_attributes][0][text_value]': 'https://www.linkedin.com/in/anirudhkashibhatla/',
#   'job_application[demographic_answers][][answer_options][][answer_option_id]': '7533',
#   'job_application[location]': 'Hyderabad',
#   'less than 6 months': '4',
#   'location': 'Hyderabad, TG, India',
#   'locationId': '6dfc051c-af6f-47e3-a186-093085d081d6',
#   'major': 'Metallurgical Engineering',
#   'mat-input-0': '7093615572',
#   'mat-input-1': '2078',
#   'mat-input-2': '9030077232',
#   'mat-input-3': '9030077232',
#   'mat-input-4': '2078',
#   'mat-input-6': 'give me this code in chat',
#   'memberDob': '08/07/2000',
#   'memberKycDocNo': '417894747994',
#   'memberName': 'Sairam Anirudh Kashibhatla',
#   'memberNewMobileNo': '9030077232',
#   'memberOtp': '248879',
#   'message': 'import React, { useState, useEffect, useRef } from \'react\';\nimport Peer from \'peerjs\';\nimport \'./styles.css\'; // Assuming you\'ll create a styles.css file with the provided CSS\n\nfunction App() {\n  const [messages, setMessages] = useState();\n  const [filterInput, setFilterInput] = useState(\'\');\n  const [messageInput, setMessageInput] = useState(\'\');\n  const [idInput, setIdInput] = useState(\'\');\n  const [durationInput, setDurationInput] = useState(\'\');\n  const [mediaInput, setMediaInput] = useState(null);\n  const [joinRoomIdInput, setJoinRoomIdInput] = useState(\'\');\n  const [isCreateRoomModalOpen, setIsCreateRoomModalOpen] = useState(false);\n  const [roomId, setRoomId] = useState(\'\');\n  const [roomPassword, setRoomPassword] = useState(\'\');\n  const [roomDuration, setRoomDuration] = useState(60);\n  const [roomErrorMessage, setRoomErrorMessage] = useState(\'\');\n  const [activeTab, setActiveTab] = useState(\'basic\');\n  const [layoutOption, setLayoutOption] = useState(\'default\');\n  const [upvoteOption, setUpvoteOption] = useState(\'disabled\');\n  const [messageRateLimit, setMessageRateLimit] = useState(0);\n  const [compulsoryDuration, setCompulsoryDuration] = useState(0);\n  const [createdRooms, setCreatedRooms] = useState({});\n  const messageTimestamps = useRef();\n  const uploadedMedia = useRef(null);\n  const peer = useRef(null);\n  const conn = useRef(null);\n  const myId = useRef(null);\n  const connectedRoomId = useRef(null);\n\n  useEffect(() => {\n    initPeer();\n    // Load any existing rooms from local storage on component mount\n    const storedRooms = {};\n    for (let i = 0; i < localStorage.length; i++) {\n      const key = localStorage.key(i);\n      if (key) {\n        try {\n          storedRooms[key] = JSON.parse(localStorage.getItem(key));\n        } catch (e) {\n          console.error(\'Error parsing room data from local storage\', e);\n        }\n      }\n    }\n    setCreatedRooms(storedRooms);\n  },);\n\n  const generateId = () => {\n    return Math.random().toString(36).substring(2, 15) + Math.random().toString(36).substring(2, 15);\n  };\n\n  const handleMediaInputChange = (event) => {\n    const file = event.target.files[0];\n    const validImageTypes = [\'image/gif\', \'image/jpeg\', \'image/png\'];\n    const validVideoTypes = [\'video/mp4\', \'video/webm\'];\n\n    if (file) {\n      if (validImageTypes.includes(file.type)) {\n        uploadedMedia.current = {\n          type: \'image\',\n          url: URL.createObjectURL(file),\n        };\n      } else if (validVideoTypes.includes(file.type)) {\n        uploadedMedia.current = {\n          type: \'video\',\n          url: URL.createObjectURL(file),\n        };\n      } else {\n        alert(\'Invalid file type. Please upload an image or video.\');\n        setMediaInput(null);\n        uploadedMedia.current = null;\n      }\n      setMediaInput(file);\n    }\n  };\n\n  const postMessage = () => {\n    const messageTextValue = messageInput;\n    const messageIdValue = idInput.trim();\n    const durationValue = durationInput;\n    if (!messageTextValue && !uploadedMedia.current) return;\n\n    const newMessage = {\n      id: messageIdValue || generateId(),\n      text: messageTextValue,\n      duration: durationValue,\n      timestamp: new Date().toLocaleTimeString(),\n      left: `${Math.random() * (window.innerWidth - 320)}px`,\n      top: `${Math.random() * (window.innerHeight - 120)}px`,\n      media: uploadedMedia.current,\n    };\n\n    // Apply layout\n    if (createdRooms[connectedRoomId.current]?.layout === \'grid\') {\n      const gridX = Math.floor(Math.random() * 5) * 320;\n      const gridY = Math.floor(Math.random() * 3) * 200;\n      newMessage.left = `${gridX}px`;\n      newMessage.top = `${gridY}px`;\n    }\n\n    setMessages((prevMessages) => [...prevMessages, newMessage]);\n    setMessageInput(\'\');\n    setIdInput(\'\');\n    setDurationInput(\'\');\n    setMediaInput(null ...
#   'messageInput': 'hgh',
#   'messageRateLimit': '0453',
#   'mobilePhone.countryCode': '+91',
#   'mobilePhone.number': '7093615572',
#   'mobilenumber': '7093615572',
#   'month': '8',
#   'name': 'Anirudh Kashibhatla',
#   'newPassword': 'Guruji$1234567',
#   'oj-combobox-2|input': 'waranga',
#   'org': 'Futures First',
#   'otc-1': '3',
#   'otc-2': '3',
#   'otc-3': '4',
#   'otc-4': '5',
#   'otc-5': '8',
#   'otc-6': '3',
#   'otpEnt.otp': '183104',
#   'otpPinValue': '032840',
#   'pass': 'anirudhbzgh',
#   'password': 'anirudhbzgh',
#   'phone': '7093615572',
#   'phoneCountry': 'IN',
#   'phoneCountryCode': '+91',
#   'phoneNumber': '070936 15572',
#   'phone_code': '+91',
#   'photos': 'C:\\fakepath\\1722027181207.jpeg',
#   'previousWorker.No': 'No',
#   'primaryQuestionnaire--97a56ab3ad0b101994f18d396b180003': '1020000',
#   'profileStatus': 'true',
#   'pull_request[title]': 'eda',
#   'r37c9a937bd9f410eb836e973fcf46531': 'No',
#   'r7eb3e444dcba4c7e8edff877bb920943': 'Yes',
#   'rateType': 'HOURLY',
#   'react-select-2-input': 'Hyderabad',
#   'react-select-3-input': 'Hyderabad',
#   'relevantExpMonths': '6',
#   'relevantExpYears': '0',
#   'resume': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'resume-upload': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume_.pdf',
#   's': 'https://wsdc.nitw.ac.in/home/',
#   'school': 'NITW',
#   'seat-pool': 'gn',
#   'select_title': 'g',
#   'smsOptIn': 'true',
#   'standardFields.locationPreference.answer': 'Bangalore',
#   'state': 'Telangana',
#   'stroke-width': 'on',
#   'subject': 'Request for referral',
#   'suggestor': 'DATA MODE',
#   'surveysResponses[a941fe7e-411c-49c9-bcd3-3ea360533bc4][responses][field0]': 'Male',
#   'termscondition': 'on',
#   'text-color': '[1,2,3,4,5,6]',
#   'token-input-primarySkills': 'STATISTIC',
#   'token-input-secondarySkills': 'DATA ',
#   'uan': '102103896453',
#   'uhiw1': '',
#   'uploadFile': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#   'urls[LinkedIn]': 'https://www.linkedin.com/in/anirudhkashibhatla/',
#   'userName': '102103896453',
#   'wcav4': '',
#   'workExperience-33--endDate-dateSectionMonth-input': '1',
#   'workExperience-33--endDate-dateSectionYear-input': '2025',
#   'workExperience-33--startDate-dateSectionMonth-input': '7',
#   'workExperience-33--startDate-dateSectionYear-input': '2024',
#   'workExperience-38--endDate-dateSectionMonth-input': '1',
#   'workExperience-38--endDate-dateSectionYear-input': '2025',
#   'workExperience-38--startDate-dateSectionMonth-input': '7',
#   'workExperience-38--startDate-dateSectionYear-input': '2024',
#   'workExperience-5--endDate-dateSectionMonth-input': '1',
#   'workExperience-5--endDate-dateSectionYear-input': '2025',
#   'workExperience-5--startDate-dateSectionMonth-input': '7',
#   'workExperience-5--startDate-dateSectionYear-input': '2024',
#   'workExperience-57--endDate-dateSectionMonth-input': '1',
#   'workExperience-57--endDate-dateSectionYear-input': '2025',
#   'workExperience-57--startDate-dateSectionMonth-input': '7',
#   'workExperience-57--startDate-dateSectionYear-input': '2024',
#   'workExperience.months': '6',
#   'yDssXfwe': 'on',
#   'year': '2000',
#   'youtube_url': 'https://www.youtube.com/watch?v=vA0-3hm5q2Y',
#   '\xa0I acknowledge *': '1',
#   '\xa0I agree': '1043734',
#   '\xa0Male': '22852622',
#   '\xa0No': '1182096',
#   '\xa0No thanks, continue to apply': '38',
#   '\xa0Yes': '37'},
#  'https://spgi.wd5.myworkdayjobs.com/en-us/SPGI_Careers/job/Hyderabad-Telangana/Data-Analyst_310792-1/apply?utm_source=linkedin': {'Company*': '',
#   'Country Phone Code*': 'India',
#   'Field of Study': 'Metallurgical Engineering',
#   'Job Title*': '',
#   'Location': '',
#   'Overall Result (GPA)': '7.19',
#   'Phone Number*': '70936 15572',
#   'Role Description': '',
#   'School or University*': '',
#   'What is your desired annual gross base salary in your local currency?': '800000',
#   'Yes, I acknowledge that I have read and understand the policy.*': 'on',
#   'input-24-dateSectionMonth-input': '7',
#   'input-24-dateSectionYear-input': '2024',
#   'input-27-dateSectionMonth-input': '1',
#   'input-27-dateSectionYear-input': '2025',
#   'input-77-dateSectionYear-input': '2020',
#   'input-80-dateSectionYear-input': '2024'}}

# %%
embeddings = model.encode(["what is your work experience excluding internships", "how much period have you worked"])
embeddings
# Out:
# array([[ 3.19674350e-02,  4.48963344e-02,  2.96354219e-02,
#          1.13420300e-02,  1.78942028e-02, -1.36142457e-02,
#         -2.70699859e-02, -2.37095729e-02, -6.23858795e-02,
#         -3.08310520e-02, -7.01392116e-03,  5.15761971e-03,
#          6.13437556e-02, -3.07480898e-02, -7.04440475e-02,
#          1.60166528e-02,  2.24253982e-02, -5.56186736e-02,
#          4.71007824e-02, -1.55279279e-01, -4.43157107e-02,
#         -7.55909458e-02,  7.76415467e-02, -1.92198437e-02,
#         -1.50336400e-02, -4.52235229e-02,  7.40479026e-03,
#          5.44520356e-02, -9.15555507e-02, -4.99601923e-02,
#         -1.20127879e-01, -7.71245137e-02,  2.69190185e-02,
#         -3.02804932e-02, -5.57917021e-02, -5.30589430e-04,
#         -2.84133595e-03, -1.88250877e-02,  1.14393033e-01,
#          6.70937542e-03, -5.54365776e-02,  1.43183675e-02,
#         -1.15610883e-01,  4.28774580e-02,  6.16316451e-03,
#         -3.90072092e-02, -3.22274026e-03,  1.65281296e-02,
#          6.68649971e-02,  3.52971628e-02,  3.12011819e-02,
#         -7.33221741e-03,  2.41689365e-02, -5.75617962e-02,
#         -1.41567677e-01, -3.18517461e-02, -9.73107759e-03,
#         -1.84768960e-02, -1.04844123e-01,  4.35893331e-03]], dtype=float32)

# %%
similarity = util.pytorch_cos_sim(embeddings[0], embeddings[1])
similarity
# Out:
# tensor([[0.3372]])

# %%
data1 = {}
for key,value in data.items():
      for a,b in value.items():
        data1[a] = b
print(data1)
data1list = list(data1.items())
dfdata1 = pd.DataFrame(data1list, columns=['Key', 'Value'])
# Out:
# {'1': '9', '2': '3', '3': '6', '4': '4', '2024': '3', '10715': '57', '\n                    Excercises filter input\n                  ': '', '\n                    Filter field for certifications\n                  ': '', '\n                    Password                ': 'q#Nf8Hz47KjsMPb', ' ': 'discuss particle physics and create a model that stimulates 3d particle interactions and dynamics in c++ using any  librarireas needed along with the math', ' Choose not to reply': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__17976', ' File': 'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf', ' Male': 'com.taleo.systemcomponent.question.entity.RegulationPossibleAnswer__4205011901', ' No': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19098', ' Not applicable': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19325', ' Yes': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19337', ' Yes - I currently hold a PAN card.': 'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__46057', '*\n\xa0Address Line 1': 'DAFFODILS APTS,DD COLNY', '*\n\xa0City': 'Hyderabad', '*\n\xa0Country': 'India', '*\n\xa0Degree': 'Bachelor', '*\n\xa0Email Address': 'anirudhkashibhatla@gmail.com', '*\n\xa0In the future, will you require sponsorship from Moody’s to work within the country to which you are applying?': 'No', '*\n\xa0Legal First Name': 'Anirudh', '*\n\xa0Legal Last Name': 'Kashibhatla', '*\n\xa0Primary Contact Number': '+917093615572', '*I have read and agree to the Employee Candidate\xa0Privacy Statement\n': 'on', '*Passcode:': '872554', '11 - 13 LPA': '201132701002', '6months - 2years': '1', ':1gi': 'meenakumarimanyam@gmail.com', ':r0:': '', ':r1:': 'xFRuDg', 'A Pandas Series': '2', 'Access password': 'sample', 'Access up‐to‐date course content': 'on', 'Achievements\n\xa0': 'At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. This ownership of real-time analytics has strengthened my ability to deliver actionable insights in fast-paced environments.\nActively traded a range of ICE,CME,EURONEXT commodity futures, including SRW ,HRW,yEBM, Corn, canola,\nyECO, and soybean oil.\n• Monitored market dynamics using open-source data focusing on supply-demand trends, geopolitical developments,\nand weather-driven factors influencing agricultural prices.\n• Developed and implemented more than 100 hedging strategies, optimized diversification using covariance analysis,\nand applied risk budgeting to mitigate risk and preserve portfolio stability during market volatility.\n• Applied lead-lag relationships, intermarket strategies, and arbitrage opportunities using tools like correlation\nanalysis and statistical tests to identify profitable trades', 'Active backlogs37442': 'No', 'Address :': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 1': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 1\n*': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 1 - Local*': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 1*': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address Line 2*': ', B lane, DD Colony, Amberpet', 'Address line 1 ': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Address line 2': 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet', 'Alternate Email ID37414': 'sr922003@student.nitw.ac.in', 'Anticipated Graduation Date\n\xa0': 'on', 'Are hands on form ...

# %%
dfdata1.head(50)
# Out:
#                                                   Key  \
# 0                                                   1
# 1                                                   2
# 2                                                   3
# 3                                                   4
# 4                                                2024
# 5                                               10715
# 6   \n                    Excercises filter input\...
# 7   \n                    Filter field for certifi...
# 8      \n                    Password
# 9
# 10                                Choose not to reply
# 11                                               File
# 12                                               Male
# 13                                                 No
# 14                                     Not applicable
# 15                                                Yes
# 16                 Yes - I currently hold a PAN card.
# 17                                 *\n Address Line 1
# 18                                           *\n City
# 19                                        *\n Country
# 20                                         *\n Degree
# 21                                  *\n Email Address
# 22  *\n In the future, will you require sponsorshi...
# 23                               *\n Legal First Name
# 24                                *\n Legal Last Name
# 25                         *\n Primary Contact Number
# 26  *I have read and agree to the Employee Candida...
# 27                                         *Passcode:
# 28                                        11 - 13 LPA
# 29                                   6months - 2years
# 30                                               :1gi
# 31                                               :r0:
# 32                                               :r1:
# 33                                    A Pandas Series
# 34                                    Access password
# 35                   Access up‐to‐date course content
# 36                                    Achievements\n
# 37                               Active backlogs37442
# 38                                          Address :
# 39                                     Address Line 1
# 40                                  Address Line 1\n*
# 41                            Address Line 1 - Local*
# 42                                    Address Line 1*
# 43                                    Address Line 2*
# 44                                    Address line 1
# 45                                     Address line 2
# 46                            Alternate Email ID37414
# 47                     Anticipated Graduation Date\n
# 48  Are hands on formulas like VLOOKUP, HLOOKUP, S...
# 49  Are you a current or former employee or offici...
#
#                                                 Value
# 0                                                   9
# 1                                                   3
# 2                                                   6
# 3                                                   4
# 4                                                   3
# 5                                                  57
# 6
# 7
# 8                                     q#Nf8Hz47KjsMPb
# 9   discuss particle physics and create a model th...
# 10  com.taleo.functionalcomponent.prescreening.ent...
# 11       C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# 12  com.taleo.systemcomponent.question.entity.Regu...
# 13  com.taleo.functionalcomponent.prescreening.ent...
# 14  com.taleo.functionalcomponent.prescreening.ent...
# 15  com.taleo.functionalcomponent.prescreening.ent...
# 16  com.taleo.functionalcomponent.prescreening.ent...
# 17                            DAFFODILS APTS,DD COLNY
# 18                                          Hyderabad
# 19                                              India
# 20                                           Bachelor
# 21                       anirudhkashibhatla@gmail.com
# 22                                                 No
# 23                                            Anirudh
# 24                                        Kashibhatla
# 25                                      +917093615572
# 26                                                 on
# 27                                             872554
# 28                                       201132701002
# 29                                                  1
# 30                        meenakumarimanyam@gmail.com
# 31
# 32                                             xFRuDg
# 33                                                  2
# 34                                             sample
# 35                                                 on
# 36  At Futures First, I worked extensively with op...
# 37                                                 No
# 38  Flat 201, Daffodils Appt, B61, B lane, DD Colo...
# 39  Flat 201, Daffodils Appt, B61, B lane, DD Colo...
# 40  Flat 201, Daffodils Appt, B61, B lane, DD Colo...
# 41  Flat 201, Daffodils Appt, B61, B lane, DD Colo...
# 42  Flat 201, Daffodils Appt, B61, B lane, DD Colo...
# 43                      , B lane, DD Colony, Amberpet
# 44  Flat 201, Daffodils Appt, B61, B lane, DD Colo...
# 45  Flat 201, Daffodils Appt, B61, B lane, DD Colo...
# 46                        sr922003@student.nitw.ac.in
# 47                                                 on
# 48                                                Yes
# 49                                                 38

# %%
data2 = {}
for key,value in data1.items():
  data2[value] = key
data2list = list(data2.items())
dfdata2 = pd.DataFrame(data2list, columns=['Value', 'Key'])
x = [key for key,value in data2.items()]
len(x)
# Out:
# 243

# %%
dfdata2.head(50)
dfdata2['Value_Length'] = dfdata2['Value'].astype(str).apply(len)
dfdata2.sort_values(by=['Value_Length'], inplace=True)
dfdata2.drop(columns=['Value_Length'], inplace=True)
dfdata2 = dfdata2[:-1]
print(dfdata2.shape)
dfdata2.tail(50)
# Out:
# (242, 2)
#                                                  Value  \
# 215                          give me this code in chat
# 217                         Sairam Anirudh Kashibhatla
# 184                         Yes, by way of citizenship
# 28                         meenakumarimanyam@gmail.com
# 35                         sr922003@student.nitw.ac.in
# 19                        anirudhkashibhatla@gmail.com
# 169                      Available to join immediately
# 34                       , B lane, DD Colony, Amberpet
# 204                      C:\fakepath\ESLII_print10.pdf
# 208                      https://wsdc.nitw.ac.in/home/
# 115                     Own Vehicle (non-reimbursable)
# 201                     C:\fakepath\1722027181207.jpeg
# 212               6dfc051c-af6f-47e3-a186-093085d081d6
# 67             C:\fakepath\Anirudh_Kashibhatla_CV_.pdf
# 179            C:\fakepath\Anirudh_Kashibhatla_Sde.pdf
# 158           C:\fakepath\Anirudh_Kashibhatla_CV _.pdf
# 124           Java,Python,C++,SQL,React,MongoDB,Pandas
# 187          list steps to start mongdb server backend
# 112          National Institute of Technology Warangal
# 53         C:\fakepath\Anirudh_Kashibhatla_Resume_.pdf
# 238        https://www.youtube.com/watch?v=vA0-3hm5q2Y
# 9         C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# 139       C:\fakepath\Anirudh_Kashibhatla__Resume_.pdf
# 205      C:\fakepath\Anirudh_Cover_Letter_JPMG (2).pdf
# 172      aditya.rama-kamalanath-polepeddi@michelin.com
# 119    https://www.linkedin.com/in/anirudhkashibhatla/
# 160   C:\fakepath\b8f7fbf246fc1d7ec90ddba93883b6d2.gif
# 33   Flat 201, Daffodils Appt, B61, B lane, DD Colo...
# 121  com.taleo.systemcomponent.olf.entity.NetworkLo...
# 154  Flat 201, Daffod ils Appt, B61, B lane, DD Col...
# 10   com.taleo.systemcomponent.question.entity.Regu...
# 8    com.taleo.functionalcomponent.prescreening.ent...
# 11   com.taleo.functionalcomponent.prescreening.ent...
# 13   com.taleo.functionalcomponent.prescreening.ent...
# 14   com.taleo.functionalcomponent.prescreening.ent...
# 12   com.taleo.functionalcomponent.prescreening.ent...
# 134  com.taleo.functionalcomponent.talent.entity.co...
# 99   com.taleo.functionalcomponent.talent.entity.co...
# 76   com.taleo.functionalcomponent.talent.entity.co...
# 96   com.taleo.functionalcomponent.talent.entity.co...
# 74   com.taleo.functionalcomponent.talent.entity.co...
# 167  com.taleo.functionalcomponent.talent.entity.co...
# 174  com.taleo.functionalcomponent.talent.entity.co...
# 77   com.taleo.functionalcomponent.talent.entity.co...
# 164  com.taleo.functionalcomponent.talent.entity.co...
# 7    discuss particle physics and create a model th...
# 202  C:\fakepath\Practical Statistics for Data Scie...
# 72   - Developed and deployed trading,hedging strat...
# 140  At Futures First, I worked extensively with op...
# 32   At Futures First, I worked extensively with op...
#
#                                                    Key
# 215                                        mat-input-6
# 217                                         memberName
# 184  cards[b937576d-7460-40d2-ae79-762f158be671][fi...
# 28                                                :1gi
# 35                             Alternate Email ID37414
# 19                                               email
# 169  What is your notice period?\nWhat is your noti...
# 34                                     Address Line 2*
# 204                 html5_1ik3o5vd617m34701csr15cck024
# 208                                                  s
# 115  Is your travel to the office, the company prov...
# 201                                             photos
# 212                                         locationId
# 67                                            Resume *
# 179                                           attachCV
# 158                         attachment-input-ember1141
# 124  PLEASE_LIST_YOUR_PRIMARY_AND_SECONDARY_TECHNIC...
# 187                                         chat-input
# 112                  Undergraduate Institute Name37419
# 53                                       resume-upload
# 238                                        youtube_url
# 9                                           uploadFile
# 139                                               file
# 205                 html5_1ilvke9vb18af1e3178hefr1h4e4
# 172               What's their name or email address?*
# 119                                     urls[LinkedIn]
# 160                                       Upload Media
# 33                                      Street Address
# 121                                             Region
# 154           Street Address (line 1)\n \n. \nRequired
# 10                                                Male
# 8                                  Choose not to reply
# 11                                                  No
# 13                                                 Yes
# 14                  Yes - I currently hold a PAN card.
# 12                                      Not applicable
# 134                                          Prefix\n
# 99            Highest Education Level\n \n. \nRequired
# 76   Do you have any relatives currently working wi...
# 96   Gender (as shown on your national ID)\n \n. \n...
# 74   Do you have a disability (including physical o...
# 167     What is your gender identity?\n \n. \nRequired
# 174  Which of the following best describes your sex...
# 77          Do you identify as Trans?\n \n. \nRequired
# 164        What is your Ethnic Group?\n \n. \nRequired
# 7
# 202                                             file[]
# 72                                         Description
# 140                           Roles & Responsibilities
# 32                                     Achievements\n

# %%
keys = []
for key,value in data1.items():
  keys.append(key)
len(keys)
# Out:
# 705

# %%
print(keys[38],"/",keys[39])
# Out:
# Address : / Address Line 1

# %%
data1[keys[39]]
# Out:
# 'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet'

# %%
embedding1 = model.encode('Address Line 1')
embedding2 = model.encode('Address :')
similarity_score = cosine_similarity([embedding1], [embedding2])
similarity
# Out:
# tensor([[0.3372]])

# %%
embeddings = model.encode(keys, show_progress_bar=True)
embeddings.shape
# Out:
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]
# (705, 384)

# %%
clusters = community_detection(embeddings, threshold=0.5)
print(len(clusters))
sum = 0
for cluster in clusters:
   sum += len(cluster)
print(sum)
# Out:
# 18
# 382

# %%
for cluster in clusters:
  for i,index in enumerate(cluster):
    print(keys[index],":",data1[keys[index]])
    if i == len(cluster)-1:
      print("///")
# Out:
# workExperience-38--endDate-dateSectionMonth-input : 1
# workExperience-33--endDate-dateSectionMonth-input : 1
# workExperience-57--endDate-dateSectionMonth-input : 1
# workExperience-5--endDate-dateSectionMonth-input : 1
# workExperience-38--startDate-dateSectionMonth-input : 7
# workExperience-38--endDate-dateSectionYear-input : 2025
# workExperience-33--startDate-dateSectionMonth-input : 7
# workExperience-33--endDate-dateSectionYear-input : 2025
# workExperience-57--startDate-dateSectionMonth-input : 7
# workExperience-57--endDate-dateSectionYear-input : 2025
# workExperience-5--startDate-dateSectionMonth-input : 7
# workExperience-5--endDate-dateSectionYear-input : 2025
# workExperience-38--startDate-dateSectionYear-input : 2024
# workExperience-33--startDate-dateSectionYear-input : 2024
# input-28-dateSectionMonth-input : 7
# input-31-dateSectionMonth-input : 1
# input-27-dateSectionMonth-input : 1
# input-23-dateSectionMonth-input : 7
# workExperience-57--startDate-dateSectionYear-input : 2024
# input-24-dateSectionMonth-input : 7
# workExperience-5--startDate-dateSectionYear-input : 2024
# input-61-dateSectionMonth-input : 1
# input-28-dateSectionYear-input : 2024
# input-31-dateSectionYear-input : 2025
# input-27-dateSectionYear-input : 2025
# input-42-dateSectionYear-input : 2020
# input-35-dateSectionYear-input : 2024
# input-43-dateSectionYear-input : 2020
# End date month* : 6
# input-46-dateSectionYear-input : 2024
# input-21-dateSectionYear-input : 2024
# input-45-dateSectionYear-input : 2024
# input-32-dateSectionYear-input : 2020
# input-23-dateSectionYear-input : 2024
# input-61-dateSectionYear-input : 2025
# input-24-dateSectionYear-input : 2024
# input-125-dateSectionYear-input : 2025
# education-28--lastYearAttended-dateSectionYear-input : 2024
# input-77-dateSectionYear-input : 2020
# input-104-dateSectionYear-input : 2024
# input-80-dateSectionYear-input : 2024
# End date year* : 2023
# End date : 2024-06-01
# input-101-dateSectionYear-input : 2020
# education-47--lastYearAttended-dateSectionYear-input : 2024
# education-73--lastYearAttended-dateSectionYear-input : 2024
# education-28--firstYearAttended-dateSectionYear-input : 2020
# education-66--lastYearAttended-dateSectionYear-input : 2024
# End date * : 2025-01-10
# End Date * : 2025-01
# workExperience.months : 6
# education-93--lastYearAttended-dateSectionYear-input : 2024
# education-40--firstYearAttended-dateSectionYear-input : 2020
# education-73--firstYearAttended-dateSectionYear-input : 2020
# education-47--firstYearAttended-dateSectionYear-input : 2020
# education-66--firstYearAttended-dateSectionYear-input : 2020
# education-93--firstYearAttended-dateSectionYear-input : 2020
# Start date year* : 2020
# ///
# How many years of relevant work experience do you have?
# How many years of relevant work experience do you have?
#   : 6 months to 1 year
# How many years of work experience do you have with SQL? : 0
# How many years of work experience do you have with Recommender Systems? : 0
# How many years of work experience do you have with Communication? : 0
# How many years of work experience do you have with Databases? : 0
# How many years of work experience do you have with Machine Learning? : 0
# How many years of work experience do you have with Predictive Modeling? : 0
# How many years of work experience do you have with Data Analysis? : 1
# How many years of work experience do you have with Microsoft Excel? : 1
# How many years of work experience do you have with Deep Learning? : 0
# How many years of work experience do you have with Data Science? : 0
# How many years of Analyst experience do you currently have? : 1
# How many years of Business Analytics experience do you currently have? : 0.5
# How many years of work experience do you have with Snowflake? : 0
# How many years of work experience do you have with Tableau? : 0
# How many years of work experience do you have with Payment Systems? : 0
# How many years of work experience do you have with BigSQL? : 0
# Total Years of Experience : 0.5
# How many years of experience do you have working with investment banks?* : 0
# How many years of work experience do you have with Data Visualization? :
# How many years of experience do you have in Quantitative Finance?* : 0.5
# How many years of work experience do you have with Python (Programming Language)? : 0
# How many years of work experience do you have with Mixpanel? : 0
# Total Experience (in years) : 0.5
# How many years of Merchant management experience do you have ?
# How many years of Merchant management experience do you have ?
#   : No
# Total years of experience* : 0.5
# Total Years of Experience* : 0.5
# How many years of work experience do you have with SWIFT Payments? : 0
# How many years of work experience do you have with Generative AI? : 0
# How many years of work experience do you have with Pivot Tables? : 0
# How many years of professional experience do you have working with coding languages and their application in the field of finance/markets? * : 0.5
# How many years of work experience do you have with Medallion Architecture. : 0
# How many years of hands-on work experience with NetSuite? : 0
# How many years of Transaction monitoring experience do you hold?  : 0
# What is your Relevant Experience? : 0.5
# Years of Experience
#
# .
# Required : 0.5
# How many years of work experience do you have with Google Cloud Platform (GCP)? : 0
# What domain/industry experience you have  ( Manufacture / Automotive / Aerospace / Healthcare ) ? : Finance
# How many years of experience in Podtfolio Management? : 0.5
# How many years of experience in credit risk? : 0
# How many years of experience you in GenAI? : 0
# How many years experience as a Data Scientist : 0.5
# ///
# Email or mobile phone number : anirudhkashibhatla@gmail.com
# Email or phone : anirudhkashibhatla@gmail.com
# Email or Phone : anirudhkashibhatla@gmail.com
# Mobile Number
#
# .
# Required : 7093615572
# Email Address  : anirudhkashibhatla@gmail.com
# Email address : anirudhkashibhatla@gmail.com
# Email Address : anirudhkashibhatla@gmail.com
# email : anirudhkashibhatla@gmail.com
# Email : anirudhkashibhatla@gmail.com
# mobilePhone.number : 7093615572
# Enter mobile number : 7093615572
# Phone Number : 07093615572
# Phone number : +917093615572
# Mobile Phone number *
# This is a required field. : 7093615572
# phoneNumber : 070936 15572
# mobilenumber : 7093615572
# Email ID: : anirudhkashibhatla@gmail.com
# E-mail Address
#
# .
# Required : anirudhkashibhatla@gmail.com
# Preferred Contact Number
#
# .
# Required : 7093615572
# Cellular Number
#
# .
# Required : 7093615572
# Business email : anirudhkashibhatla@gmail.com
# Email address
# * : anirudhkashibhatla@gmail.com
# Email Address* : anirudhkashibhatla@gmail.com
# Email address* : anirudhkashibhatla@gmail.com
# Phone number* : 7093615572
# Phone Number* : 70936 15572
# Phone number
# * : 7093615572
# Phone number * : +917093615572
# Email ID37413 : anirudhkashibhatla@gmail.com
# Primary Phone Number
#
# .
# Required : 7093615572
# *
#  Email Address : anirudhkashibhatla@gmail.com
# Email Address: * : anirudhkashibhatla@gmail.com
# Email Address:* : anirudhkashibhatla@gmail.com
# Contact Number * : 7093615572
# Email* : anirudhkashibhatla@gmail.com
# Email * : anirudhkashibhatla@gmail.com
# Phone Number:* : 7093615572
# ///
# Last Name: * : Kashibhatla
# Last Name* : Kashibhatla
# Last name * : Kashibhatla
# First Name: * : Anirudh
# Last Name : Kashibhatla
# Last name : Kashibhatla
# Last name  : Kashibhatla
# First name: : Anirudh
# First Name* : Anirudh
# First name * : Anirudh
# Full Name* : Anirudh Kashibhatla
# Legal Last Name * : Kashibhatla
# First Name : Anirudh
# First name  : Anirudh
# *
#  Legal Last Name : Kashibhatla
# Given Name* : Anirudh
# Full name : Anirudh Kashibhatla
# Family Name
# * : Kashibhatla
# Family Name* : Kashibhatla
# Given Name(s)
# * : Anirudh
# Given Name(s)* : Anirudh
# Name : Anirudh Kashibhatla
# name : Anirudh Kashibhatla
# Your Name * : Anirudh Kashibhatla
# Last Name37411 : Kashibhatla
# Legal First Name * : Anirudh
# Legal first name * : Anirudh
# *
#  Legal First Name : Anirudh
# Family Name : Kashibhatla
# First Name37410 : Anirudh
# Type Your Full Name Here : Anirudh Kashibhatla
# Company name* : Futures First
# ///
# Location (City)* : Hyderabad
# City* : Hyderabad
# City
# * : Hyderabad
# *
#  City : Hyderabad
# City : Hyderabad
# City  : Hyderabad
# City
#   : Hyderabad
# City - Local* : Hyderabad
# City
# City : hydera
# City
# City
#   : hyderabad
# Location :
# location : Hyderabad, TG, India
# Current Location * : Hyderabad
# Resident city : : hYDERA
# Current Location?* : Hyderabad
# City
#
# .
# Required : Hyderabad
# City *
# This is a required field. : Hyderabad
# Current City : Hyderabad
# Preferred Location : Hyderabad
# Current Location : Hyderabad
# Country/Region of Residence:* : IN
# locationId : 6dfc051c-af6f-47e3-a186-093085d081d6
# Nearest Metropolitan City : com.taleo.systemcomponent.olf.entity.NetworkLocation__54300
# First Location Preference : 890901
# Second Location Preference : 11267698
# ExperienceDetails[0].location : Hyderabad
# Country * : 101
# *
#  Country : India
# Country/Region Code:* : IN
# ///
# What is your current ctc ? : 10.2
# What is your current CTC? : 1020000
# What is your Current CTC? : 10.2
# Whats your current CTC? : 1020000
# What is your current CTC? (INR) : 1020000
# What's your current CTC? (In Lakhs) : 10
# Current ctc? : 10.2
# Current CTC : 1020000
# What is your current annual CTC (in INR)? : 1020000
# What is your expected CTC? : 900000
# What is your Expected CTC? : 10.2
# What is your expected ctc? : 10.2
# Whats your expected CTC? : 1020000
# What is your current CTC in lakhs (for e.g. 6/ 9/ 11 etc)? : 10.2
# What is your current annual CTC, in Lakhs? : 10
# CTC: : 10.2
# What is your expected annual CTC (in INR)? : 1020000
# Expected ctc? : 10.2
# What is your expected annual CTC, in Lakhs? : 10
# Expected CTC: : 11
# What is your current compensation? : 1020000
# ///
# phone_code : +91
# phoneCountryCode : +91
# Country Phone Code* : India
# mobilePhone.countryCode : +91
# phoneCountry : IN
# Country / Territory Phone Code* : +917093615572
# International Dialling Code
#   : 7093615572
# Code : 47379623
# International Calling Code
# International Calling Code
#
# .
# Required : +91
# Cell Phone : 07093615572
# Phone : 07093615572
# phone : 7093615572
# Phone * : +917093615572
# Phone* : 7093615572
# Postal Code* : 500013
# Enter code : 002584
# countryCode : IN
# *Passcode: : 872554
# ///
# Are you serving notice period ?
# Are you serving notice period ?
#   : No
# What is your notice period?
# What is your notice period?
#   : Available to join immediately
# Notice period : 0
# Notice Period: : 0
# Notice period : : 0
# What is your Notice Period? : 0
# What is your notice period? : 0
# What is your notice period ? : 0
# Notice Period? : 0
# What is your Official Notice Period in days? : 0
# Please share your remaining Notice Period : 0
# Whats your notice period? : 0
# Please confirm your Notice Period (In Days) : 0
# What is your notice period (in days)? : 0
# What's your notice period? (In days)  : 0
# What is your notice period in days (e.g. 0/ 15/ 30/ 45 with 0 meaning immediate joiner) ? : 0
# Please mention your notice period to join? : 0
# Notice Period? * : 0
# ///
# cards[0c0bf90e-d4ac-454a-a268-701db5240562][field0] : Yes
# cards[b937576d-7460-40d2-ae79-762f158be671][field0] : Yes, by way of citizenship
# cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field0] : No
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field0] : Male
# cards[61edf07f-a0f9-41cd-8901-24d4cb79eb71][field0] : I Agree
# cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field0] : Between 9 LPA- 11LPA
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field4] : 1020000
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field7] : Linkedin
# cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field1] : Yes
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field5] : 1020000
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field1] : 0.5
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field3] : Yes
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field6] : 0
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field2] : No
# cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field1] : 0
# cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field2] : 10LPA
# Please provide your PAN Card Number
#
# .
# Required : JCSPK3366J
# ///
# uploadFile : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# Upload a file : C:\fakepath\Anirudh_Kashibhatla_Resume_.pdf
# Upload : C:\fakepath\Anirudh_Kashibhatla__Resume_.pdf
# Upload Media : C:\fakepath\b8f7fbf246fc1d7ec90ddba93883b6d2.gif
# file : C:\fakepath\Anirudh_Kashibhatla__Resume_.pdf
#  File : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# Attach File : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# resume-upload : C:\fakepath\Anirudh_Kashibhatla_Resume_.pdf
# UPLOAD RESUME : C:\fakepath\Anirudh_Kashibhatla_CV _.pdf
# Upload resume : C:\fakepath\Anirudh_Kashibhatla__Resume_.pdf
# Select the file to attach : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# Choose file : C:\fakepath\Anirudh_Kashibhatla_Resume_.pdf
# Upload resume : : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# file[] : C:\fakepath\Practical Statistics for Data Scientists_ 50+ Essential -- Peter Bruce; Andrew Bruce; Peter Gedeck -- 2, 2020 -- O'Reilly Media -- 9781492072911 -- 7cc7f5be94b748e6ecbe5eff5ff3ee97 -- Anna’s Archive.epub
# Choose Files : C:\fakepath\logo.png
# ///
# I acknowledge and understand the Privacy Policy, and I hereby consent to the Applicant Terms. : on
# I have read the terms of the privacy policy and consent to the processing of my information : on
# By applying, you hereby accept the data processing terms under the Privacy Policy and give consent to processing of the data as part of this job application. : 2
# *I have read and agree to the Employee Candidate Privacy Statement
#  : on
# I acknowledge and agree to Invesco's Recruitment Privacy Notice : on
# I have read the Privacy Notice : on
# I accept AMEX GBT's Recruitment Privacy Statement : on
# I consent to the Google APIs Terms of Service and the Gemini API Additional Terms of Service and acknowledge that I have read the Google Privacy Policy * : on
# I authorize the use of my responses to these questions to help with the Company's Diversity and Inclusion program and I understand that I can withdraw this consent at any time : 1182073
# Yes, I have read and consent to the terms and conditions* : on
# I authorize the use of my responses to these questions to be invited to Diversity Events and I understand that I can withdraw this consent at any time : 1182074
# Yes, I acknowledge that I have read and understand the policy.* : on
# Yes, I consent to sharing information with AllianceBernstein. : on
# Yes, I have read and consent to the terms and conditions. : on
# ///
# Address : : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Street Address : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address line 2 : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address line 1  : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address Line 1 : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address Line 2* : , B lane, DD Colony, Amberpet
# Address Line 1
# * : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address Line 1* : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# *
#  Address Line 1 : DAFFODILS APTS,DD COLNY
# Retype Email Address: * : anirudhkashibhatla@gmail.com
# Street Address (line 1)
#
# .
# Required : Flat 201, Daffod ils Appt, B61, B lane, DD Colony, Amberpet
# Contact number 2: : 07093615572
# Contact number 1: : 07093615572
# ///
# password : anirudhbzgh
#
#                     Password                 : q#Nf8Hz47KjsMPb
# Password : 1
# Access password : sample
# Password (optional): : 453
# Verify Password : Guruji$1
# Password (optional) : 1
# Choose Password: * : Guruji$1
# Retype Password: * : Guruji$1
# Verify New Password : Guruji$1
# confirmPassword : Guruji$1234567
# newPassword : Guruji$1234567
# Passwd : anirudhbzgh
# ///
# EducationDetails[0].university : NITWarangal
# EducationDetails[0].degree : B.tech
# EducationDetails[0].location : Warangal
# EducationDetails[0].branch : Metallurgy
# School or University* :
# Campus  : -
# School (Please use the full name, for example, University of Connecticut) : National Institute of Technology Warangal
# Undergraduate Institute Name37419 : National Institute of Technology Warangal
# Institution
#
# .
# Required : National Institute of Technology Warangal
# degree : BTECH
# Which institute/university did you graduate from? * : NITW
# Graduation : 1
# *
#  Degree : Bachelor
# ///
# Gender37412 : Male
# gender : 1
# Gender * : 92
# Marks37420 : 71.9
# What is your gender identity?
#
# .
# Required : com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14321__59452
#  Male : 22852622
#  Male : com.taleo.systemcomponent.question.entity.RegulationPossibleAnswer__4205011901
# GENDER / GÉNERO : 1
# Gender (as shown on your national ID)
#
# .
# Required : com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__12040__1
# Specialization37422 : Others
# r37c9a937bd9f410eb836e973fcf46531 : No
# ///
# Current employer : : FUTURES FIRST
# Employer
#   : Futures First
# Current Organisation : Futures First
# PLEASE_PROVIDE_THE_NAME_OF_YOUR_CURRENT_EMPLOYER_FOLLOWED_BY_A_LIST_OF_PAST_EMPLOYERS : Futures First
# Employer
#
# .
# Required :
# Current Salary * : 10,20,000
# I currently work here : on
# Please mention your current compensation? : 1020000
# Job Title
#   : Market Analyst
# Job Title and Rank
#
# .
# Required : Market Analyst
# Job Board
#
# .
# Required : 534324
# ///
# LinkedIn Profile* : https://www.linkedin.com/in/anirudhkashibhatla/
# LinkedIn Profile : https://www.linkedin.com/in/anirudhkashibhatla/
# LinkedIn Profile Link* : https://www.linkedin.com/in/anirudhkashibhatla/
# LinkedIn : https://www.linkedin.com/in/anirudhkashibhatla/
# Please provide the URL to your LinkedIn profile. : https://www.linkedin.com/in/anirudhkashibhatla/
# urls[LinkedIn] : https://www.linkedin.com/in/anirudhkashibhatla/
# Please supply the URL to your LinkedIn page : https://www.linkedin.com/in/anirudhkashibhatla/
# Influencer on LinkedIn
# Filter by Influencer on LinkedIn : influencer_on_linkedin
# Recruiters only
#
# Limited to people using LinkedIn Recruiter
#
# While we take steps not to show recruiters at your current company, we can’t guarantee complete privacy. : RECRUITERS
# profileStatus : true
# ///
# ctl00$pageContent$ctl02$ApplicationQuestions$desiredsalary : 800000inr
# ctl00$pageContent$ctl02$ApplicationQuestions$requiresponsorship : 0
# ctl00$pageContent$qset$ctl12$ch227516$227516 : -
# ctl00$pageContent$qset$ctl08$ch226355$226355 : 8
# ctl00$pageContent$qset$ctl10$ch226357$226357 : no
# ctl00$pageContent$qset$ctl07$ch226354$226354 : 10
# ctl00$pageContent$qset$ctl09$ch226356$226356 : 365398
# ctl00$pageContent$qset$ctl06$ch226353$226353 : 365393
# ctl00$pageContent$qset$ctl11$ch226358$226358 : -
# ctl00$pageContent$ResumeUpload1$uploadedresume : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# ///

# %%
clusterlabels = defaultdict(list)
for cluster in clusters:
  for i,index in enumerate(cluster):
    print(keys[index],":",data1[keys[index]])
    if i == len(cluster)-1:
      print("///")
# Out:
# workExperience-38--endDate-dateSectionMonth-input : 1
# workExperience-33--endDate-dateSectionMonth-input : 1
# workExperience-57--endDate-dateSectionMonth-input : 1
# workExperience-5--endDate-dateSectionMonth-input : 1
# workExperience-38--startDate-dateSectionMonth-input : 7
# workExperience-38--endDate-dateSectionYear-input : 2025
# workExperience-33--startDate-dateSectionMonth-input : 7
# workExperience-33--endDate-dateSectionYear-input : 2025
# workExperience-57--startDate-dateSectionMonth-input : 7
# workExperience-57--endDate-dateSectionYear-input : 2025
# workExperience-5--startDate-dateSectionMonth-input : 7
# workExperience-5--endDate-dateSectionYear-input : 2025
# workExperience-38--startDate-dateSectionYear-input : 2024
# workExperience-33--startDate-dateSectionYear-input : 2024
# input-28-dateSectionMonth-input : 7
# input-31-dateSectionMonth-input : 1
# input-27-dateSectionMonth-input : 1
# input-23-dateSectionMonth-input : 7
# workExperience-57--startDate-dateSectionYear-input : 2024
# input-24-dateSectionMonth-input : 7
# workExperience-5--startDate-dateSectionYear-input : 2024
# input-61-dateSectionMonth-input : 1
# input-28-dateSectionYear-input : 2024
# input-31-dateSectionYear-input : 2025
# input-27-dateSectionYear-input : 2025
# input-42-dateSectionYear-input : 2020
# input-35-dateSectionYear-input : 2024
# input-43-dateSectionYear-input : 2020
# End date month* : 6
# input-46-dateSectionYear-input : 2024
# input-21-dateSectionYear-input : 2024
# input-45-dateSectionYear-input : 2024
# input-32-dateSectionYear-input : 2020
# input-23-dateSectionYear-input : 2024
# input-61-dateSectionYear-input : 2025
# input-24-dateSectionYear-input : 2024
# input-125-dateSectionYear-input : 2025
# education-28--lastYearAttended-dateSectionYear-input : 2024
# input-77-dateSectionYear-input : 2020
# input-104-dateSectionYear-input : 2024
# input-80-dateSectionYear-input : 2024
# End date year* : 2023
# End date : 2024-06-01
# input-101-dateSectionYear-input : 2020
# education-47--lastYearAttended-dateSectionYear-input : 2024
# education-73--lastYearAttended-dateSectionYear-input : 2024
# education-28--firstYearAttended-dateSectionYear-input : 2020
# education-66--lastYearAttended-dateSectionYear-input : 2024
# End date * : 2025-01-10
# End Date * : 2025-01
# workExperience.months : 6
# education-93--lastYearAttended-dateSectionYear-input : 2024
# education-40--firstYearAttended-dateSectionYear-input : 2020
# education-73--firstYearAttended-dateSectionYear-input : 2020
# education-47--firstYearAttended-dateSectionYear-input : 2020
# education-66--firstYearAttended-dateSectionYear-input : 2020
# education-93--firstYearAttended-dateSectionYear-input : 2020
# Start date year* : 2020
# ///
# How many years of relevant work experience do you have?
# How many years of relevant work experience do you have?
#   : 6 months to 1 year
# How many years of work experience do you have with SQL? : 0
# How many years of work experience do you have with Recommender Systems? : 0
# How many years of work experience do you have with Communication? : 0
# How many years of work experience do you have with Databases? : 0
# How many years of work experience do you have with Machine Learning? : 0
# How many years of work experience do you have with Predictive Modeling? : 0
# How many years of work experience do you have with Data Analysis? : 1
# How many years of work experience do you have with Microsoft Excel? : 1
# How many years of work experience do you have with Deep Learning? : 0
# How many years of work experience do you have with Data Science? : 0
# How many years of Analyst experience do you currently have? : 1
# How many years of Business Analytics experience do you currently have? : 0.5
# How many years of work experience do you have with Snowflake? : 0
# How many years of work experience do you have with Tableau? : 0
# How many years of work experience do you have with Payment Systems? : 0
# How many years of work experience do you have with BigSQL? : 0
# Total Years of Experience : 0.5
# How many years of experience do you have working with investment banks?* : 0
# How many years of work experience do you have with Data Visualization? :
# How many years of experience do you have in Quantitative Finance?* : 0.5
# How many years of work experience do you have with Python (Programming Language)? : 0
# How many years of work experience do you have with Mixpanel? : 0
# Total Experience (in years) : 0.5
# How many years of Merchant management experience do you have ?
# How many years of Merchant management experience do you have ?
#   : No
# Total years of experience* : 0.5
# Total Years of Experience* : 0.5
# How many years of work experience do you have with SWIFT Payments? : 0
# How many years of work experience do you have with Generative AI? : 0
# How many years of work experience do you have with Pivot Tables? : 0
# How many years of professional experience do you have working with coding languages and their application in the field of finance/markets? * : 0.5
# How many years of work experience do you have with Medallion Architecture. : 0
# How many years of hands-on work experience with NetSuite? : 0
# How many years of Transaction monitoring experience do you hold?  : 0
# What is your Relevant Experience? : 0.5
# Years of Experience
#
# .
# Required : 0.5
# How many years of work experience do you have with Google Cloud Platform (GCP)? : 0
# What domain/industry experience you have  ( Manufacture / Automotive / Aerospace / Healthcare ) ? : Finance
# How many years of experience in Podtfolio Management? : 0.5
# How many years of experience in credit risk? : 0
# How many years of experience you in GenAI? : 0
# How many years experience as a Data Scientist : 0.5
# ///
# Email or mobile phone number : anirudhkashibhatla@gmail.com
# Email or phone : anirudhkashibhatla@gmail.com
# Email or Phone : anirudhkashibhatla@gmail.com
# Mobile Number
#
# .
# Required : 7093615572
# Email Address  : anirudhkashibhatla@gmail.com
# Email address : anirudhkashibhatla@gmail.com
# Email Address : anirudhkashibhatla@gmail.com
# email : anirudhkashibhatla@gmail.com
# Email : anirudhkashibhatla@gmail.com
# mobilePhone.number : 7093615572
# Enter mobile number : 7093615572
# Phone Number : 07093615572
# Phone number : +917093615572
# Mobile Phone number *
# This is a required field. : 7093615572
# phoneNumber : 070936 15572
# mobilenumber : 7093615572
# Email ID: : anirudhkashibhatla@gmail.com
# E-mail Address
#
# .
# Required : anirudhkashibhatla@gmail.com
# Preferred Contact Number
#
# .
# Required : 7093615572
# Cellular Number
#
# .
# Required : 7093615572
# Business email : anirudhkashibhatla@gmail.com
# Email address
# * : anirudhkashibhatla@gmail.com
# Email Address* : anirudhkashibhatla@gmail.com
# Email address* : anirudhkashibhatla@gmail.com
# Phone number* : 7093615572
# Phone Number* : 70936 15572
# Phone number
# * : 7093615572
# Phone number * : +917093615572
# Email ID37413 : anirudhkashibhatla@gmail.com
# Primary Phone Number
#
# .
# Required : 7093615572
# *
#  Email Address : anirudhkashibhatla@gmail.com
# Email Address: * : anirudhkashibhatla@gmail.com
# Email Address:* : anirudhkashibhatla@gmail.com
# Contact Number * : 7093615572
# Email* : anirudhkashibhatla@gmail.com
# Email * : anirudhkashibhatla@gmail.com
# Phone Number:* : 7093615572
# ///
# Last Name: * : Kashibhatla
# Last Name* : Kashibhatla
# Last name * : Kashibhatla
# First Name: * : Anirudh
# Last Name : Kashibhatla
# Last name : Kashibhatla
# Last name  : Kashibhatla
# First name: : Anirudh
# First Name* : Anirudh
# First name * : Anirudh
# Full Name* : Anirudh Kashibhatla
# Legal Last Name * : Kashibhatla
# First Name : Anirudh
# First name  : Anirudh
# *
#  Legal Last Name : Kashibhatla
# Given Name* : Anirudh
# Full name : Anirudh Kashibhatla
# Family Name
# * : Kashibhatla
# Family Name* : Kashibhatla
# Given Name(s)
# * : Anirudh
# Given Name(s)* : Anirudh
# Name : Anirudh Kashibhatla
# name : Anirudh Kashibhatla
# Your Name * : Anirudh Kashibhatla
# Last Name37411 : Kashibhatla
# Legal First Name * : Anirudh
# Legal first name * : Anirudh
# *
#  Legal First Name : Anirudh
# Family Name : Kashibhatla
# First Name37410 : Anirudh
# Type Your Full Name Here : Anirudh Kashibhatla
# Company name* : Futures First
# ///
# Location (City)* : Hyderabad
# City* : Hyderabad
# City
# * : Hyderabad
# *
#  City : Hyderabad
# City : Hyderabad
# City  : Hyderabad
# City
#   : Hyderabad
# City - Local* : Hyderabad
# City
# City : hydera
# City
# City
#   : hyderabad
# Location :
# location : Hyderabad, TG, India
# Current Location * : Hyderabad
# Resident city : : hYDERA
# Current Location?* : Hyderabad
# City
#
# .
# Required : Hyderabad
# City *
# This is a required field. : Hyderabad
# Current City : Hyderabad
# Preferred Location : Hyderabad
# Current Location : Hyderabad
# Country/Region of Residence:* : IN
# locationId : 6dfc051c-af6f-47e3-a186-093085d081d6
# Nearest Metropolitan City : com.taleo.systemcomponent.olf.entity.NetworkLocation__54300
# First Location Preference : 890901
# Second Location Preference : 11267698
# ExperienceDetails[0].location : Hyderabad
# Country * : 101
# *
#  Country : India
# Country/Region Code:* : IN
# ///
# What is your current ctc ? : 10.2
# What is your current CTC? : 1020000
# What is your Current CTC? : 10.2
# Whats your current CTC? : 1020000
# What is your current CTC? (INR) : 1020000
# What's your current CTC? (In Lakhs) : 10
# Current ctc? : 10.2
# Current CTC : 1020000
# What is your current annual CTC (in INR)? : 1020000
# What is your expected CTC? : 900000
# What is your Expected CTC? : 10.2
# What is your expected ctc? : 10.2
# Whats your expected CTC? : 1020000
# What is your current CTC in lakhs (for e.g. 6/ 9/ 11 etc)? : 10.2
# What is your current annual CTC, in Lakhs? : 10
# CTC: : 10.2
# What is your expected annual CTC (in INR)? : 1020000
# Expected ctc? : 10.2
# What is your expected annual CTC, in Lakhs? : 10
# Expected CTC: : 11
# What is your current compensation? : 1020000
# ///
# phone_code : +91
# phoneCountryCode : +91
# Country Phone Code* : India
# mobilePhone.countryCode : +91
# phoneCountry : IN
# Country / Territory Phone Code* : +917093615572
# International Dialling Code
#   : 7093615572
# Code : 47379623
# International Calling Code
# International Calling Code
#
# .
# Required : +91
# Cell Phone : 07093615572
# Phone : 07093615572
# phone : 7093615572
# Phone * : +917093615572
# Phone* : 7093615572
# Postal Code* : 500013
# Enter code : 002584
# countryCode : IN
# *Passcode: : 872554
# ///
# Are you serving notice period ?
# Are you serving notice period ?
#   : No
# What is your notice period?
# What is your notice period?
#   : Available to join immediately
# Notice period : 0
# Notice Period: : 0
# Notice period : : 0
# What is your Notice Period? : 0
# What is your notice period? : 0
# What is your notice period ? : 0
# Notice Period? : 0
# What is your Official Notice Period in days? : 0
# Please share your remaining Notice Period : 0
# Whats your notice period? : 0
# Please confirm your Notice Period (In Days) : 0
# What is your notice period (in days)? : 0
# What's your notice period? (In days)  : 0
# What is your notice period in days (e.g. 0/ 15/ 30/ 45 with 0 meaning immediate joiner) ? : 0
# Please mention your notice period to join? : 0
# Notice Period? * : 0
# ///
# cards[0c0bf90e-d4ac-454a-a268-701db5240562][field0] : Yes
# cards[b937576d-7460-40d2-ae79-762f158be671][field0] : Yes, by way of citizenship
# cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field0] : No
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field0] : Male
# cards[61edf07f-a0f9-41cd-8901-24d4cb79eb71][field0] : I Agree
# cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field0] : Between 9 LPA- 11LPA
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field4] : 1020000
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field7] : Linkedin
# cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field1] : Yes
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field5] : 1020000
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field1] : 0.5
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field3] : Yes
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field6] : 0
# cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field2] : No
# cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field1] : 0
# cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field2] : 10LPA
# Please provide your PAN Card Number
#
# .
# Required : JCSPK3366J
# ///
# uploadFile : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# Upload a file : C:\fakepath\Anirudh_Kashibhatla_Resume_.pdf
# Upload : C:\fakepath\Anirudh_Kashibhatla__Resume_.pdf
# Upload Media : C:\fakepath\b8f7fbf246fc1d7ec90ddba93883b6d2.gif
# file : C:\fakepath\Anirudh_Kashibhatla__Resume_.pdf
#  File : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# Attach File : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# resume-upload : C:\fakepath\Anirudh_Kashibhatla_Resume_.pdf
# UPLOAD RESUME : C:\fakepath\Anirudh_Kashibhatla_CV _.pdf
# Upload resume : C:\fakepath\Anirudh_Kashibhatla__Resume_.pdf
# Select the file to attach : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# Choose file : C:\fakepath\Anirudh_Kashibhatla_Resume_.pdf
# Upload resume : : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# file[] : C:\fakepath\Practical Statistics for Data Scientists_ 50+ Essential -- Peter Bruce; Andrew Bruce; Peter Gedeck -- 2, 2020 -- O'Reilly Media -- 9781492072911 -- 7cc7f5be94b748e6ecbe5eff5ff3ee97 -- Anna’s Archive.epub
# Choose Files : C:\fakepath\logo.png
# ///
# I acknowledge and understand the Privacy Policy, and I hereby consent to the Applicant Terms. : on
# I have read the terms of the privacy policy and consent to the processing of my information : on
# By applying, you hereby accept the data processing terms under the Privacy Policy and give consent to processing of the data as part of this job application. : 2
# *I have read and agree to the Employee Candidate Privacy Statement
#  : on
# I acknowledge and agree to Invesco's Recruitment Privacy Notice : on
# I have read the Privacy Notice : on
# I accept AMEX GBT's Recruitment Privacy Statement : on
# I consent to the Google APIs Terms of Service and the Gemini API Additional Terms of Service and acknowledge that I have read the Google Privacy Policy * : on
# I authorize the use of my responses to these questions to help with the Company's Diversity and Inclusion program and I understand that I can withdraw this consent at any time : 1182073
# Yes, I have read and consent to the terms and conditions* : on
# I authorize the use of my responses to these questions to be invited to Diversity Events and I understand that I can withdraw this consent at any time : 1182074
# Yes, I acknowledge that I have read and understand the policy.* : on
# Yes, I consent to sharing information with AllianceBernstein. : on
# Yes, I have read and consent to the terms and conditions. : on
# ///
# Address : : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Street Address : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address line 2 : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address line 1  : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address Line 1 : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address Line 2* : , B lane, DD Colony, Amberpet
# Address Line 1
# * : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# Address Line 1* : Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet
# *
#  Address Line 1 : DAFFODILS APTS,DD COLNY
# Retype Email Address: * : anirudhkashibhatla@gmail.com
# Street Address (line 1)
#
# .
# Required : Flat 201, Daffod ils Appt, B61, B lane, DD Colony, Amberpet
# Contact number 2: : 07093615572
# Contact number 1: : 07093615572
# ///
# password : anirudhbzgh
#
#                     Password                 : q#Nf8Hz47KjsMPb
# Password : 1
# Access password : sample
# Password (optional): : 453
# Verify Password : Guruji$1
# Password (optional) : 1
# Choose Password: * : Guruji$1
# Retype Password: * : Guruji$1
# Verify New Password : Guruji$1
# confirmPassword : Guruji$1234567
# newPassword : Guruji$1234567
# Passwd : anirudhbzgh
# ///
# EducationDetails[0].university : NITWarangal
# EducationDetails[0].degree : B.tech
# EducationDetails[0].location : Warangal
# EducationDetails[0].branch : Metallurgy
# School or University* :
# Campus  : -
# School (Please use the full name, for example, University of Connecticut) : National Institute of Technology Warangal
# Undergraduate Institute Name37419 : National Institute of Technology Warangal
# Institution
#
# .
# Required : National Institute of Technology Warangal
# degree : BTECH
# Which institute/university did you graduate from? * : NITW
# Graduation : 1
# *
#  Degree : Bachelor
# ///
# Gender37412 : Male
# gender : 1
# Gender * : 92
# Marks37420 : 71.9
# What is your gender identity?
#
# .
# Required : com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14321__59452
#  Male : 22852622
#  Male : com.taleo.systemcomponent.question.entity.RegulationPossibleAnswer__4205011901
# GENDER / GÉNERO : 1
# Gender (as shown on your national ID)
#
# .
# Required : com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__12040__1
# Specialization37422 : Others
# r37c9a937bd9f410eb836e973fcf46531 : No
# ///
# Current employer : : FUTURES FIRST
# Employer
#   : Futures First
# Current Organisation : Futures First
# PLEASE_PROVIDE_THE_NAME_OF_YOUR_CURRENT_EMPLOYER_FOLLOWED_BY_A_LIST_OF_PAST_EMPLOYERS : Futures First
# Employer
#
# .
# Required :
# Current Salary * : 10,20,000
# I currently work here : on
# Please mention your current compensation? : 1020000
# Job Title
#   : Market Analyst
# Job Title and Rank
#
# .
# Required : Market Analyst
# Job Board
#
# .
# Required : 534324
# ///
# LinkedIn Profile* : https://www.linkedin.com/in/anirudhkashibhatla/
# LinkedIn Profile : https://www.linkedin.com/in/anirudhkashibhatla/
# LinkedIn Profile Link* : https://www.linkedin.com/in/anirudhkashibhatla/
# LinkedIn : https://www.linkedin.com/in/anirudhkashibhatla/
# Please provide the URL to your LinkedIn profile. : https://www.linkedin.com/in/anirudhkashibhatla/
# urls[LinkedIn] : https://www.linkedin.com/in/anirudhkashibhatla/
# Please supply the URL to your LinkedIn page : https://www.linkedin.com/in/anirudhkashibhatla/
# Influencer on LinkedIn
# Filter by Influencer on LinkedIn : influencer_on_linkedin
# Recruiters only
#
# Limited to people using LinkedIn Recruiter
#
# While we take steps not to show recruiters at your current company, we can’t guarantee complete privacy. : RECRUITERS
# profileStatus : true
# ///
# ctl00$pageContent$ctl02$ApplicationQuestions$desiredsalary : 800000inr
# ctl00$pageContent$ctl02$ApplicationQuestions$requiresponsorship : 0
# ctl00$pageContent$qset$ctl12$ch227516$227516 : -
# ctl00$pageContent$qset$ctl08$ch226355$226355 : 8
# ctl00$pageContent$qset$ctl10$ch226357$226357 : no
# ctl00$pageContent$qset$ctl07$ch226354$226354 : 10
# ctl00$pageContent$qset$ctl09$ch226356$226356 : 365398
# ctl00$pageContent$qset$ctl06$ch226353$226353 : 365393
# ctl00$pageContent$qset$ctl11$ch226358$226358 : -
# ctl00$pageContent$ResumeUpload1$uploadedresume : C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf
# ///

# %%
embedding_store = {}
key_to_index = {}
for index, key in enumerate(keys):
    embedding = model.encode(key, show_progress_bar=False)
    embedding_store[index] = embedding  #
    key_to_index[key] = index
key_to_index
# Out:
# {'1': 0,
#  '2': 1,
#  '3': 2,
#  '4': 3,
#  '2024': 4,
#  '10715': 5,
#  '\n                    Excercises filter input\n                  ': 6,
#  '\n                    Filter field for certifications\n                  ': 7,
#  '\n                    Password                ': 8,
#  ' ': 9,
#  ' Choose not to reply': 10,
#  ' File': 11,
#  ' Male': 12,
#  ' No': 13,
#  ' Not applicable': 14,
#  ' Yes': 15,
#  ' Yes - I currently hold a PAN card.': 16,
#  '*\n\xa0Address Line 1': 17,
#  '*\n\xa0City': 18,
#  '*\n\xa0Country': 19,
#  '*\n\xa0Degree': 20,
#  '*\n\xa0Email Address': 21,
#  '*\n\xa0In the future, will you require sponsorship from Moody’s to work within the country to which you are applying?': 22,
#  '*\n\xa0Legal First Name': 23,
#  '*\n\xa0Legal Last Name': 24,
#  '*\n\xa0Primary Contact Number': 25,
#  '*I have read and agree to the Employee Candidate\xa0Privacy Statement\n': 26,
#  '*Passcode:': 27,
#  '11 - 13 LPA': 28,
#  '6months - 2years': 29,
#  ':1gi': 30,
#  ':r0:': 31,
#  ':r1:': 32,
#  'A Pandas Series': 33,
#  'Access password': 34,
#  'Access up‐to‐date course content': 35,
#  'Achievements\n\xa0': 36,
#  'Active backlogs37442': 37,
#  'Address :': 38,
#  'Address Line 1': 39,
#  'Address Line 1\n*': 40,
#  'Address Line 1 - Local*': 41,
#  'Address Line 1*': 42,
#  'Address Line 2*': 43,
#  'Address line 1 ': 44,
#  'Address line 2': 45,
#  'Alternate Email ID37414': 46,
#  'Anticipated Graduation Date\n\xa0': 47,
#  'Are hands on formulas like VLOOKUP, HLOOKUP, SUMIF, COUNTIF, INDEX-MATCH ?\nAre hands on formulas like VLOOKUP, HLOOKUP, SUMIF, COUNTIF, INDEX-MATCH ?\n ': 48,
#  'Are you a current or former employee or official of a State, Local, or Government Entity or political party, a member of a royal family, or a candidate for political office? *': 49,
#  'Are you a former employee (including as a co-op/intern) of GE Aerospace (formerly GE Aviation), the General Electric Company, or one of either company’s affiliates or subsidiaries?*': 50,
#  'Are you authorized to work permanently in location in which you are expressing an interest?': 51,
#  'Are you available immediately to join?\nAre you available immediately to join?\n ': 52,
#  'Are you comfortable working in a Hybrid mode in the following work timings(02:00 pm to 11:00 pm)?\nAre you comfortable working in a Hybrid mode in the following work timings(02:00 pm to 11:00 pm)?\n ': 53,
#  'Are you comfortable working in our Bengaluru office 3-4 days per week?': 54,
#  'Are you currently authorized to work in the Country to which you are applying to work? *': 55,
#  'Are you currently in Pune or willing to relocate to Pune for this role?\nAre you currently in Pune or willing to relocate to Pune for this role?\n ': 56,
#  'Are you currently or have you ever worked at MetLife or its affiliates, whether as an employee or non-employee worker (i.e., independent contractor, consultant, temporary worker, contingent worker, etc.)? *': 57,
#  'Are you open in relocating to Bangalore?\nAre you open in relocating to Bangalore?\n ': 58,
#  'Are you ready to relocate to Bangalore?\nAre you ready to relocate to Bangalore?\n ': 59,
#  'Are you serving notice period ?\nAre you serving notice period ?\n ': 60,
#  'Are you willing to work onsite in Bangalore?\nAre you willing to work onsite in Bangalore?\n ': 61,
#  'Area of Study': 62,
#  'Ascending': 63,
#  'Associate\nFilter by Associate': 64,
#  'Attach': 65,
#  'Attach File': 66,
#  'Available To Join (in days)': 67,
#  'Business email': 68,
#  'By applying, you hereby accept the data processing terms under the Privacy Policy and give consent to processing of the data as part of this job application.': 69,
#  'CGPA': 70,
#  'CTC:': 71,
#  'Campus ': 72,
#  'Can help you get a job\nFilter by Can help you get a job': 73,
#  'Can you meet this requirement? *': 74,
#  'CaptchaInputText': 75,
#  'Cell Phone': 76,
#  'Cellular Number\n\xa0\n.\xa0\nRequired': 77,
#  'Choose Files': 78,
#  'Choose Password: *': 79,
#  'Choose file': 80,
#  'City': 81,
#  'City\n*': 82,
#  'City\nCity': 83,
#  'City\nCity\n ': 84,
#  'City\n\xa0': 85,
#  'City\n\xa0\n.\xa0\nRequired': 86,
#  'City ': 87,
#  'City *\nThis is a required field.': 88,
#  'City - Local*': 89,
#  'City*': 90,
#  'City, state, or zip code': 91,
#  'Class X Marks (%)37417': 92,
#  'Class Xll Marks (%)37418': 93,
#  'Code': 94,
#  'Color': 95,
#  'Comments about the file': 96,
#  'Company': 97,
#  'Company name*': 98,
#  'Company*': 99,
#  'Competency Area :': 100,
#  'Consent!': 101,
#  'Contact Number *': 102,
#  'Contact number 1:': 103,
#  'Contact number 2:': 104,
#  'Contact people outside my network': 105,
#  'Country': 106,
#  'Country *': 107,
#  'Country *\nThis is a required field.': 108,
#  'Country / Territory Phone Code*': 109,
#  'Country Phone Code*': 110,
#  'Country/Region Code:*': 111,
#  'Country/Region of Residence:*': 112,
#  'Cover Letter': 113,
#  'Create an optimized resume with keyword insights': 114,
#  'Current CTC': 115,
#  'Current City': 116,
#  'Current Compensation? *': 117,
#  'Current Location': 118,
#  'Current Location *': 119,
#  'Current Location?*': 120,
#  'Current Organisation': 121,
#  'Current Salary *': 122,
#  'Current State': 123,
#  'Current ctc?': 124,
#  'Current employer :': 125,
#  'Current position? *': 126,
#  'Degree Type': 127,
#  'Description': 128,
#  "Do you get leave encashment? If 'Yes', please select the Maximum Number of Leaves you can encash from the below options\nDo you get leave encashment? If 'Yes', please select the Maximum Number of Leaves you can encash from the below options": 129,
#  "Do you have a disability (including physical or sensory)? Long term / mental health condition or are you neurodiverse?\nIf you have answered 'Yes' to the above question, share details below —\n\xa0\n.\xa0\nRequired": 130,
#  'Do you have a disability? *': 131,
#  'Do you have an outside business activity or financial interest of greater than 5% in any entity / organization? Outside business activities include any employment, participation, or significant financial interest in a business or organization outside of your (expected) primary position at MetLife. Some examples include: a second job, a business you own, holding a local government position, or holding a board position at a non-profit organization. *': 132,
#  'Do you have any reason to believe that an acceptance of an employment offer from MetLife or its affiliates would breach or violate any non-compete agreement, any non-solicitation agreement, or any other contract or agreement? *': 133,
#  'Do you have any relatives currently working within the HSBC Group?\n\xa0\n.\xa0\nRequired': 134,
#  'Do you have experience in Alteryx, VB and SQL?\nDo you have experience in Alteryx, VB and SQL?\n ': 135,
#  'Do you identify as Trans?\n\xa0\n.\xa0\nRequired': 136,
#  'E-mail Address\n\xa0\n.\xa0\nRequired': 137,
#  'Education Level\n\xa0\n.\xa0\nRequired': 138,
#  'EducationDetails[0].branch': 139,
#  'EducationDetails[0].degree': 140,
#  'EducationDetails[0].location': 141,
#  'EducationDetails[0].university': 142,
#  'Email': 143,
#  'Email *': 144,
#  'Email Address': 145,
#  'Email Address ': 146,
#  'Email Address*': 147,
#  'Email Address: *': 148,
#  'Email Address:*': 149,
#  'Email ID37413': 150,
#  'Email ID:': 151,
#  'Email address': 152,
#  'Email address\n*': 153,
#  'Email address*': 154,
#  'Email or Phone': 155,
#  'Email or mobile phone number': 156,
#  'Email or phone': 157,
#  'Email*': 158,
#  'Employer\n\xa0': 159,
#  'Employer\n\xa0\n.\xa0\nRequired': 160,
#  'End Date *': 161,
#  'End date': 162,
#  'End date *': 163,
#  'End date month*': 164,
#  'End date year*': 165,
#  'Enter ID (optional)': 166,
#  'Enter code': 167,
#  'Enter mobile number': 168,
#  'Entry level\nFilter by Entry level': 169,
#  'Exclude Inactive (FIDE rated only)': 170,
#  'Expected CTC:': 171,
#  'Expected Compensation? *': 172,
#  'Expected Salary *': 173,
#  'Expected ctc?': 174,
#  'ExperienceDetails[0].companyName': 175,
#  'ExperienceDetails[0].designation': 176,
#  'ExperienceDetails[0].location': 177,
#  'Explore a full library of courses': 178,
#  'Family Name': 179,
#  'Family Name\n*': 180,
#  'Family Name*': 181,
#  'Field of Study': 182,
#  'Field(s) of Study\n\xa0': 183,
#  'Filter by ID/IP': 184,
#  'Filter by ID/IP/Room': 185,
#  'Find jobs where I’d be a top applicant': 186,
#  'First Location Preference': 187,
#  'First Name': 188,
#  'First Name*': 189,
#  'First Name37410': 190,
#  'First Name: *': 191,
#  'First name ': 192,
#  'First name *': 193,
#  'First name:': 194,
#  'For purposes of determining whether there may be a conflict of interest please tell us, to the best of your knowledge, is any member of your family or household a current MetLife employee or member of its Board of Directors? (Examples include any child, stepchild, parent, stepparent, spouse, sibling, mother-in-law, father-in-law, son-in-law, daughter-in-law, brother-in-law, or sister-in-law, and any person sharing a household other than a tenant.) *': 195,
#  'From Device *': 196,
#  'Full Name*': 197,
#  'Full name': 198,
#  'GENDER / GÉNERO': 199,
#  'Gender (as shown on your national ID)\n\xa0\n.\xa0\nRequired': 200,
#  'Gender *': 201,
#  'Gender37412': 202,
#  'Github and Leetcode Profile (If Applicable)37632': 203,
#  'Given Name(s)\n*': 204,
#  'Given Name(s)*': 205,
#  'Given Name*': 206,
#  'Graduation': 207,
#  'Have you previously worked for Mr. Cooper, Nationstar Mortgage, Xome, Champion Mortgage, Centex Home Equity or a subsidiary or an affiliate?*': 208,
#  'Highest Education Level\n\xa0\n.\xa0\nRequired': 209,
#  'How Did You Hear About Us? *\nThis is a required field.': 210,
#  'How did you hear about this job?': 211,
#  'How did you hear about this position?\nHow did you hear about this position?\n ': 212,
#  'How did you hear about us?*': 213,
#  'How many total paid leaves you get in year in your current organization?\nHow many total paid leaves you get in year in your current organization?': 214,
#  'How many years experience as a Data Scientist': 215,
#  'How many years of Analyst experience do you currently have?': 216,
#  'How many years of Business Analytics experience do you currently have?': 217,
#  'How many years of Merchant management experience do you have ? \nHow many years of Merchant management experience do you have ? \n ': 218,
#  'How many years of Transaction monitoring experience do you hold? ': 219,
#  'How many years of experience do you have in Quantitative Finance?*': 220,
#  'How many years of experience do you have working with investment banks?*': 221,
#  'How many years of experience in Podtfolio Management?': 222,
#  'How many years of experience in credit risk?': 223,
#  'How many years of experience you in GenAI?': 224,
#  'How many years of hands-on work experience with NetSuite?': 225,
#  'How many years of professional experience do you have working with coding languages and their application in the field of finance/markets? *': 226,
#  'How many years of relevant work experience do you have?\nHow many years of relevant work experience do you have?\n ': 227,
#  'How many years of work experience do you have with BigSQL?': 228,
#  'How many years of work experience do you have with Communication?': 229,
#  'How many years of work experience do you have with Data Analysis?': 230,
#  'How many years of work experience do you have with Data Science?': 231,
#  'How many years of work experience do you have with Data Visualization?': 232,
#  'How many years of work experience do you have with Databases?': 233,
#  'How many years of work experience do you have with Deep Learning?': 234,
#  'How many years of work experience do you have with Generative AI?': 235,
#  'How many years of work experience do you have with Google Cloud Platform (GCP)?': 236,
#  'How many years of work experience do you have with Machine Learning?': 237,
#  'How many years of work experience do you have with Medallion Architecture.': 238,
#  'How many years of work experience do you have with Microsoft Excel?': 239,
#  'How many years of work experience do you have with Mixpanel?': 240,
#  'How many years of work experience do you have with Payment Systems?': 241,
#  'How many years of work experience do you have with Pivot Tables?': 242,
#  'How many years of work experience do you have with Predictive Modeling?': 243,
#  'How many years of work experience do you have with Python (Programming Language)?': 244,
#  'How many years of work experience do you have with Recommender Systems?': 245,
#  'How many years of work experience do you have with SQL?': 246,
#  'How many years of work experience do you have with SWIFT Payments?': 247,
#  'How many years of work experience do you have with Snowflake?': 248,
#  'How many years of work experience do you have with Tableau?': 249,
#  'How soon can you join us, in days?': 250,
#  'I Agree Terms & Conditions': 251,
#  'I accept': 252,
#  "I accept AMEX GBT's Recruitment Privacy Statement": 253,
#  "I acknowledge and agree to Invesco's Recruitment Privacy Notice": 254,
#  'I acknowledge and understand the Privacy Policy, and I hereby consent to the Applicant Terms.': 255,
#  'I agree to creating this account to allow me to apply for positions with this Organization.': 256,
#  'I am fluent in this language.': 257,
#  'I authorize the use of my responses to these questions to be invited to Diversity Events and I understand that I can withdraw this consent at any time': 258,
#  "I authorize the use of my responses to these questions to help with the Company's Diversity and Inclusion program and I understand that I can withdraw this consent at any time": 259,
#  'I consent to the Google APIs Terms of Service and the Gemini API Additional Terms of Service and acknowledge that I have read the Google Privacy Policy *': 260,
#  'I currently work here': 261,
#  'I have read the Privacy Notice': 262,
#  'I have read the terms of the privacy policy and consent to the processing of my information': 263,
#  'I hereby declare that I have not impersonated, or allowed myself to be impersonated by any person for the purposes of this assessment. All work submitted in this assessment will be my own work and does not involve plagiarism or teamwork.': 264,
#  'Immediately, I am actively applying': 265,
#  'India\n\xa0': 266,
#  'Influencer on LinkedIn\nFilter by Influencer on LinkedIn': 267,
#  'Institution\n\xa0\n.\xa0\nRequired': 268,
#  'International Calling Code\nInternational Calling Code\n\xa0\n.\xa0\nRequired': 269,
#  'International Dialling Code\n\xa0': 270,
#  'Internship\nFilter by Internship': 271,
#  'Is your Current location is Bangalore, Hyderabad Or Chennai\nIs your Current location is Bangalore, Hyderabad Or Chennai\n ': 272,
#  'Is your travel to the office, the company provided/ reimbursement basis?\nIs your travel to the office, the company provided/ reimbursement basis?': 273,
#  'I’d use Premium for my personal goals': 274,
#  'Job Board\n\xa0\n.\xa0\nRequired': 275,
#  'Job Function\n\xa0\n.\xa0\nRequired': 276,
#  'Job Title\n\xa0': 277,
#  'Job Title and Rank\n\xa0\n.\xa0\nRequired': 278,
#  'Job Title*': 279,
#  'Kindly enter National ID number': 280,
#  'Kindly specify the additional source details below for Employee Referral/ Job Portal/Consultant/Campus/Social media site': 281,
#  'Last Name': 282,
#  'Last Name*': 283,
#  'Last Name37411': 284,
#  'Last Name: *': 285,
#  'Last name': 286,
#  'Last name ': 287,
#  'Last name *': 288,
#  'Learn about hiring trends at companies of interest': 289,
#  'Legal First Name *': 290,
#  'Legal Last Name *': 291,
#  'Legal first name *': 292,
#  'Link 1': 293,
#  'LinkedIn': 294,
#  'LinkedIn Profile': 295,
#  'LinkedIn Profile Link*': 296,
#  'LinkedIn Profile*': 297,
#  'Local Family Name': 298,
#  'Local Given Name(s)': 299,
#  'Location': 300,
#  'Location (City)*': 301,
#  'Major': 302,
#  'Mark job as a top choice job': 303,
#  'Market Analyst at Futures First': 304,
#  'Marks37420': 305,
#  'Message Duration (s)': 306,
#  'Mobile Number\n\xa0\n.\xa0\nRequired': 307,
#  'Mobile Phone number *\nThis is a required field.': 308,
#  'Month': 309,
#  'Name': 310,
#  'Nearest Metropolitan City': 311,
#  'No': 312,
#  'No - Never Applied': 313,
#  'Not Covered': 314,
#  'Notice Period:': 315,
#  'Notice Period?': 316,
#  'Notice Period? *': 317,
#  'Notice period': 318,
#  'Notice period :': 319,
#  'Notification:': 320,
#  'Others': 321,
#  'Overall Result (GPA)': 322,
#  'PLEASE_LIST_YOUR_PRIMARY_AND_SECONDARY_TECHNICAL_DOMAIN_SKILLS': 323,
#  'PLEASE_PROVIDE_THE_NAME_OF_YOUR_CURRENT_EMPLOYER_FOLLOWED_BY_A_LIST_OF_PAST_EMPLOYERS': 324,
#  'Panel Data': 325,
#  'Passwd': 326,
#  'Password': 327,
#  'Password (optional)': 328,
#  'Password (optional):': 329,
#  'Phone': 330,
#  'Phone *': 331,
#  'Phone Device Type\n*': 332,
#  'Phone Device Type*': 333,
#  'Phone Number': 334,
#  'Phone Number*': 335,
#  'Phone Number:*': 336,
#  'Phone number': 337,
#  'Phone number\n*': 338,
#  'Phone number *': 339,
#  'Phone number*': 340,
#  'Phone*': 341,
#  'Place of Residence\n\xa0\n.\xa0\nRequired': 342,
#  'Please confirm your Notice Period (In Days)': 343,
#  'Please enter your WNS Employee ID (Request not to mention "u", just type the Employee ID)': 344,
#  'Please enter your full name:\n\xa0\n.\xa0\nRequired': 345,
#  'Please limit personal note to 300 characters.': 346,
#  'Please mention your current compensation?': 347,
#  'Please mention your notice period to join?': 348,
#  'Please provide the URL to your LinkedIn profile.': 349,
#  'Please provide your PAN Card Number\n\xa0\n.\xa0\nRequired': 350,
#  'Please select the highest level of education that you have achieved (or on track to achieve in the next 12 months). *': 351,
#  'Please share your current compensation (INR Annual in Lacs - Fixed + Variable)': 352,
#  'Please share your expected compensation (INR Annual in Lacs - Fixed + Variable)': 353,
#  'Please share your remaining Notice Period': 354,
#  'Please signify your acceptance by checking the box below.*': 355,
#  'Please supply the URL to your LinkedIn page': 356,
#  'Postal Code': 357,
#  'Postal Code*': 358,
#  'Postal code': 359,
#  'Postal/Zip code ': 360,
#  'Preferred Contact Number\n\xa0\n.\xa0\nRequired': 361,
#  'Preferred Location': 362,
#  'Prefix\n\xa0': 363,
#  'Price': 364,
#  'Primary Phone Number\n\xa0\n.\xa0\nRequired': 365,
#  'Proficiency in Coding Languages Known37627': 366,
#  'Pronouns': 367,
#  'Python and Statistics for Financial Analysis': 368,
#  'RACE/ETHNICITY / RAZA/ETNICIDAD': 369,
#  'Recruiters only\n\nLimited to people using LinkedIn Recruiter\n\nWhile we take steps not to show recruiters at your current company, we can’t guarantee complete privacy.': 370,
#  'Region': 371,
#  'Relevant Exp:': 372,
#  'Resident city :': 373,
#  'Resume': 374,
#  'Resume *': 375,
#  'Resume / CV *': 376,
#  'Resume37634': 377,
#  'Retype Email Address: *': 378,
#  'Retype Password: *': 379,
#  'Role Description': 380,
#  'Roles & Responsibilities': 381,
#  'Room ID': 382,
#  'Room ID:': 383,
#  'Room Life (seconds)': 384,
#  'School': 385,
#  'School (Please use the full name, for example, University of Connecticut)': 386,
#  'School or University*': 387,
#  'School*': 388,
#  'Second Location Preference': 389,
#  'See how I compare to other job applicants': 390,
#  'See who’s interested in my professional experience': 391,
#  'Select the file to attach': 392,
#  'Send an email notification whenever a new position matching this profile is posted.': 393,
#  'Skills': 394,
#  'Source Type\n.\xa0\nRequired': 395,
#  'Specialization (If others, please specify your specialization)37440': 396,
#  'Specialization37422': 397,
#  'Start date': 398,
#  'Start date *': 399,
#  'Start date year*': 400,
#  'State / Province': 401,
#  'State*': 402,
#  'State/Province': 403,
#  'Stay up to date on companies of interest': 404,
#  'Street Address': 405,
#  'Street Address (line 1)\n\xa0\n.\xa0\nRequired': 406,
#  'Take expert‐led courses': 407,
#  'Thickness': 408,
#  'This is a full-time onsite role - 6 days a week - work from office (WFO) based in HSR Layout, Bengaluru - are you OK with that?\nThis is a full-time onsite role - 6 days a week - work from office (WFO) based in HSR Layout, Bengaluru - are you OK with that?\n ': 409,
#  'TimeStamp': 410,
#  'Title*': 411,
#  'Title:': 412,
#  'To be eligible for hiring, you need to have work authorization / work permit / resident permit / work visa. Please confirm you are legally eligible to work in the country where this job is located. (Note: IBM will not provide sponsorship for any work permit/visa and/or residence permit required) *': 413,
#  'To develop my professional skills': 414,
#  'To find and contact new leads': 415,
#  'To grow my network, business, or reputation': 416,
#  'Total Experience (in years)': 417,
#  'Total Experience working as a Business Analyst?': 418,
#  'Total Experience:': 419,
#  'Total Years of Experience': 420,
#  'Total Years of Experience*': 421,
#  'Total years of experience*': 422,
#  'True': 423,
#  'Type Your Full Name Here': 424,
#  'Type a message...': 425,
#  'Type to Add Skills': 426,
#  'UAN': 427,
#  'UPLOAD RESUME': 428,
#  'Undergraduate Degree37421': 429,
#  'Undergraduate Institute Name37419': 430,
#  'Upload': 431,
#  'Upload Media': 432,
#  'Upload a file': 433,
#  'Upload resume': 434,
#  'Upload resume :': 435,
#  'UserName': 436,
#  'Verify Email Address': 437,
#  'Verify New Password': 438,
#  'Verify Password': 439,
#  'Veteran Status - Voluntary': 440,
#  'What domain/industry experience you have\xa0 ( Manufacture / Automotive / Aerospace / Healthcare ) ?': 441,
#  'What is your CGPA (Cumulative Grade Point Average)?*': 442,
#  'What is your Current CTC?': 443,
#  'What is your Ethnic Group?\n\xa0\n.\xa0\nRequired': 444,
#  'What is your Expected CTC?': 445,
#  'What is your Notice Period?': 446,
#  'What is your Official Notice Period in days?': 447,
#  'What is your Relevant Experience?': 448,
#  'What is your current CTC in lakhs (for e.g. 6/ 9/ 11 etc)?': 449,
#  'What is your current CTC?': 450,
#  'What is your current CTC? (INR)': 451,
#  'What is your current annual CTC (in INR)?': 452,
#  'What is your current annual CTC, in Lakhs?': 453,
#  'What is your current compensation?': 454,
#  'What is your current ctc ?': 455,
#  'What is your expected CTC?': 456,
#  'What is your expected annual CTC (in INR)?': 457,
#  'What is your expected annual CTC, in Lakhs?': 458,
#  'What is your expected compensation?': 459,
#  'What is your expected ctc?': 460,
#  'What is your experience ?': 461,
#  'What is your gender identity?\n\xa0\n.\xa0\nRequired': 462,
#  'What is your level of proficiency in English?\nWhat is your level of proficiency in English?\n ': 463,
#  'What is your notice period (in days)?': 464,
#  'What is your notice period ?': 465,
#  'What is your notice period in days (e.g. 0/ 15/ 30/ 45 with 0 meaning immediate joiner) ?': 466,
#  'What is your notice period?': 467,
#  'What is your notice period?\nWhat is your notice period?\n ': 468,
#  'What is your preferred location to work? (select all that apply to you)\nWhat is your preferred location to work? (select all that apply to you)\n ': 469,
#  'What percentage of time are you willing to travel? *': 470,
#  "What's their name or email address?": 471,
#  "What's their name or email address?*": 472,
#  "What's your current CTC? (In Lakhs)": 473,
#  "What's your notice period? (In days) ": 474,
#  'Whats your current CTC?': 475,
#  'Whats your expected CTC?': 476,
#  'Whats your notice period?': 477,
#  'Which institute/university did you graduate from? *': 478,
#  'Which major investment banks do you have experience working with?*': 479,
#  'Which of the following best describes your sexual orientation?\n\xa0\n.\xa0\nRequired': 480,
#  'Will you now or in the future require MetLife sponsorship or support for a work permit or visa in any capacity? *': 481,
#  'Will you require sponsorship?*': 482,
#  'Willing to relocate to Mumbai:\nWilling to relocate to Mumbai:\n ': 483,
#  'Year': 484,
#  'Year of Graduation': 485,
#  'Year of Passing37441': 486,
#  'Years of Experience\n\xa0\n.\xa0\nRequired': 487,
#  'Yes': 488,
#  'Yes, I consent to sharing information with AllianceBernstein.': 489,
#  'Yes, I have read and consent to the terms and conditions': 490,
#  'Yes, I have read and consent to the terms and conditions*': 491,
#  'Yes, I have read and consent to the terms and conditions.': 492,
#  'Your Name *': 493,
#  'Zip/Postal Code': 494,
#  'Zip/Postal code*': 495,
#  'aadhaarConsent.consentStatus': 496,
#  'attachCV': 497,
#  'attachment-input-ember1141': 498,
#  'attachment-input-ember1147': 499,
#  'attachment-input-ember1391': 500,
#  'attachment-input-ember2841': 501,
#  'captcha': 502,
#  'cards[0c0bf90e-d4ac-454a-a268-701db5240562][field0]': 503,
#  'cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field0]': 504,
#  'cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field1]': 505,
#  'cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field2]': 506,
#  'cards[61edf07f-a0f9-41cd-8901-24d4cb79eb71][field0]': 507,
#  'cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field0]': 508,
#  'cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field1]': 509,
#  'cards[b937576d-7460-40d2-ae79-762f158be671][field0]': 510,
#  'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field0]': 511,
#  'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field1]': 512,
#  'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field2]': 513,
#  'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field3]': 514,
#  'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field4]': 515,
#  'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field5]': 516,
#  'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field6]': 517,
#  'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field7]': 518,
#  'cat': 519,
#  'chat-input': 520,
#  'compulsoryDuration': 521,
#  'confirmPassword': 522,
#  'countryCode': 523,
#  'ctl00$pageContent$ResumeUpload1$uploadedresume': 524,
#  'ctl00$pageContent$ctl02$ApplicationQuestions$desiredsalary': 525,
#  'ctl00$pageContent$ctl02$ApplicationQuestions$requiresponsorship': 526,
#  'ctl00$pageContent$qset$ctl06$ch226353$226353': 527,
#  'ctl00$pageContent$qset$ctl07$ch226354$226354': 528,
#  'ctl00$pageContent$qset$ctl08$ch226355$226355': 529,
#  'ctl00$pageContent$qset$ctl09$ch226356$226356': 530,
#  'ctl00$pageContent$qset$ctl10$ch226357$226357': 531,
#  'ctl00$pageContent$qset$ctl11$ch226358$226358': 532,
#  'ctl00$pageContent$qset$ctl12$ch227516$227516': 533,
#  'custom1': 534,
#  'cut-type': 535,
#  'day': 536,
#  'degree': 537,
#  'doc-name': 538,
#  'edit-amount': 539,
#  'edit-date': 540,
#  'edit-key': 541,
#  'editor-current-shape': 542,
#  'education-28--firstYearAttended-dateSectionYear-input': 543,
#  'education-28--lastYearAttended-dateSectionYear-input': 544,
#  'education-40--firstYearAttended-dateSectionYear-input': 545,
#  'education-47--firstYearAttended-dateSectionYear-input': 546,
#  'education-47--lastYearAttended-dateSectionYear-input': 547,
#  'education-66--firstYearAttended-dateSectionYear-input': 548,
#  'education-66--lastYearAttended-dateSectionYear-input': 549,
#  'education-73--firstYearAttended-dateSectionYear-input': 550,
#  'education-73--lastYearAttended-dateSectionYear-input': 551,
#  'education-93--firstYearAttended-dateSectionYear-input': 552,
#  'education-93--lastYearAttended-dateSectionYear-input': 553,
#  'email': 554,
#  'exp-list-item-2': 555,
#  'exp-list-item-3': 556,
#  'expMonths': 557,
#  'expYears': 558,
#  'expense-amount': 559,
#  'expense-description': 560,
#  'file': 561,
#  'fileData1': 562,
#  'file[]': 563,
#  'fullWidth': 564,
#  'gender': 565,
#  'html5_1ik3o5vd617m34701csr15cck024': 566,
#  'html5_1ilvke9vb18af1e3178hefr1h4e4': 567,
#  'html5_1imi9h8vk1vgj14hlhm91c56nhb4': 568,
#  'income-amount': 569,
#  'income-source': 570,
#  'input-101-dateSectionYear-input': 571,
#  'input-104-dateSectionYear-input': 572,
#  'input-125-dateSectionYear-input': 573,
#  'input-21-dateSectionYear-input': 574,
#  'input-23-dateSectionMonth-input': 575,
#  'input-23-dateSectionYear-input': 576,
#  'input-24-dateSectionYear-input': 577,
#  'input-28-dateSectionMonth-input': 578,
#  'input-28-dateSectionYear-input': 579,
#  'input-31-dateSectionMonth-input': 580,
#  'input-31-dateSectionYear-input': 581,
#  'input-32-dateSectionYear-input': 582,
#  'input-35-dateSectionYear-input': 583,
#  'input-354': 584,
#  'input-42-dateSectionYear-input': 585,
#  'input-43-dateSectionYear-input': 586,
#  'input-45-dateSectionYear-input': 587,
#  'input-46-dateSectionYear-input': 588,
#  'input-61-dateSectionMonth-input': 589,
#  'input-61-dateSectionYear-input': 590,
#  'inputDefault': 591,
#  'ipzb1': 592,
#  'job_application[answers_attributes][0][text_value]': 593,
#  'job_application[demographic_answers][][answer_options][][answer_option_id]': 594,
#  'job_application[location]': 595,
#  'less than 6 months': 596,
#  'location': 597,
#  'locationId': 598,
#  'major': 599,
#  'mat-input-0': 600,
#  'mat-input-1': 601,
#  'mat-input-2': 602,
#  'mat-input-3': 603,
#  'mat-input-4': 604,
#  'mat-input-6': 605,
#  'memberDob': 606,
#  'memberKycDocNo': 607,
#  'memberName': 608,
#  'memberNewMobileNo': 609,
#  'memberOtp': 610,
#  'message': 611,
#  'messageInput': 612,
#  'messageRateLimit': 613,
#  'mobilePhone.countryCode': 614,
#  'mobilePhone.number': 615,
#  'mobilenumber': 616,
#  'month': 617,
#  'name': 618,
#  'newPassword': 619,
#  'oj-combobox-2|input': 620,
#  'org': 621,
#  'otc-1': 622,
#  'otc-2': 623,
#  'otc-3': 624,
#  'otc-4': 625,
#  'otc-5': 626,
#  'otc-6': 627,
#  'otpEnt.otp': 628,
#  'otpPinValue': 629,
#  'pass': 630,
#  'password': 631,
#  'phone': 632,
#  'phoneCountry': 633,
#  'phoneCountryCode': 634,
#  'phoneNumber': 635,
#  'phone_code': 636,
#  'photos': 637,
#  'previousWorker.No': 638,
#  'primaryQuestionnaire--97a56ab3ad0b101994f18d396b180003': 639,
#  'profileStatus': 640,
#  'pull_request[title]': 641,
#  'r37c9a937bd9f410eb836e973fcf46531': 642,
#  'r7eb3e444dcba4c7e8edff877bb920943': 643,
#  'rateType': 644,
#  'react-select-2-input': 645,
#  'react-select-3-input': 646,
#  'relevantExpMonths': 647,
#  'relevantExpYears': 648,
#  'resume': 649,
#  'resume-upload': 650,
#  's': 651,
#  'school': 652,
#  'seat-pool': 653,
#  'select_title': 654,
#  'smsOptIn': 655,
#  'standardFields.locationPreference.answer': 656,
#  'state': 657,
#  'stroke-width': 658,
#  'subject': 659,
#  'suggestor': 660,
#  'surveysResponses[a941fe7e-411c-49c9-bcd3-3ea360533bc4][responses][field0]': 661,
#  'termscondition': 662,
#  'text-color': 663,
#  'token-input-primarySkills': 664,
#  'token-input-secondarySkills': 665,
#  'uan': 666,
#  'uhiw1': 667,
#  'uploadFile': 668,
#  'urls[LinkedIn]': 669,
#  'userName': 670,
#  'wcav4': 671,
#  'workExperience-33--endDate-dateSectionMonth-input': 672,
#  'workExperience-33--endDate-dateSectionYear-input': 673,
#  'workExperience-33--startDate-dateSectionMonth-input': 674,
#  'workExperience-33--startDate-dateSectionYear-input': 675,
#  'workExperience-38--endDate-dateSectionMonth-input': 676,
#  'workExperience-38--endDate-dateSectionYear-input': 677,
#  'workExperience-38--startDate-dateSectionMonth-input': 678,
#  'workExperience-38--startDate-dateSectionYear-input': 679,
#  'workExperience-5--endDate-dateSectionMonth-input': 680,
#  'workExperience-5--endDate-dateSectionYear-input': 681,
#  'workExperience-5--startDate-dateSectionMonth-input': 682,
#  'workExperience-5--startDate-dateSectionYear-input': 683,
#  'workExperience-57--endDate-dateSectionMonth-input': 684,
#  'workExperience-57--endDate-dateSectionYear-input': 685,
#  'workExperience-57--startDate-dateSectionMonth-input': 686,
#  'workExperience-57--startDate-dateSectionYear-input': 687,
#  'workExperience.months': 688,
#  'yDssXfwe': 689,
#  'year': 690,
#  'youtube_url': 691,
#  '\xa0I acknowledge *': 692,
#  '\xa0I agree': 693,
#  '\xa0Male': 694,
#  '\xa0No': 695,
#  '\xa0No thanks, continue to apply': 696,
#  '\xa0Yes': 697,
#  'What is your desired annual gross base salary in your local currency?': 698,
#  'Yes, I acknowledge that I have read and understand the policy.*': 699,
#  'input-24-dateSectionMonth-input': 700,
#  'input-27-dateSectionMonth-input': 701,
#  'input-27-dateSectionYear-input': 702,
#  'input-77-dateSectionYear-input': 703,
#  'input-80-dateSectionYear-input': 704}

# %%
def similarity_list(value):
  arr = []
  for i in range(len(value)):
        for j in range(i + 1, len(value)):
            if value[i] in key_to_index and value[j] in key_to_index:
                embedding1 = embedding_store[key_to_index[value[i]]]
                embedding2 = embedding_store[key_to_index[value[j]]]
                similarity_score = util.pytorch_cos_sim(embedding1, embedding2).item()
                arr.append(similarity_score)
            #else:
                #print(f"Key not found in key_to_index: {value[i]} or {value[j]}")
  return arr

# %%
def similarity_list_value(sentences):
    embeddings = model.encode(sentences, show_progress_bar=False)
    similarity_matrix = cosine_similarity(embeddings)
    upper_triangle = similarity_matrix[np.triu_indices(len(sentences), k=1)]
    mean = np.mean(upper_triangle).item()
    std = np.std(upper_triangle).item()

    return [mean, std]

# %%
def evaluate(value):
    cos = similarity_list(value)
    if not cos:
        return []
    mean, std = np.mean(cos), np.std(cos)
    print("mean :",mean,std)
    q1, q3 = np.percentile(cos, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    print("asd",lower_bound,upper_bound)
    high_confidence= len([s for s in cos if s > upper_bound])
    low_confidence= len([s for s in cos if s < lower_bound])
    print (high_confidence,low_confidence)

    return [mean, std, high_confidence, low_confidence]

# %%
clustersim = []
for cluster in clusters:
  values =[data1[keys[x]] for x in cluster]
  #print(values)
  sim = similarity_list_value(values)
  print(sim)
  clustersim.append(sim)
#clustersim
# Out:
# [0.582302987575531, 0.2989356815814972]
# [0.6873805522918701, 0.28398260474205017]
# [0.5635839700698853, 0.39076825976371765]
# [0.6392470598220825, 0.322564959526062]
# [0.5325607061386108, 0.379258930683136]
# [0.5795403122901917, 0.2801763415336609]
# [0.44075509905815125, 0.27279332280158997]
# [0.8288729786872864, 0.32846710085868835]
# [0.25827038288116455, 0.22819258272647858]
# [0.7874010801315308, 0.250448077917099]
# [0.7494634389877319, 0.31915539503097534]
# [0.5746560096740723, 0.35079237818717957]
# [0.3812091648578644, 0.2901642918586731]
# [0.2890462577342987, 0.20658743381500244]
# [0.24445900321006775, 0.20426629483699799]
# [0.27826350927352905, 0.29009196162223816]
# [0.5650362372398376, 0.4216561019420624]
# [0.2902366518974304, 0.2149137258529663]

# %%
keys_by_value = defaultdict(list)
for key, value in data1.items():
    keys_by_value[value].append(key)
keys_list = list(keys_by_value.keys())
keys_list
# Out:
# ['9',
#  '3',
#  '6',
#  '4',
#  '57',
#  '',
#  'q#Nf8Hz47KjsMPb',
#  'discuss particle physics and create a model that stimulates 3d particle interactions and dynamics in c++ using any  librarireas needed along with the math',
#  'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__17976',
#  'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf',
#  'com.taleo.systemcomponent.question.entity.RegulationPossibleAnswer__4205011901',
#  'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19098',
#  'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19325',
#  'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19337',
#  'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__46057',
#  'DAFFODILS APTS,DD COLNY',
#  'Hyderabad',
#  'India',
#  'Bachelor',
#  'anirudhkashibhatla@gmail.com',
#  'No',
#  'Anirudh',
#  'Kashibhatla',
#  '+917093615572',
#  'on',
#  '872554',
#  '201132701002',
#  '1',
#  'meenakumarimanyam@gmail.com',
#  'xFRuDg',
#  '2',
#  'sample',
#  'At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. This ownership of real-time analytics has strengthened my ability to deliver actionable insights in fast-paced environments.\nActively traded a range of ICE,CME,EURONEXT commodity futures, including SRW ,HRW,yEBM, Corn, canola,\nyECO, and soybean oil.\n• Monitored market dynamics using open-source data focusing on supply-demand trends, geopolitical developments,\nand weather-driven factors influencing agricultural prices.\n• Developed and implemented more than 100 hedging strategies, optimized diversification using covariance analysis,\nand applied risk budgeting to mitigate risk and preserve portfolio stability during market volatility.\n• Applied lead-lag relationships, intermarket strategies, and arbitrage opportunities using tools like correlation\nanalysis and statistical tests to identify profitable trades',
#  'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet',
#  ', B lane, DD Colony, Amberpet',
#  'sr922003@student.nitw.ac.in',
#  'Yes',
#  '38',
#  'yes',
#  '37',
#  '468925',
#  'Engineering',
#  'ascending',
#  '0',
#  '7.19',
#  '10.2',
#  '-',
#  'can_help_you_get_a_job',
#  'SEUEW',
#  '07093615572',
#  '7093615572',
#  'C:\\fakepath\\logo.png',
#  'Guruji$1',
#  'C:\\fakepath\\Anirudh_Kashibhatla_Resume_.pdf',
#  'hydera',
#  'hyderabad',
#  'Hyderabad ',
#  'india',
#  '93',
#  '77.3',
#  '47379623',
#  '#ff0000',
#  'Resume',
#  'Futures First',
#  'Technologies',
#  'IN',
#  '101',
#  'C:\\fakepath\\Anirudh_Kashibhatla_CV_.pdf',
#  '1020000',
#  '10,20,000',
#  'Telangana ',
#  'FUTURES FIRST',
#  '- Developed and deployed trading,hedging strategies on 8 Commodity futures products across CME, ICE , Euronext exchanges.\n- Worked with open-source data and in-house data using quantitative and fundamental analysis to create risk - adjusted forecasts.\n- Worked on ',
#  'No Leave Encashment',
#  'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14322__59370',
#  '127',
#  'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14680__2',
#  'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14320__59464',
#  'Metallurgy',
#  'B.tech',
#  'Warangal',
#  'NITWarangal',
#  '2025-01',
#  '2024-06-01',
#  '2025-01-10',
#  '2023',
#  '234',
#  '002584',
#  '11',
#  '1100000',
#  'Market Analyst',
#  'Kashibhatla ',
#  'Metallurgical Engineering',
#  '890901',
#  'Anirudh ',
#  'Anirudh Kashibhatla',
#  'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__12040__1',
#  '92',
#  'Male',
#  'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__10248__3',
#  '36',
#  'LINKEDIN',
#  'Job Portal',
#  'Referral',
#  '0-10',
#  '0.5',
#  '6 months to 1 year',
#  '7',
#  '1182074',
#  '1182073',
#  'ACTIVELY_SEEKING',
#  'influencer_on_linkedin',
#  'National Institute of Technology Warangal',
#  '+91',
#  '7093615572 ',
#  'Own Vehicle (non-reimbursable)',
#  '534324',
#  '417894747994',
#  'linkedin',
#  'https://www.linkedin.com/in/anirudhkashibhatla/',
#  '71.9',
#  'com.taleo.systemcomponent.olf.entity.NetworkLocation__54300',
#  'false',
#  '1636107552',
#  'Java,Python,C++,SQL,React,MongoDB,Pandas',
#  'anirudhbzgh',
#  '453',
#  'Mobile',
#  '70936 15572',
#  'India ',
#  'Data Lemur is great!',
#  'JCSPK3366J',
#  '20',
#  '500013',
#  'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__10080__3',
#  '100000',
#  'Python',
#  'RECRUITERS',
#  'hYDERA',
#  'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf',
#  'At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. ',
#  '10000',
#  'other',
#  'OTHER',
#  '11267698',
#  'data science',
#  '8',
#  'Others',
#  '2020-08-13',
#  '2024-07-22',
#  '2020',
#  'TG',
#  'IND-TS',
#  '40',
#  'Flat 201, Daffod ils Appt, B61, B lane, DD Colony, Amberpet',
#  '1742915866553',
#  'Mr.',
#  '102103896453',
#  'C:\\fakepath\\Anirudh_Kashibhatla_CV _.pdf',
#  'B.Tech',
#  'C:\\fakepath\\b8f7fbf246fc1d7ec90ddba93883b6d2.gif',
#  'ffispl/3857',
#  'string:Not a Veteran',
#  'Finance',
#  'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__12120__67570',
#  '10',
#  '900000',
#  'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14321__59452',
#  'Professional',
#  'Available to join immediately',
#  'Bangalore',
#  '579',
#  'aditya.rama-kamalanath-polepeddi@michelin.com',
#  'NITW',
#  'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14360__59514',
#  'NO',
#  '2025',
#  '2024',
#  'Y',
#  'C:\\fakepath\\Anirudh_Kashibhatla_Sde.pdf',
#  '24ASB',
#  'Between 9 LPA- 11LPA',
#  '10LPA',
#  'I Agree',
#  'Yes, by way of citizenship',
#  'Linkedin',
#  'op',
#  'list steps to start mongdb server backend',
#  '0453',
#  'Guruji$1234567',
#  '800000inr',
#  '365393',
#  '365398',
#  'no',
#  'adv',
#  'BTECH',
#  'Untitled0.jsx',
#  '2025-02-14',
#  'food-nuts',
#  '5273',
#  '53yuiyu',
#  'C:\\fakepath\\1722027181207.jpeg',
#  "C:\\fakepath\\Practical Statistics for Data Scientists_ 50+ Essential -- Peter Bruce; Andrew Bruce; Peter Gedeck -- 2, 2020 -- O'Reilly Media -- 9781492072911 -- 7cc7f5be94b748e6ecbe5eff5ff3ee97 -- Anna’s Archive.epub",
#  'FDGDFRGDFG',
#  'C:\\fakepath\\ESLII_print10.pdf',
#  'C:\\fakepath\\Anirudh_Cover_Letter_JPMG (2).pdf',
#  '-135353',
#  'fggf',
#  'https://wsdc.nitw.ac.in/home/',
#  'algeria',
#  '7533',
#  'Hyderabad, TG, India',
#  '6dfc051c-af6f-47e3-a186-093085d081d6',
#  '2078',
#  '9030077232',
#  'give me this code in chat',
#  '08/07/2000',
#  'Sairam Anirudh Kashibhatla',
#  '248879',
#  'import React, { useState, useEffect, useRef } from \'react\';\nimport Peer from \'peerjs\';\nimport \'./styles.css\'; // Assuming you\'ll create a styles.css file with the provided CSS\n\nfunction App() {\n  const [messages, setMessages] = useState();\n  const [filterInput, setFilterInput] = useState(\'\');\n  const [messageInput, setMessageInput] = useState(\'\');\n  const [idInput, setIdInput] = useState(\'\');\n  const [durationInput, setDurationInput] = useState(\'\');\n  const [mediaInput, setMediaInput] = useState(null);\n  const [joinRoomIdInput, setJoinRoomIdInput] = useState(\'\');\n  const [isCreateRoomModalOpen, setIsCreateRoomModalOpen] = useState(false);\n  const [roomId, setRoomId] = useState(\'\');\n  const [roomPassword, setRoomPassword] = useState(\'\');\n  const [roomDuration, setRoomDuration] = useState(60);\n  const [roomErrorMessage, setRoomErrorMessage] = useState(\'\');\n  const [activeTab, setActiveTab] = useState(\'basic\');\n  const [layoutOption, setLayoutOption] = useState(\'default\');\n  const [upvoteOption, setUpvoteOption] = useState(\'disabled\');\n  const [messageRateLimit, setMessageRateLimit] = useState(0);\n  const [compulsoryDuration, setCompulsoryDuration] = useState(0);\n  const [createdRooms, setCreatedRooms] = useState({});\n  const messageTimestamps = useRef();\n  const uploadedMedia = useRef(null);\n  const peer = useRef(null);\n  const conn = useRef(null);\n  const myId = useRef(null);\n  const connectedRoomId = useRef(null);\n\n  useEffect(() => {\n    initPeer();\n    // Load any existing rooms from local storage on component mount\n    const storedRooms = {};\n    for (let i = 0; i < localStorage.length; i++) {\n      const key = localStorage.key(i);\n      if (key) {\n        try {\n          storedRooms[key] = JSON.parse(localStorage.getItem(key));\n        } catch (e) {\n          console.error(\'Error parsing room data from local storage\', e);\n        }\n      }\n    }\n    setCreatedRooms(storedRooms);\n  },);\n\n  const generateId = () => {\n    return Math.random().toString(36).substring(2, 15) + Math.random().toString(36).substring(2, 15);\n  };\n\n  const handleMediaInputChange = (event) => {\n    const file = event.target.files[0];\n    const validImageTypes = [\'image/gif\', \'image/jpeg\', \'image/png\'];\n    const validVideoTypes = [\'video/mp4\', \'video/webm\'];\n\n    if (file) {\n      if (validImageTypes.includes(file.type)) {\n        uploadedMedia.current = {\n          type: \'image\',\n          url: URL.createObjectURL(file),\n        };\n      } else if (validVideoTypes.includes(file.type)) {\n        uploadedMedia.current = {\n          type: \'video\',\n          url: URL.createObjectURL(file),\n        };\n      } else {\n        alert(\'Invalid file type. Please upload an image or video.\');\n        setMediaInput(null);\n        uploadedMedia.current = null;\n      }\n      setMediaInput(file);\n    }\n  };\n\n  const postMessage = () => {\n    const messageTextValue = messageInput;\n    const messageIdValue = idInput.trim();\n    const durationValue = durationInput;\n    if (!messageTextValue && !uploadedMedia.current) return;\n\n    const newMessage = {\n      id: messageIdValue || generateId(),\n      text: messageTextValue,\n      duration: durationValue,\n      timestamp: new Date().toLocaleTimeString(),\n      left: `${Math.random() * (window.innerWidth - 320)}px`,\n      top: `${Math.random() * (window.innerHeight - 120)}px`,\n      media: uploadedMedia.current,\n    };\n\n    // Apply layout\n    if (createdRooms[connectedRoomId.current]?.layout === \'grid\') {\n      const gridX = Math.floor(Math.random() * 5) * 320;\n      const gridY = Math.floor(Math.random() * 3) * 200;\n      newMessage.left = `${gridX}px`;\n      newMessage.top = `${gridY}px`;\n    }\n\n    setMessages((prevMessages) => [...prevMessages, newMessage]);\n    setMessageInput(\'\');\n    setIdInput(\'\');\n    setDurationInput(\'\');\n    setMediaInput(null);\n    uplo ...
#  'hgh',
#  'waranga',
#  '5',
#  '183104',
#  '032840',
#  '070936 15572',
#  'true',
#  'eda',
#  'HOURLY',
#  'gn',
#  'g',
#  'Telangana',
#  'Request for referral',
#  'DATA MODE',
#  '[1,2,3,4,5,6]',
#  'STATISTIC',
#  'DATA ',
#  '2000',
#  'https://www.youtube.com/watch?v=vA0-3hm5q2Y',
#  '1043734',
#  '22852622',
#  '1182096',
#  '800000']

# %%
keys_by_value
# Out:
# defaultdict(list,
#             {'9': ['1', 'Thickness'],
#              '3': ['2',
#               '2024',
#               'Associate\nFilter by Associate',
#               'otc-1',
#               'otc-2',
#               'otc-6'],
#              '6': ['3',
#               'Education Level\n\xa0\n.\xa0\nRequired',
#               'End date month*',
#               'expMonths',
#               'relevantExpMonths',
#               'workExperience.months'],
#              '4': ['4',
#               'Others',
#               'RACE/ETHNICITY / RAZA/ETNICIDAD',
#               'less than 6 months',
#               'otc-3'],
#              '57': ['10715'],
#              '': ['\n                    Excercises filter input\n                  ',
#               '\n                    Filter field for certifications\n                  ',
#               ':r0:',
#               'Company*',
#               'Employer\n\xa0\n.\xa0\nRequired',
#               'Filter by ID/IP',
#               'How many years of work experience do you have with Data Visualization?',
#               'Job Function\n\xa0\n.\xa0\nRequired',
#               'Job Title*',
#               'Location',
#               'Role Description',
#               'School or University*',
#               'ipzb1',
#               'uhiw1',
#               'wcav4'],
#              'q#Nf8Hz47KjsMPb': ['\n                    Password                '],
#              'discuss particle physics and create a model that stimulates 3d particle interactions and dynamics in c++ using any  librarireas needed along with the math': [' '],
#              'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__17976': [' Choose not to reply'],
#              'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf': [' File',
#               'Attach',
#               'Attach File',
#               'From Device *',
#               'Select the file to attach',
#               'Upload resume :',
#               'attachment-input-ember1391',
#               'ctl00$pageContent$ResumeUpload1$uploadedresume',
#               'html5_1imi9h8vk1vgj14hlhm91c56nhb4',
#               'resume',
#               'uploadFile'],
#              'com.taleo.systemcomponent.question.entity.RegulationPossibleAnswer__4205011901': [' Male'],
#              'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19098': [' No'],
#              'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19325': [' Not applicable'],
#              'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19337': [' Yes'],
#              'com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__46057': [' Yes - I currently hold a PAN card.'],
#              'DAFFODILS APTS,DD COLNY': ['*\n\xa0Address Line 1'],
#              'Hyderabad': ['*\n\xa0City',
#               'City',
#               'City\n*',
#               'City\n\xa0',
#               'City ',
#               'City *\nThis is a required field.',
#               'City - Local*',
#               'City*',
#               'Current Location',
#               'Current Location *',
#               'Current Location?*',
#               'ExperienceDetails[0].location',
#               'Location (City)*',
#               'Preferred Location',
#               'job_application[location]',
#               'react-select-2-input',
#               'react-select-3-input'],
#              'India': ['*\n\xa0Country', 'Country Phone Code*'],
#              'Bachelor': ['*\n\xa0Degree'],
#              'anirudhkashibhatla@gmail.com': ['*\n\xa0Email Address',
#               'Business email',
#               'E-mail Address\n\xa0\n.\xa0\nRequired',
#               'Email',
#               'Email *',
#               'Email Address',
#               'Email Address ',
#               'Email Address*',
#               'Email Address: *',
#               'Email Address:*',
#               'Email ID37413',
#               'Email ID:',
#               'Email address',
#               'Email address\n*',
#               'Email address*',
#               'Email or Phone',
#               'Email or mobile phone number',
#               'Email or phone',
#               'Email*',
#               'Retype Email Address: *',
#               'Verify Email Address',
#               'email'],
#              'No': ['*\n\xa0In the future, will you require sponsorship from Moody’s to work within the country to which you are applying?',
#               'Active backlogs37442',
#               'Are you a former employee (including as a co-op/intern) of GE Aerospace (formerly GE Aviation), the General Electric Company, or one of either company’s affiliates or subsidiaries?*',
#               'Are you serving notice period ?\nAre you serving notice period ?\n ',
#               'Have you previously worked for Mr. Cooper, Nationstar Mortgage, Xome, Champion Mortgage, Centex Home Equity or a subsidiary or an affiliate?*',
#               'How many years of Merchant management experience do you have ? \nHow many years of Merchant management experience do you have ? \n ',
#               'cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field0]',
#               'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field2]',
#               'custom1',
#               'previousWorker.No',
#               'r37c9a937bd9f410eb836e973fcf46531'],
#              'Anirudh': ['*\n\xa0Legal First Name',
#               'First Name',
#               'First Name*',
#               'First Name37410',
#               'First Name: *',
#               'First name ',
#               'First name:',
#               'Given Name(s)\n*',
#               'Given Name*',
#               'Legal First Name *',
#               'Legal first name *',
#               'Pronouns'],
#              'Kashibhatla': ['*\n\xa0Legal Last Name',
#               'Family Name',
#               'Family Name\n*',
#               'Last Name',
#               'Last Name*',
#               'Last Name37411',
#               'Last Name: *',
#               'Last name',
#               'Last name ',
#               'Legal Last Name *'],
#              '+917093615572': ['*\n\xa0Primary Contact Number',
#               'Country / Territory Phone Code*',
#               'Phone *',
#               'Phone number',
#               'Phone number *'],
#              'on': ['*I have read and agree to the Employee Candidate\xa0Privacy Statement\n',
#               'Access up‐to‐date course content',
#               'Anticipated Graduation Date\n\xa0',
#               'Consent!',
#               'Contact people outside my network',
#               'Create an optimized resume with keyword insights',
#               'Exclude Inactive (FIDE rated only)',
#               'Explore a full library of courses',
#               'Find jobs where I’d be a top applicant',
#               'I Agree Terms & Conditions',
#               'I accept',
#               "I accept AMEX GBT's Recruitment Privacy Statement",
#               "I acknowledge and agree to Invesco's Recruitment Privacy Notice",
#               'I acknowledge and understand the Privacy Policy, and I hereby consent to the Applicant Terms.',
#               'I agree to creating this account to allow me to apply for positions with this Organization.',
#               'I am fluent in this language.',
#               'I consent to the Google APIs Terms of Service and the Gemini API Additional Terms of Service and acknowledge that I have read the Google Privacy Policy *',
#               'I currently work here',
#               'I have read the Privacy Notice',
#               'I have read the terms of the privacy policy and consent to the processing of my information',
#               'I hereby declare that I have not impersonated, or allowed myself to be impersonated by any person for the purposes of this assessment. All work submitted in this assessment will be my own work and does not involve plagiarism or teamwork.',
#               'I’d use Premium for my personal goals',
#               'Learn about hiring trends at companies of interest',
#               'Mark job as a top choice job',
#               'Market Analyst at Futures First',
#               'Not Covered',
#               'Notification:',
#               'Please signify your acceptance by checking the box below.*',
#               'Python and Statistics for Financial Analysis',
#               'See how I compare to other job applicants',
#               'See who’s interested in my professional experience',
#               'Send an email notification whenever a new position matching this profile is posted.',
#               'Stay up to date on companies of interest',
#               'Take expert‐led courses',
#               'To develop my professional skills',
#               'To find and contact new leads',
#               'To grow my network, business, or reputation',
#               'Yes',
#               'Yes, I consent to sharing information with AllianceBernstein.',
#               'Yes, I have read and consent to the terms and conditions',
#               'Yes, I have read and consent to the terms and conditions*',
#               'Yes, I have read and consent to the terms and conditions.',
#               'editor-current-shape',
#               'exp-list-item-2',
#               'exp-list-item-3',
#               'stroke-width',
#               'termscondition',
#               'yDssXfwe',
#               'Yes, I acknowledge that I have read and understand the policy.*'],
#              '872554': ['*Passcode:'],
#              '201132701002': ['11 - 13 LPA'],
#              '1': ['6months - 2years',
#               'GENDER / GÉNERO',
#               'Graduation',
#               'How many years of Analyst experience do you currently have?',
#               'How many years of work experience do you have with Data Analysis?',
#               'How many years of work experience do you have with Microsoft Excel?',
#               'India\n\xa0',
#               'Internship\nFilter by Internship',
#               'Password',
#               'Password (optional)',
#               'Room ID',
#               'edit-amount',
#               'gender',
#               'input-31-dateSectionMonth-input',
#               'input-61-dateSectionMonth-input',
#               'workExperience-33--endDate-dateSectionMonth-input',
#               'workExperience-38--endDate-dateSectionMonth-input',
#               'workExperience-5--endDate-dateSectionMonth-input',
#               'workExperience-57--endDate-dateSectionMonth-input',
#               '\xa0I acknowledge *',
#               'input-27-dateSectionMonth-input'],
#              'meenakumarimanyam@gmail.com': [':1gi'],
#              'xFRuDg': [':r1:'],
#              '2': ['A Pandas Series',
#               'By applying, you hereby accept the data processing terms under the Privacy Policy and give consent to processing of the data as part of this job application.',
#               'Entry level\nFilter by Entry level',
#               'Filter by ID/IP/Room'],
#              'sample': ['Access password'],
#              'At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. This ownership of real-time analytics has strengthened my ability to deliver actionable insights in fast-paced environments.\nActively traded a range of ICE,CME,EURONEXT commodity futures, including SRW ,HRW,yEBM, Corn, canola,\nyECO, and soybean oil.\n• Monitored market dynamics using open-source data focusing on supply-demand trends, geopolitical developments,\nand weather-driven factors influencing agricultural prices.\n• Developed and implemented more than 100 hedging strategies, optimized diversification using covariance analysis,\nand applied risk budgeting to mitigate risk and preserve portfolio stability during market volatility.\n• Applied lead-lag relationships, intermarket strategies, and arbitrage opportunities using tools like correlation\nanalysis and statistical tests to identify profitable trades': ['Achievements\n\xa0'],
#              'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet': ['Address :',
#               'Address Line 1',
#               'Address Line 1\n*',
#               'Address Line 1 - Local*',
#               'Address Line 1*',
#               'Address line 1 ',
#               'Address line 2',
#               'Street Address'],
#              ', B lane, DD Colony, Amberpet': ['Address Line 2*'],
#              'sr922003@student.nitw.ac.in': ['Alternate Email ID37414'],
#              'Yes': ['Are hands on formulas like VLOOKUP, HLOOKUP, SUMIF, COUNTIF, INDEX-MATCH ?\nAre hands on formulas like VLOOKUP, HLOOKUP, SUMIF, COUNTIF, INDEX-MATCH ?\n ',
#               'Are you available immediately to join?\nAre you available immediately to join?\n ',
#               'Are you comfortable working in a Hybrid mode in the following work timings(02:00 pm to 11:00 pm)?\nAre you comfortable working in a Hybrid mode in the following work timings(02:00 pm to 11:00 pm)?\n ',
#               'Are you currently in Pune or willing to relocate to Pune for this role?\nAre you currently in Pune or willing to relocate to Pune for this role?\n ',
#               'Are you open in relocating to Bangalore?\nAre you open in relocating to Bangalore?\n ',
#               'Are you ready to relocate to Bangalore?\nAre you ready to relocate to Bangalore?\n ',
#               'Are you willing to work onsite in Bangalore?\nAre you willing to work onsite in Bangalore?\n ',
#               'Do you have experience in Alteryx, VB and SQL?\nDo you have experience in Alteryx, VB and SQL?\n ',
#               'Is your Current location is Bangalore, Hyderabad Or Chennai\nIs your Current location is Bangalore, Hyderabad Or Chennai\n ',
#               'This is a full-time onsite role - 6 days a week - work from office (WFO) based in HSR Layout, Bengaluru - are you OK with that?\nThis is a full-time onsite role - 6 days a week - work from office (WFO) based in HSR Layout, Bengaluru - are you OK with that?\n ',
#               'Willing to relocate to Mumbai:\nWilling to relocate to Mumbai:\n ',
#               'cards[0c0bf90e-d4ac-454a-a268-701db5240562][field0]',
#               'cards[abfd920f-89e8-4dc7-a723-d150f928e7a6][field1]',
#               'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field3]',
#               'r7eb3e444dcba4c7e8edff877bb920943'],
#              '38': ['Are you a current or former employee or official of a State, Local, or Government Entity or political party, a member of a royal family, or a candidate for political office? *',
#               'Current position? *',
#               'Do you have an outside business activity or financial interest of greater than 5% in any entity / organization? Outside business activities include any employment, participation, or significant financial interest in a business or organization outside of your (expected) primary position at MetLife. Some examples include: a second job, a business you own, holding a local government position, or holding a board position at a non-profit organization. *',
#               'Do you have any reason to believe that an acceptance of an employment offer from MetLife or its affiliates would breach or violate any non-compete agreement, any non-solicitation agreement, or any other contract or agreement? *',
#               'For purposes of determining whether there may be a conflict of interest please tell us, to the best of your knowledge, is any member of your family or household a current MetLife employee or member of its Board of Directors? (Examples include any child, stepchild, parent, stepparent, spouse, sibling, mother-in-law, father-in-law, son-in-law, daughter-in-law, brother-in-law, or sister-in-law, and any person sharing a household other than a tenant.) *',
#               'Will you now or in the future require MetLife sponsorship or support for a work permit or visa in any capacity? *',
#               '\xa0No thanks, continue to apply'],
#              'yes': ['Are you authorized to work permanently in location in which you are expressing an interest?',
#               'Are you comfortable working in our Bengaluru office 3-4 days per week?'],
#              '37': ['Are you currently authorized to work in the Country to which you are applying to work? *',
#               'Can you meet this requirement? *',
#               'To be eligible for hiring, you need to have work authorization / work permit / resident permit / work visa. Please confirm you are legally eligible to work in the country where this job is located. (Note: IBM will not provide sponsorship for any work permit/visa and/or residence permit required) *',
#               '\xa0Yes'],
#              '468925': ['Are you currently or have you ever worked at MetLife or its affiliates, whether as an employee or non-employee worker (i.e., independent contractor, consultant, temporary worker, contingent worker, etc.)? *'],
#              'Engineering': ['Area of Study', 'Degree Type'],
#              'ascending': ['Ascending'],
#              '0': ['Available To Join (in days)',
#               'How many years of Transaction monitoring experience do you hold? ',
#               'How many years of experience do you have working with investment banks?*',
#               'How many years of experience in credit risk?',
#               'How many years of experience you in GenAI?',
#               'How many years of hands-on work experience with NetSuite?',
#               'How many years of work experience do you have with BigSQL?',
#               'How many years of work experience do you have with Communication?',
#               'How many years of work experience do you have with Data Science?',
#               'How many years of work experience do you have with Databases?',
#               'How many years of work experience do you have with Deep Learning?',
#               'How many years of work experience do you have with Generative AI?',
#               'How many years of work experience do you have with Google Cloud Platform (GCP)?',
#               'How many years of work experience do you have with Machine Learning?',
#               'How many years of work experience do you have with Medallion Architecture.',
#               'How many years of work experience do you have with Mixpanel?',
#               'How many years of work experience do you have with Payment Systems?',
#               'How many years of work experience do you have with Pivot Tables?',
#               'How many years of work experience do you have with Predictive Modeling?',
#               'How many years of work experience do you have with Python (Programming Language)?',
#               'How many years of work experience do you have with Recommender Systems?',
#               'How many years of work experience do you have with SQL?',
#               'How many years of work experience do you have with SWIFT Payments?',
#               'How many years of work experience do you have with Snowflake?',
#               'How many years of work experience do you have with Tableau?',
#               'Month',
#               'Notice Period:',
#               'Notice Period?',
#               'Notice Period? *',
#               'Notice period',
#               'Notice period :',
#               'Panel Data',
#               'Please confirm your Notice Period (In Days)',
#               'Please enter your WNS Employee ID (Request not to mention "u", just type the Employee ID)',
#               'Please mention your notice period to join?',
#               'Please share your remaining Notice Period',
#               'True',
#               'What is your Notice Period?',
#               'What is your Official Notice Period in days?',
#               'What is your notice period (in days)?',
#               'What is your notice period ?',
#               'What is your notice period in days (e.g. 0/ 15/ 30/ 45 with 0 meaning immediate joiner) ?',
#               'What is your notice period?',
#               "What's your notice period? (In days) ",
#               'Whats your notice period?',
#               'Which major investment banks do you have experience working with?*',
#               'cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field1]',
#               'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field6]',
#               'ctl00$pageContent$ctl02$ApplicationQuestions$requiresponsorship',
#               'expYears',
#               'relevantExpYears'],
#              '7.19': ['CGPA',
#               'Overall Result (GPA)',
#               'What is your CGPA (Cumulative Grade Point Average)?*'],
#              '10.2': ['CTC:',
#               'Current ctc?',
#               'Expected ctc?',
#               'What is your Current CTC?',
#               'What is your Expected CTC?',
#               'What is your current CTC in lakhs (for e.g. 6/ 9/ 11 etc)?',
#               'What is your current ctc ?',
#               'What is your expected ctc?'],
#              '-': ['Campus ',
#               'Github and Leetcode Profile (If Applicable)37632',
#               'ctl00$pageContent$qset$ctl11$ch226358$226358',
#               'ctl00$pageContent$qset$ctl12$ch227516$227516'],
#              'can_help_you_get_a_job': ['Can help you get a job\nFilter by Can help you get a job'],
#              'SEUEW': ['CaptchaInputText'],
#              '07093615572': ['Cell Phone',
#               'Contact number 1:',
#               'Contact number 2:',
#               'Phone',
#               'Phone Number'],
#              '7093615572': ['Cellular Number\n\xa0\n.\xa0\nRequired',
#               'Contact Number *',
#               'Enter mobile number',
#               'Mobile Number\n\xa0\n.\xa0\nRequired',
#               'Mobile Phone number *\nThis is a required field.',
#               'Phone Number:*',
#               'Phone number\n*',
#               'Phone number*',
#               'Phone*',
#               'Preferred Contact Number\n\xa0\n.\xa0\nRequired',
#               'Primary Phone Number\n\xa0\n.\xa0\nRequired',
#               'mat-input-0',
#               'mobilePhone.number',
#               'mobilenumber',
#               'phone'],
#              'C:\\fakepath\\logo.png': ['Choose Files'],
#              'Guruji$1': ['Choose Password: *',
#               'Retype Password: *',
#               'Verify New Password',
#               'Verify Password'],
#              'C:\\fakepath\\Anirudh_Kashibhatla_Resume_.pdf': ['Choose file',
#               'Resume / CV *',
#               'Upload a file',
#               'resume-upload'],
#              'hydera': ['City\nCity'],
#              'hyderabad': ['City\nCity\n '],
#              'Hyderabad ': ['City\n\xa0\n.\xa0\nRequired', 'Current City'],
#              'india': ['City, state, or zip code'],
#              '93': ['Class X Marks (%)37417'],
#              '77.3': ['Class Xll Marks (%)37418'],
#              '47379623': ['Code'],
#              '#ff0000': ['Color'],
#              'Resume': ['Comments about the file'],
#              'Futures First': ['Company',
#               'Company name*',
#               'Current Organisation',
#               'Employer\n\xa0',
#               'ExperienceDetails[0].companyName',
#               'PLEASE_PROVIDE_THE_NAME_OF_YOUR_CURRENT_EMPLOYER_FOLLOWED_BY_A_LIST_OF_PAST_EMPLOYERS',
#               'org'],
#              'Technologies': ['Competency Area :'],
#              'IN': ['Country',
#               'Country *\nThis is a required field.',
#               'Country/Region Code:*',
#               'Country/Region of Residence:*',
#               'countryCode',
#               'phoneCountry'],
#              '101': ['Country *'],
#              'C:\\fakepath\\Anirudh_Kashibhatla_CV_.pdf': ['Cover Letter',
#               'Resume *'],
#              '1020000': ['Current CTC',
#               'Current Compensation? *',
#               'Please mention your current compensation?',
#               'Please share your current compensation (INR Annual in Lacs - Fixed + Variable)',
#               'Please share your expected compensation (INR Annual in Lacs - Fixed + Variable)',
#               'What is your current CTC?',
#               'What is your current CTC? (INR)',
#               'What is your current annual CTC (in INR)?',
#               'What is your current compensation?',
#               'What is your expected annual CTC (in INR)?',
#               'What is your expected compensation?',
#               'Whats your current CTC?',
#               'Whats your expected CTC?',
#               'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field4]',
#               'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field5]',
#               'primaryQuestionnaire--97a56ab3ad0b101994f18d396b180003'],
#              '10,20,000': ['Current Salary *', 'Expected Salary *'],
#              'Telangana ': ['Current State'],
#              'FUTURES FIRST': ['Current employer :'],
#              '- Developed and deployed trading,hedging strategies on 8 Commodity futures products across CME, ICE , Euronext exchanges.\n- Worked with open-source data and in-house data using quantitative and fundamental analysis to create risk - adjusted forecasts.\n- Worked on ': ['Description'],
#              'No Leave Encashment': ["Do you get leave encashment? If 'Yes', please select the Maximum Number of Leaves you can encash from the below options\nDo you get leave encashment? If 'Yes', please select the Maximum Number of Leaves you can encash from the below options"],
#              'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14322__59370': ["Do you have a disability (including physical or sensory)? Long term / mental health condition or are you neurodiverse?\nIf you have answered 'Yes' to the above question, share details below —\n\xa0\n.\xa0\nRequired"],
#              '127': ['Do you have a disability? *'],
#              'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14680__2': ['Do you have any relatives currently working within the HSBC Group?\n\xa0\n.\xa0\nRequired'],
#              'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14320__59464': ['Do you identify as Trans?\n\xa0\n.\xa0\nRequired'],
#              'Metallurgy': ['EducationDetails[0].branch'],
#              'B.tech': ['EducationDetails[0].degree'],
#              'Warangal': ['EducationDetails[0].location'],
#              'NITWarangal': ['EducationDetails[0].university'],
#              '2025-01': ['End Date *'],
#              '2024-06-01': ['End date'],
#              '2025-01-10': ['End date *'],
#              '2023': ['End date year*'],
#              '234': ['Enter ID (optional)',
#               'Message Duration (s)',
#               'Type a message...'],
#              '002584': ['Enter code'],
#              '11': ['Expected CTC:'],
#              '1100000': ['Expected Compensation? *'],
#              'Market Analyst': ['ExperienceDetails[0].designation',
#               'Job Title\n\xa0',
#               'Job Title and Rank\n\xa0\n.\xa0\nRequired',
#               'Title*'],
#              'Kashibhatla ': ['Family Name*',
#               'Last name *',
#               'Local Family Name'],
#              'Metallurgical Engineering': ['Field of Study',
#               'Field(s) of Study\n\xa0',
#               'Major',
#               'Specialization (If others, please specify your specialization)37440',
#               'major'],
#              '890901': ['First Location Preference'],
#              'Anirudh ': ['First name *',
#               'Given Name(s)*',
#               'Local Given Name(s)'],
#              'Anirudh Kashibhatla': ['Full Name*',
#               'Full name',
#               'Name',
#               'Please enter your full name:\n\xa0\n.\xa0\nRequired',
#               'Type Your Full Name Here',
#               'Your Name *',
#               'name'],
#              'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__12040__1': ['Gender (as shown on your national ID)\n\xa0\n.\xa0\nRequired'],
#              '92': ['Gender *'],
#              'Male': ['Gender37412',
#               'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field0]',
#               'surveysResponses[a941fe7e-411c-49c9-bcd3-3ea360533bc4][responses][field0]'],
#              'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__10248__3': ['Highest Education Level\n\xa0\n.\xa0\nRequired'],
#              '36': ['How Did You Hear About Us? *\nThis is a required field.'],
#              'LINKEDIN': ['How did you hear about this job?'],
#              'Job Portal': ['How did you hear about this position?\nHow did you hear about this position?\n '],
#              'Referral': ['How did you hear about us?*'],
#              '0-10': ['How many total paid leaves you get in year in your current organization?\nHow many total paid leaves you get in year in your current organization?'],
#              '0.5': ['How many years experience as a Data Scientist',
#               'How many years of Business Analytics experience do you currently have?',
#               'How many years of experience do you have in Quantitative Finance?*',
#               'How many years of experience in Podtfolio Management?',
#               'How many years of professional experience do you have working with coding languages and their application in the field of finance/markets? *',
#               'Relevant Exp:',
#               'Total Experience (in years)',
#               'Total Experience working as a Business Analyst?',
#               'Total Experience:',
#               'Total Years of Experience',
#               'Total Years of Experience*',
#               'Total years of experience*',
#               'What is your Relevant Experience?',
#               'What is your experience ?',
#               'Years of Experience\n\xa0\n.\xa0\nRequired',
#               'cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field1]'],
#              '6 months to 1 year': ['How many years of relevant work experience do you have?\nHow many years of relevant work experience do you have?\n '],
#              '7': ['How soon can you join us, in days?',
#               'input-23-dateSectionMonth-input',
#               'input-28-dateSectionMonth-input',
#               'workExperience-33--startDate-dateSectionMonth-input',
#               'workExperience-38--startDate-dateSectionMonth-input',
#               'workExperience-5--startDate-dateSectionMonth-input',
#               'workExperience-57--startDate-dateSectionMonth-input',
#               'input-24-dateSectionMonth-input'],
#              '1182074': ['I authorize the use of my responses to these questions to be invited to Diversity Events and I understand that I can withdraw this consent at any time'],
#              '1182073': ["I authorize the use of my responses to these questions to help with the Company's Diversity and Inclusion program and I understand that I can withdraw this consent at any time"],
#              'ACTIVELY_SEEKING': ['Immediately, I am actively applying'],
#              'influencer_on_linkedin': ['Influencer on LinkedIn\nFilter by Influencer on LinkedIn'],
#              'National Institute of Technology Warangal': ['Institution\n\xa0\n.\xa0\nRequired',
#               'School (Please use the full name, for example, University of Connecticut)',
#               'Undergraduate Institute Name37419'],
#              '+91': ['International Calling Code\nInternational Calling Code\n\xa0\n.\xa0\nRequired',
#               'mobilePhone.countryCode',
#               'phoneCountryCode',
#               'phone_code'],
#              '7093615572 ': ['International Dialling Code\n\xa0'],
#              'Own Vehicle (non-reimbursable)': ['Is your travel to the office, the company provided/ reimbursement basis?\nIs your travel to the office, the company provided/ reimbursement basis?'],
#              '534324': ['Job Board\n\xa0\n.\xa0\nRequired'],
#              '417894747994': ['Kindly enter National ID number',
#               'memberKycDocNo'],
#              'linkedin': ['Kindly specify the additional source details below for Employee Referral/ Job Portal/Consultant/Campus/Social media site'],
#              'https://www.linkedin.com/in/anirudhkashibhatla/': ['Link 1',
#               'LinkedIn',
#               'LinkedIn Profile',
#               'LinkedIn Profile Link*',
#               'LinkedIn Profile*',
#               'Please provide the URL to your LinkedIn profile.',
#               'Please supply the URL to your LinkedIn page',
#               'job_application[answers_attributes][0][text_value]',
#               'urls[LinkedIn]'],
#              '71.9': ['Marks37420'],
#              'com.taleo.systemcomponent.olf.entity.NetworkLocation__54300': ['Nearest Metropolitan City',
#               'Region'],
#              'false': ['No'],
#              '1636107552': ['No - Never Applied'],
#              'Java,Python,C++,SQL,React,MongoDB,Pandas': ['PLEASE_LIST_YOUR_PRIMARY_AND_SECONDARY_TECHNICAL_DOMAIN_SKILLS'],
#              'anirudhbzgh': ['Passwd', 'pass', 'password'],
#              '453': ['Password (optional):', 'Room ID:'],
#              'Mobile': ['Phone Device Type\n*', 'Phone Device Type*'],
#              '70936 15572': ['Phone Number*'],
#              'India ': ['Place of Residence\n\xa0\n.\xa0\nRequired'],
#              'Data Lemur is great!': ['Please limit personal note to 300 characters.'],
#              'JCSPK3366J': ['Please provide your PAN Card Number\n\xa0\n.\xa0\nRequired'],
#              '20': ['Please select the highest level of education that you have achieved (or on track to achieve in the next 12 months). *'],
#              '500013': ['Postal Code',
#               'Postal Code*',
#               'Postal code',
#               'Postal/Zip code ',
#               'Zip/Postal Code',
#               'Zip/Postal code*'],
#              'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__10080__3': ['Prefix\n\xa0'],
#              '100000': ['Price'],
#              'Python': ['Proficiency in Coding Languages Known37627'],
#              'RECRUITERS': ['Recruiters only\n\nLimited to people using LinkedIn Recruiter\n\nWhile we take steps not to show recruiters at your current company, we can’t guarantee complete privacy.'],
#              'hYDERA': ['Resident city :'],
#              'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf': ['Resume',
#               'Resume37634',
#               'Upload',
#               'Upload resume',
#               'attachment-input-ember1147',
#               'attachment-input-ember2841',
#               'file'],
#              'At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. ': ['Roles & Responsibilities'],
#              '10000': ['Room Life (seconds)'],
#              'other': ['School'],
#              'OTHER': ['School*'],
#              '11267698': ['Second Location Preference'],
#              'data science': ['Skills', 'Type to Add Skills'],
#              '8': ['Source Type\n.\xa0\nRequired',
#               'ctl00$pageContent$qset$ctl08$ch226355$226355',
#               'day',
#               'month',
#               'otc-5'],
#              'Others': ['Specialization37422'],
#              '2020-08-13': ['Start date'],
#              '2024-07-22': ['Start date *'],
#              '2020': ['Start date year*',
#               'education-28--firstYearAttended-dateSectionYear-input',
#               'education-40--firstYearAttended-dateSectionYear-input',
#               'education-47--firstYearAttended-dateSectionYear-input',
#               'education-66--firstYearAttended-dateSectionYear-input',
#               'education-73--firstYearAttended-dateSectionYear-input',
#               'education-93--firstYearAttended-dateSectionYear-input',
#               'input-101-dateSectionYear-input',
#               'input-32-dateSectionYear-input',
#               'input-42-dateSectionYear-input',
#               'input-43-dateSectionYear-input',
#               'input-77-dateSectionYear-input'],
#              'TG': ['State / Province'],
#              'IND-TS': ['State*'],
#              '40': ['State/Province'],
#              'Flat 201, Daffod ils Appt, B61, B lane, DD Colony, Amberpet': ['Street Address (line 1)\n\xa0\n.\xa0\nRequired'],
#              '1742915866553': ['TimeStamp'],
#              'Mr.': ['Title:'],
#              '102103896453': ['UAN', 'uan', 'userName'],
#              'C:\\fakepath\\Anirudh_Kashibhatla_CV _.pdf': ['UPLOAD RESUME',
#               'attachment-input-ember1141'],
#              'B.Tech': ['Undergraduate Degree37421'],
#              'C:\\fakepath\\b8f7fbf246fc1d7ec90ddba93883b6d2.gif': ['Upload Media'],
#              'ffispl/3857': ['UserName'],
#              'string:Not a Veteran': ['Veteran Status - Voluntary'],
#              'Finance': ['What domain/industry experience you have\xa0 ( Manufacture / Automotive / Aerospace / Healthcare ) ?'],
#              'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__12120__67570': ['What is your Ethnic Group?\n\xa0\n.\xa0\nRequired'],
#              '10': ['What is your current annual CTC, in Lakhs?',
#               'What is your expected annual CTC, in Lakhs?',
#               "What's your current CTC? (In Lakhs)",
#               'ctl00$pageContent$qset$ctl07$ch226354$226354'],
#              '900000': ['What is your expected CTC?'],
#              'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14321__59452': ['What is your gender identity?\n\xa0\n.\xa0\nRequired'],
#              'Professional': ['What is your level of proficiency in English?\nWhat is your level of proficiency in English?\n '],
#              'Available to join immediately': ['What is your notice period?\nWhat is your notice period?\n '],
#              'Bangalore': ['What is your preferred location to work? (select all that apply to you)\nWhat is your preferred location to work? (select all that apply to you)\n ',
#               'standardFields.locationPreference.answer'],
#              '579': ['What percentage of time are you willing to travel? *'],
#              'aditya.rama-kamalanath-polepeddi@michelin.com': ["What's their name or email address?",
#               "What's their name or email address?*"],
#              'NITW': ['Which institute/university did you graduate from? *',
#               'school'],
#              'com.taleo.functionalcomponent.talent.entity.common.selection.UDSElement__14360__59514': ['Which of the following best describes your sexual orientation?\n\xa0\n.\xa0\nRequired'],
#              'NO': ['Will you require sponsorship?*'],
#              '2025': ['Year',
#               'input-125-dateSectionYear-input',
#               'input-31-dateSectionYear-input',
#               'input-61-dateSectionYear-input',
#               'workExperience-33--endDate-dateSectionYear-input',
#               'workExperience-38--endDate-dateSectionYear-input',
#               'workExperience-5--endDate-dateSectionYear-input',
#               'workExperience-57--endDate-dateSectionYear-input',
#               'input-27-dateSectionYear-input'],
#              '2024': ['Year of Graduation',
#               'Year of Passing37441',
#               'education-28--lastYearAttended-dateSectionYear-input',
#               'education-47--lastYearAttended-dateSectionYear-input',
#               'education-66--lastYearAttended-dateSectionYear-input',
#               'education-73--lastYearAttended-dateSectionYear-input',
#               'education-93--lastYearAttended-dateSectionYear-input',
#               'input-104-dateSectionYear-input',
#               'input-21-dateSectionYear-input',
#               'input-23-dateSectionYear-input',
#               'input-24-dateSectionYear-input',
#               'input-28-dateSectionYear-input',
#               'input-35-dateSectionYear-input',
#               'input-45-dateSectionYear-input',
#               'input-46-dateSectionYear-input',
#               'workExperience-33--startDate-dateSectionYear-input',
#               'workExperience-38--startDate-dateSectionYear-input',
#               'workExperience-5--startDate-dateSectionYear-input',
#               'workExperience-57--startDate-dateSectionYear-input',
#               'input-80-dateSectionYear-input'],
#              'Y': ['aadhaarConsent.consentStatus'],
#              'C:\\fakepath\\Anirudh_Kashibhatla_Sde.pdf': ['attachCV'],
#              '24ASB': ['captcha'],
#              'Between 9 LPA- 11LPA': ['cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field0]'],
#              '10LPA': ['cards[28507a19-3a38-4ea3-a8b4-c9debbb7ba6a][field2]'],
#              'I Agree': ['cards[61edf07f-a0f9-41cd-8901-24d4cb79eb71][field0]'],
#              'Yes, by way of citizenship': ['cards[b937576d-7460-40d2-ae79-762f158be671][field0]'],
#              'Linkedin': ['cards[e3fd6642-8f4d-4a86-b7d8-f464a94ef3be][field7]'],
#              'op': ['cat'],
#              'list steps to start mongdb server backend': ['chat-input'],
#              '0453': ['compulsoryDuration', 'messageRateLimit'],
#              'Guruji$1234567': ['confirmPassword', 'newPassword'],
#              '800000inr': ['ctl00$pageContent$ctl02$ApplicationQuestions$desiredsalary'],
#              '365393': ['ctl00$pageContent$qset$ctl06$ch226353$226353'],
#              '365398': ['ctl00$pageContent$qset$ctl09$ch226356$226356'],
#              'no': ['ctl00$pageContent$qset$ctl10$ch226357$226357'],
#              'adv': ['cut-type'],
#              'BTECH': ['degree'],
#              'Untitled0.jsx': ['doc-name'],
#              '2025-02-14': ['edit-date'],
#              'food-nuts': ['edit-key'],
#              '5273': ['expense-amount'],
#              '53yuiyu': ['expense-description'],
#              'C:\\fakepath\\1722027181207.jpeg': ['fileData1', 'photos'],
#              "C:\\fakepath\\Practical Statistics for Data Scientists_ 50+ Essential -- Peter Bruce; Andrew Bruce; Peter Gedeck -- 2, 2020 -- O'Reilly Media -- 9781492072911 -- 7cc7f5be94b748e6ecbe5eff5ff3ee97 -- Anna’s Archive.epub": ['file[]'],
#              'FDGDFRGDFG': ['fullWidth'],
#              'C:\\fakepath\\ESLII_print10.pdf': ['html5_1ik3o5vd617m34701csr15cck024'],
#              'C:\\fakepath\\Anirudh_Cover_Letter_JPMG (2).pdf': ['html5_1ilvke9vb18af1e3178hefr1h4e4'],
#              '-135353': ['income-amount'],
#              'fggf': ['income-source'],
#              'https://wsdc.nitw.ac.in/home/': ['input-354', 's'],
#              'algeria': ['inputDefault'],
#              '7533': ['job_application[demographic_answers][][answer_options][][answer_option_id]'],
#              'Hyderabad, TG, India': ['location'],
#              '6dfc051c-af6f-47e3-a186-093085d081d6': ['locationId'],
#              '2078': ['mat-input-1', 'mat-input-4'],
#              '9030077232': ['mat-input-2', 'mat-input-3', 'memberNewMobileNo'],
#              'give me this code in chat': ['mat-input-6'],
#              '08/07/2000': ['memberDob'],
#              'Sairam Anirudh Kashibhatla': ['memberName'],
#              '248879': ['memberOtp'],
#              'import React, { useState, useEffect, useRef } from \'react\';\nimport Peer from \'peerjs\';\nimport \'./styles.css\'; // Assuming you\'ll create a styles.css file with the provided CSS\n\nfunction App() {\n  const [messages, setMessages] = useState();\n  const [filterInput, setFilterInput] = useState(\'\');\n  const [messageInput, setMessageInput] = useState(\'\');\n  const [idInput, setIdInput] = useState(\'\');\n  const [durationInput, setDurationInput] = useState(\'\');\n  const [mediaInput, setMediaInput] = useState(null);\n  const [joinRoomIdInput, setJoinRoomIdInput] = useState(\'\');\n  const [isCreateRoomModalOpen, setIsCreateRoomModalOpen] = useState(false);\n  const [roomId, setRoomId] = useState(\'\');\n  const [roomPassword, setRoomPassword] = useState(\'\');\n  const [roomDuration, setRoomDuration] = useState(60);\n  const [roomErrorMessage, setRoomErrorMessage] = useState(\'\');\n  const [activeTab, setActiveTab] = useState(\'basic\');\n  const [layoutOption, setLayoutOption] = useState(\'default\');\n  const [upvoteOption, setUpvoteOption] = useState(\'disabled\');\n  const [messageRateLimit, setMessageRateLimit] = useState(0);\n  const [compulsoryDuration, setCompulsoryDuration] = useState(0);\n  const [createdRooms, setCreatedRooms] = useState({});\n  const messageTimestamps = useRef();\n  const uploadedMedia = useRef(null);\n  const peer = useRef(null);\n  const conn = useRef(null);\n  const myId = useRef(null);\n  const connectedRoomId = useRef(null);\n\n  useEffect(() => {\n    initPeer();\n    // Load any existing rooms from local storage on component mount\n    const storedRooms = {};\n    for (let i = 0; i < localStorage.length; i++) {\n      const key = localStorage.key(i);\n      if (key) {\n        try {\n          storedRooms[key] = JSON.parse(localStorage.getItem(key));\n        } catch (e) {\n          console.error(\'Error parsing room data from local storage\', e);\n        }\n      }\n    }\n    setCreatedRooms(storedRooms);\n  },);\n\n  const generateId = () => {\n    return Math.random().toString(36).substring(2, 15) + Math.random().toString(36).substring(2, 15);\n  };\n\n  const handleMediaInputChange = (event) => {\n    const file = event.target.files[0];\n    const validImageTypes = [\'image/gif\', \'image/jpeg\', \'image/png\'];\n    const validVideoTypes = [\'video/mp4\', \'video/webm\'];\n\n    if (file) {\n      if (validImageTypes.includes(file.type)) {\n        uploadedMedia.current = {\n          type: \'image\',\n          url: URL.createObjectURL(file),\n        };\n      } else if (validVideoTypes.includes(file.type)) {\n        uploadedMedia.current = {\n          type: \'video\',\n          url: URL.createObjectURL(file),\n        };\n      } else {\n        alert(\'Invalid file type. Please upload an image or video.\');\n        setMediaInput(null);\n        uploadedMedia.current = null;\n      }\n      setMediaInput(file);\n    }\n  };\n\n  const postMessage = () => {\n    const messageTextValue = messageInput;\n    const messageIdValue = idInput.trim();\n    const durationValue = durationInput;\n    if (!messageTextValue && !uploadedMedia.current) return;\n\n    const newMessage = {\n      id: messageIdValue || generateId(),\n      text: messageTextValue,\n      duration: durationValue,\n      timestamp: new Date().toLocaleTimeString(),\n      left: `${Math.random() * (window.innerWidth - 320)}px`,\n      top: `${Math.random() * (window.innerHeight - 120)}px`,\n      media: uploadedMedia.current,\n    };\n\n    // Apply layout\n    if (createdRooms[connectedRoomId.current]?.layout === \'grid\') {\n      const gridX = Math.floor(Math.random() * 5) * 320;\n      const gridY = Math.floor(Math.random() * 3) * 200;\n      newMessage.left = `${gridX}px`;\n      newMessage.top = `${gridY}px`;\n    }\n\n    setMessages((prevMessages) => [...prevMessages, newMessage]);\n    setMessageInput(\'\');\n    setIdInput(\'\');\n    setDurationInput(\'\');\n    setMediaInput(null ...
#              'hgh': ['messageInput'],
#              'waranga': ['oj-combobox-2|input'],
#              '5': ['otc-4'],
#              '183104': ['otpEnt.otp'],
#              '032840': ['otpPinValue'],
#              '070936 15572': ['phoneNumber'],
#              'true': ['profileStatus', 'smsOptIn'],
#              'eda': ['pull_request[title]'],
#              'HOURLY': ['rateType'],
#              'gn': ['seat-pool'],
#              'g': ['select_title'],
#              'Telangana': ['state'],
#              'Request for referral': ['subject'],
#              'DATA MODE': ['suggestor'],
#              '[1,2,3,4,5,6]': ['text-color'],
#              'STATISTIC': ['token-input-primarySkills'],
#              'DATA ': ['token-input-secondarySkills'],
#              '2000': ['year'],
#              'https://www.youtube.com/watch?v=vA0-3hm5q2Y': ['youtube_url'],
#              '1043734': ['\xa0I agree'],
#              '22852622': ['\xa0Male'],
#              '1182096': ['\xa0No'],
#              '800000': ['What is your desired annual gross base salary in your local currency?']})

# %%
sorted_keys_by_value = dict(sorted(keys_by_value.items(), key=lambda item: len(item[1]), reverse=True))

for key, value in sorted_keys_by_value.items():
    print(f"{key}: {len(value)}")
# Out:
# 0: 51
# on: 49
# anirudhkashibhatla@gmail.com: 22
# 1: 21
# 2024: 20
# Hyderabad: 17
# 1020000: 16
# 0.5: 16
# : 15
# Yes: 15
# 7093615572: 15
# Anirudh: 12
# 2020: 12
# C:\fakepath\Anirudh_Kashibhatla_Resume__.pdf: 11
# No: 11
# Kashibhatla: 10
# https://www.linkedin.com/in/anirudhkashibhatla/: 9
# 2025: 9
# Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet: 8
# 10.2: 8
# 7: 8
# 38: 7
# Futures First: 7
# Anirudh Kashibhatla: 7
# C:\fakepath\Anirudh_Kashibhatla__Resume_.pdf: 7
# 3: 6
# 6: 6
# IN: 6
# 500013: 6
# 4: 5
# +917093615572: 5
# 07093615572: 5
# Metallurgical Engineering: 5
# 8: 5
# 2: 4
# 37: 4
# -: 4
# Guruji$1: 4
# C:\fakepath\Anirudh_Kashibhatla_Resume_.pdf: 4
# Market Analyst: 4
# +91: 4
# 10: 4
# 7.19: 3
# 234: 3
# Kashibhatla : 3
# Anirudh : 3
# Male: 3
# National Institute of Technology Warangal: 3
# anirudhbzgh: 3
# 102103896453: 3
# 9030077232: 3
# 9: 2
# India: 2
# yes: 2
# Engineering: 2
# Hyderabad : 2
# C:\fakepath\Anirudh_Kashibhatla_CV_.pdf: 2
# 10,20,000: 2
# 417894747994: 2
# com.taleo.systemcomponent.olf.entity.NetworkLocation__54300: 2
# 453: 2
# Mobile: 2
# data science: 2
# C:\fakepath\Anirudh_Kashibhatla_CV _.pdf: 2
# Bangalore: 2
# aditya.rama-kamalanath-polepeddi@michelin.com: 2
# NITW: 2
# 0453: 2
# Guruji$1234567: 2
# C:\fakepath\1722027181207.jpeg: 2
# https://wsdc.nitw.ac.in/home/: 2
# 2078: 2
# true: 2
# 57: 1
# q#Nf8Hz47KjsMPb: 1
# discuss particle physics and create a model that stimulates 3d particle interactions and dynamics in c++ using any  librarireas needed along with the math: 1
# com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__17976: 1
# com.taleo.systemcomponent.question.entity.RegulationPossibleAnswer__4205011901: 1
# com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19098: 1
# com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19325: 1
# com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__19337: 1
# com.taleo.functionalcomponent.prescreening.entity.question.PossibleAnswer__46057: 1
# DAFFODILS APTS,DD COLNY: 1
# Bachelor: 1
# 872554: 1
# 201132701002: 1
# meenakumarimanyam@gmail.com: 1
# xFRuDg: 1
# sample: 1
# At Futures First, I worked extensively with open-source data, conducting research to monitor market movements on the ICE, CME, and Euronext exchanges. My role involved analyzing supply-demand dynamics, geopolitical events, and weather-related factors that directly influence commodity pricing. I’ve designed and implemented over 100 trading strategies using statistical tools like correlation analysis and risk budgeting, ensuring both profitability and resilience in volatile markets. This ownership of real-time analytics has strengthened my ability to deliver actionable insights in fast-paced environments.
# Actively traded a range of ICE,CME,EURONEXT commodity futures, including SRW ,HRW,yEBM, Corn, canola,
# yECO, and soybean oil.
# • Monitored market dynamics using open-source data focusing on supply-demand trends, geopolitical developments,
# and weather-driven factors influencing agricultural prices.
# • Developed and implemented more than 100 hedging strategies, optimized diversification using covariance analysis,
# and applied risk budgeting to mitigate risk and preserve portfolio stability during market volatility.
# • Applied lead-lag relationships, intermarket strategies, and arbitrage opportunities using tools like correlation
# analysis and statistical tests to identify profitable trades: 1
# , B lane, DD Colony, Amberpet: 1
# sr922003@student.nitw.ac.in: 1
# 468925: 1
# ascending: 1
# C:\fakepath\Practical Statistics for Data Scientists_ 50+ Essential -- Peter Bruce; Andrew Bruce; Peter Gedeck -- 2, 2020 -- O'Reilly Media -- 9781492072911 -- 7cc7f5be94b748e6ecbe5eff5ff3ee97 -- Anna’s Archive.epub: 1
# FDGDFRGDFG: 1
# C:\fakepath\ESLII_print10.pdf: 1
# C:\fakepath\Anirudh_Cover_Letter_JPMG (2).pdf: 1
# -135353: 1
# fggf: 1
# algeria: 1
# 7533: 1
# Hyderabad, TG, India: 1
# 6dfc051c-af6f-47e3-a186-093085d081d6: 1
# give me this code in chat: 1
# 08/07/2000: 1
# Sairam Anirudh Kashibhatla: 1
# 248879: 1
# import React, { useState, useEffect, useRef } from 'react';
# import Peer from 'peerjs';
# import './styles.css'; // Assuming you'll create a styles.css file with the provided CSS
#
# function App() {
#   const [messages, setMessages] = useState();
#   const [filterInput, setFilterInput] = useState('');
#   const [messageInput, setMessageInput] = useState('');
#   const [idInput, setIdInput] = useState('');
#   const [durationInput, setDurationInput] = useState('');
#   const [mediaInput, setMediaInput] = useState(null);
#   const [joinRoomIdInput, setJoinRoomIdInput] = useState('');
#   const [isCreateRoomModalOpen, setIsCreateRoomModalOpen] = useState(false);
#   const [roomId, setRoomId] = useState('');
#   const [roomPassword, setRoomPassword] = useState('');
#   const [roomDuration, setRoomDuration] = useState(60);
#   const [roomErrorMessage, setRoomErrorMessage] = useState('');
#   const [activeTab, setActiveTab] = useState('basic');
#   const [layoutOption, setLayoutOption] = useState('default');
#   const [upvoteOption, setUpvoteOption] = useState('disabled');
#   const [messageRateLimit, setMessageRateLimit] = useState(0);
#   const [compulsoryDuration, setCompulsoryDuration] = useState(0);
#   const [createdRooms, setCreatedRooms] = useState({});
#   const messageTimestamps = useRef();
#   const uploadedMedia = useRef(null);
#   const peer = useRef(null);
#   const conn = useRef(null);
#   const myId = useRef(null);
#   const connectedRoomId = useRef(null);
#
#   useEffect(() => {
#     initPeer();
#     // Load any existing rooms from local storage on component mount
#     const storedRooms = {};
#     for (let i = 0; i < localStorage.length; i++) {
#       const key = localStorage.key(i);
#       if (key) {
#         try {
#           storedRooms[key] = JSON.parse(localStorage.getItem(key));
#         } catch (e) {
#           console.error('Error parsing room data from local storage', e);
#         }
#       }
#     }
#     setCreatedRooms(storedRooms);
#   },);
#
#   const generateId = () => {
#     return Math.random().toString(36).substring(2, 15) + Math.random().toString(36).substring(2, 15);
#   };
#
#   const handleMediaInputChange = (event) => {
#     const file = event.target.files[0];
#     const validImageTypes = ['image/gif', 'image/jpeg', 'image/png'];
#     const validVideoTypes = ['video/mp4', 'video/webm'];
#
#     if (file) {
#       if (validImageTypes.includes(file.type)) {
#         uploadedMedia.current = {
#           type: 'image',
#           url: URL.createObjectURL(file),
#         };
#       } else if (validVideoTypes.includes(file.type)) {
#         uploadedMedia.current = {
#           type: 'video',
#           url: URL.createObjectURL(file),
#         };
#       } else {
#         alert('Invalid file type. Please upload an image or video.');
#         setMediaInput(null);
#         uploadedMedia.current = null;
#       }
#       setMediaInput(file);
#     }
#   };
#
#   const postMessage = () => {
#     const messageTextValue = messageInput;
#     const messageIdValue = idInput.trim();
#     const durationValue = durationInput;
#     if (!messageTextValue && !uploadedMedia.current) return;
#
#     const newMessage = {
#       id: messageIdValue || generateId(),
#       text: messageTextValue,
#       duration: durationValue,
#       timestamp: new Date().toLocaleTimeString(),
#       left: `${Math.random() * (window.innerWidth - 320)}px`,
#       top: `${Math.random() * (window.innerHeight - 120)}px`,
#       media: uploadedMedia.current,
#     };
#
#     // Apply layout
#     if (createdRooms[connectedRoomId.current]?.layout === 'grid') {
#       const gridX = Math.floor(Math.random() * 5) * 320;
#       const gridY = Math.floor(Math.random() * 3) * 200;
#       newMessage.left = `${gridX}px`;
#       newMessage.top = `${gridY}px`;
#     }
#
#     setMessages((prevMessages) => [...prevMessages, newMessage]);
#     setMessageInput('');
#     setIdInput('');
#     setDurationInput('');
#     setMediaInput(null);
#     uploadedMedia.current = null;
#
#     // Rate limiting
#     const now = Date.now();
#     const currentTimestamps = messageTimestamps.current.filter(t => now - t < 1000);
#     const rateLimitValue = createdRooms[connectedRoomId.current]?.messageRateLimit || 0;
#     if (rateLimitValue > 0 && currentTimestamps.length >= rateLimitValue) {
#       alert(`Message rate limit of ${rateLimitValue} per second exceeded.`);
#       setMessages((prevMessages) => prevMessages.filter((msg) => msg !== newMessage));
#       return;
#     }
#     messageTimestamps.current.push(now);
#     setTimeout(() => {
#       messageTimestamps.current = messageTimestamps.current.filter(t => now - t < 1000);
#     }, 1000);
#
#     if (conn.current) {
#       conn.current.send({ type: 'message', data: newMessage });
#     }
#   };
#
#   const filterById = (id) => {
#     setMessages(prevMessages => prevMessages.map(msg => ({ ...msg, visible: msg.id === id })));
#   };
#
#   const filterMessagesHandler = () => {
#     if (!filterInput) {
#       alert("Please enter an ID to filter.");
#       return;
#     }
#     setMessages(prevMessages => prevMessages.map(msg => ({ ...msg, visible: msg.id === filterInput })));
#   };
#
#   const openCreateRoomModal = () => {
#     setIsCreateRoomModalOpen(true);
#     setRoomErrorMessage('');
#     setRoomId('');
#     setRoomPassword('');
#     setRoomDuration(60);
#     setLayoutOption('default');
#     setUpvoteOption('disabled');
#     setMessageRateLimit(0);
#     setCompulsoryDuration(0);
#     setActiveTab('basic');
#     if (!peer.current || peer.current.disconnected) {
#       initPeer();
#     }
#   };
#
#   const handleCreateRoom = () => {
#     if (!roomId) {
#       setRoomErrorMessage("Please enter a room ID.");
#       return;
#     }
#     if (isNaN(roomDuration) || roomDuration <= 0) {
#       setRoomErrorMessage("Please enter a valid duration in seconds.");
#       return;
#     }
#
#     if (createdRooms[roomId]) {
#       setRoomErrorMessage("Room ID already exists. Please choose a different ID.");
#       return;
#     }
#
#     const newRoom = {
#       password: roomPassword,
#       duration: roomDuration,
#       expiration: Date.now() + (roomDuration * 1000),
#       layout: layoutOption,
#       upvote: upvoteOption,
#       messageRateLimit: parseInt(messageRateLimit),
#       compulsoryDuration: parseInt(compulsoryDuration),
#       hostId: peer.current?.id,
#     };
#
#     setCreatedRooms((prevRooms) => ({ ...prevRooms, [roomId]: newRoom }));
#     localStorage.setItem(roomId, JSON.stringify(newRoom));
#     alert(`Room '${roomId}' created with password: ${roomPassword || "None"}. It will expire in ${roomDuration} seconds.`);
#     setIsCreateRoomModalOpen(false);
#     connectedRoomId.current = roomId;
#
#     setTimeout(() => {
#       const updatedRooms = { ...createdRooms };
#       delete updatedRooms[roomId];
#       setCreatedRooms(updatedRooms);
#       localStorage.removeItem(roomId);
#       console.log(`Room '${roomId}' has expired and its data has been deleted.`);
#     }, roomDuration * 1000);
#   };
#
#   const closeCreateRoomModal = () => {
#     setIsCreateRoomModalOpen(false);
#   };
#
#   const handleTabClick = (tabId) => {
#     setActiveTab(tabId);
#   };
#
#   const initPeer = () => {
#     try {
#       peer.current = new Peer();
#       peer.current.on('open', (id) => {
#         myId.current = id;
#         console.log('My Peer ID: ' + id);
#       });
#       peer.current.on('connection', (c) => {
#         conn.current = c;
#         console.log('Connected to: ' + c.peer);
#         c.on('data', (data) => {
#           if (data.type === 'roomData') {
#             const roomData = data.data;
#             setCreatedRooms((prevRooms) => ({ ...prevRooms, [connectedRoomId.current]: roomData }));
#             console.log("fetched room data", roomData);
#           } else if (data.type === 'message') {
#             const messageData = data.data;
#             setMessages((prevMessages) => [...prevMessages, messageData]);
#           }
#         });
#         c.on('disconnect', () => {
#           console.log('Disconnected from peer: ' + c.peer);
#           conn.current = null;
#           connectedRoomId.current = null;
#         });
#         c.on('error', (err) => {
#           console.error("Connection Error:", err);
#         });
#       });
#       peer.current.on('disconnected', () => {
#         console.log('Peer disconnected');
#       });
#       peer.current.on('close', () => {
#         console.log('Peer connection closed');
#       });
#       peer.current.on('error', (err) => {
#         console.log('Peer error:', err);
#       });
#     } catch (error) {
#       console.error("Failed to initialize PeerJS:", error);
#       alert("Failed to initialize peer connection. Please check your connection.");
#     }
#   };
#
#   const joinRoom = () => {
#     const roomIdToJoin = joinRoomIdInput.trim();
#     if (!roomIdToJoin) {
#       alert('Please enter a Room ID to join.');
#       return;
#     }
#
#     if (!peer.current || peer.current.disconnected) {
#       initPeer();
#     }
#
#     const roomData = localStorage.getItem(roomIdToJoin);
#     const parsedRoomData = roomData ? JSON.parse(roomData) : null;
#
#     if (parsedRoomData && peer.current?.id === parsedRoomData.hostId) {
#       connectedRoomId.current = roomIdToJoin;
#       setCreatedRooms((prevRooms) => ({ ...prevRooms, [roomIdToJoin]: parsedRoomData }));
#       alert("You are the host of this room");
#       return;
#     }
#
#     conn.current = peer.current?.connect(parsedRoomData?.hostId || roomIdToJoin);
#
#     if (conn.current) {
#       conn.current.on('open', () => {
#         console.log('Connected to peer: ' + conn.current.peer);
#         connectedRoomId.current = roomIdToJoin;
#         if (parsedRoomData) {
#           conn.current.send({ type: 'roomData', data: parsedRoomData });
#         } else {
#           alert("No room data found, you have joined an empty room");
#         }
#       });
#
#       conn.current.on('data', (data) => {
#         if (data.type === 'roomData') {
#           const roomData = data.data;
#           setCreatedRooms((prevRooms) => ({ ...prevRooms, [connectedRoomId.current]: roomData }));
#           console.log("fetched room data", roomData);
#         } else if (data.type === 'message') {
#           const messageData = data.data;
#           setMessages((prevMessages) => [...prevMessages, messageData]);
#         }
#       });
#
#       conn.current.on('disconnect', () => {
#         console.log('Disconnected from peer: ' + conn.current.peer);
#         conn.current = null;
#         connectedRoomId.current = null;
#       });
#
#       conn.current.on('error', (err) => {
#         console.error("Connection Error:", err);
#       });
#     }
#   };
#
#   const makeDraggable = (elementRef) => {
#     const element = elementRef.current;
#     const header = element?.firstChild;
#     if (!element || !header) return;
#
#     let offsetX, offsetY, isDragging = false;
#
#     const handleMouseDown = (e) => {
#       isDragging = true;
#       offsetX = e.clientX - element.getBoundingClientRect().left;
#       offsetY = e.clientY - element.getBoundingClientRect().top;
#       element.style.zIndex = '1000';
#     };
#
#     const handleMouseMove = (e) => {
#       if (!isDragging) return;
#       element.style.left = `${Math.max(0, Math.min(window.innerWidth - 300, e.clientX - offsetX))}px`;
#       element.style.top = `${Math.max(0, Math.min(window.innerHeight - 100, e.clientY - offsetY))}px`;
#     };
#
#     const handleMouseUp = () => {
#       isDragging = false;
#     };
#
#     header.addEventListener('mousedown', handleMouseDown);
#     document.addEventListener('mousemove', handleMouseMove);
#     document.addEventListener('mouseup', handleMouseUp);
#
#     return () => {
#       header.removeEventListener('mousedown', handleMouseDown);
#       document.removeEventListener('mousemove', handleMouseMove);
#       document.removeEventListener('mouseup', handleMouseUp);
#     };
#   };
#
#   return (
#     <div>
#       <div className="input-container">
#         <input
#           type="text"
#           id="filterInput"
#           placeholder="Filter by ID/IP/Room"
#           value={filterInput}
#           onChange={(e) => setFilterInput(e.target.value)}
#         />
#         <button onClick={filterMessagesHandler}>Filter</button>
#         <button onClick={openCreateRoomModal}>Create Room</button>
#         <input
#           type="text"
#           id="messageInput"
#           placeholder="Type a message..."
#           value={messageInput}
#           onChange={(e) => setMessageInput(e.target.value)}
#         />
#         <input
#           type="text"
#           id="idInput"
#           placeholder="Enter ID (optional)"
#           value={idInput}
#           onChange={(e) => setIdInput(e.target.value)}
#         />
#         <input
#           type="text"
#           id="durationInput"
#           placeholder="Message Duration (s)"
#           value={durationInput}
#           onChange={(e) => setDurationInput(e.target.value)}
#         />
#         <input
#           type="file"
#           id="mediaInput"
#           accept="image/*,video/*"
#           style={{ display: 'none' }}
#           onChange={handleMediaInputChange}
#           ref={(input) => input && setMediaInput(input)}
#         />
#         <label htmlFor="mediaInput" className="upload-btn">
#           <span>Upload Media</span>
#         </label>
#         <button onClick={postMessage}>Post</button>
#         <input
#           type="text"
#           id="joinRoomIdInput"
#           placeholder="Enter Room ID to Join"
#           value={joinRoomIdInput}
#           onChange={(e) => setJoinRoomIdInput(e.target.value)}
#         />
#         <button onClick={joinRoom}>Join Room</button>
#       </div>
#
#       {isCreateRoomModalOpen && (
#         <div id="createRoomModal" className="modal" onClick={(e) => { if (e.target === e.currentTarget) closeCreateRoomModal(); }}>
#           <div className="modal-content">
#             <div className="modal-header">Create Room</div>
#             <div className="modal-body">
#               <div className="tabs">
#                 <div
#                   className={`tab ${activeTab === 'basic' ? 'active' : ''}`}
#                   data-tab="basic"
#                   onClick={() => handleTabClick('basic')}
#                 >
#                   Basic
#                 </div>
#                 <div
#                   className={`tab ${activeTab === 'customize' ? 'active' : ''}`}
#                   data-tab="customize"
#                   onClick={() => handleTabClick('customize')}
#                 >
#                   Customize
#                 </div>
#               </div>
#               <div id="basic" className={`tab-content ${activeTab === 'basic' ? 'active' : ''}`}>
#                 <div className="form-group">
#                   <label htmlFor="roomId">Room ID:</label>
#                   <input type="text" id="roomId" value={roomId} onChange={(e) => setRoomId(e.target.value)} />
#                 </div>
#                 <div className="form-group">
#                   <label htmlFor="roomPassword">Password (optional):</label>
#                   <input
#                     type="password"
#                     id="roomPassword"
#                     value={roomPassword}
#                     onChange={(e) => setRoomPassword(e.target.value)}
#                   />
#                 </div>
#                 <div className="form-group">
#                   <label htmlFor="roomDuration">Duration (seconds):</label>
#                   <input
#                     type="number"
#                     id="roomDuration"
#                     value={roomDuration}
#                     onChange={(e) => setRoomDuration(parseInt(e.target.value))}
#                   />
#                 </div>
#               </div>
#               <div id="customize" className={`tab-content ${activeTab === 'customize' ? 'active' : ''}`}>
#                 <div className="form-group">
#                   <label>Layout:</label>
#                   <div className="select-group">
#                     <select id="layoutOption" value={layoutOption} onChange={(e) => setLayoutOption(e.target.value)}>
#                       <option value="default">Default</option>
#                       <option value="grid">Grid</option>
#                     </select>
#                   </div>
#                 </div>
#                 <div className="form-group">
#                   <label>Upvote:</label>
#                   <div className="select-group">
#                     <select id="upvoteOption" value={upvoteOption} onChange={(e) => setUpvoteOption(e.target.value)}>
#                       <option value="disabled">Disabled</option>
#                       <option value="single-click">Single Click</option>
#                       <option value="double-click">Double Click</option>
#                     </select>
#                   </div>
#                 </div>
#                 <div className="form-group">
#                   <label>Message Rate Limit (per second):</label>
#                   <input
#                     type="number"
#                     id="messageRateLimit"
#                     value={messageRateLimit}
#                     onChange={(e) => setMessageRateLimit(parseInt(e.target.value))}
#                   />
#                 </div>
#                 <div className="form-group">
#                   <label>Compulsory Message Duration:</label>
#                   <input
#                     type="number"
#                     id="compulsoryDurationInput"
#                     value={compulsoryDuration}
#                     onChange={(e) => setCompulsoryDuration(parseInt(e.target.value))}
#                   />
#                 </div>
#               </div>
#               <div id="roomErrorMessage" className="error-message">{roomErrorMessage}</div>
#             </div>
#             <div className="modal-footer">
#               <button id="createRoomButton" onClick={handleCreateRoom}>
#                 Create
#               </button>
#               <button id="cancelRoomButton" onClick={closeCreateRoomModal}>
#                 Cancel
#               </button>
#             </div>
#           </div>
#         </div>
#       )}
#
#       {messages.map((msg, index) => (
#         <div
#           key={index}
#           className="message"
#           style={{
#             left: msg.left,
#             top: msg.top,
#             display: msg.visible === undefined || msg.visible ? 'block' : 'none',
#           }}
#           ref={makeDraggable}
#           onDoubleClick={() => setMessages(prevMessages => prevMessages.filter((_, i) => i !== index))}
#         >
#           <div className="message-header">{msg.id ? `ID: ${msg.id}` : 'No ID'}</div>
#           <div
#             className="message-content"
#             onClick={() => {
#               if (createdRooms[connectedRoomId.current]?.upvote === 'single-click') {
#                 alert('Upvoted!');
#               }
#             }}
#             onDoubleClick={() => {
#               if (createdRooms[connectedRoomId.current]?.upvote === 'double-click') {
#                 alert('Upvoted!');
#               }
#             }}
#             dangerouslySetInnerHTML={{
#               __html: msg.text ? msg.text.replace(/#(\w+)/g, '<a href="#" onclick="/* TODO: Implement filter by tag */">#$1</a>') : '',
#             }}
#           >
#             {msg.media && msg.media.type === 'image' && (
#               <img src={msg.media.url} alt="Uploaded Image" className="preview-image" />
#             )}
#             {msg.media && msg.media.type === 'video' && (
#               <video src={msg.media.url} className="preview-video" controls />
#             )}
#           </div>
#           <div className="message-timestamp">{msg.timestamp}</div>
#           {msg.duration && (
#             <useEffect(() => {
#               const timer = setTimeout(() => {
#                 setMessages(prevMessages => prevMessages.filter((_, i) => i !== index));
#               }, parseInt(msg.duration) * 1000);
#               return () => clearTimeout(timer);
#             }, [index, msg.duration])}
#           )}
#           {createdRooms[connectedRoomId.current]?.compulsoryDuration > 0 && !msg.duration && (
#             <useEffect(() => {
#               const timer = setTimeout(() => {
#                 setMessages(prevMessages => prevMessages.filter((_, i) => i !== index));
#               }, createdRooms[connectedRoomId.current].compulsoryDuration * 1000);
#               return () => clearTimeout(timer);
#             }, [index, createdRooms, connectedRoomId])}
#           )}
#         </div>
#       ))}
#     </div>
#   );
# }
#
# export default App;: 1
# hgh: 1
# waranga: 1
# 5: 1
# 183104: 1
# 032840: 1
# 070936 15572: 1
# eda: 1
# HOURLY: 1
# gn: 1
# g: 1
# Telangana: 1
# Request for referral: 1
# DATA MODE: 1
# [1,2,3,4,5,6]: 1
# STATISTIC: 1
# DATA : 1
# 2000: 1
# https://www.youtube.com/watch?v=vA0-3hm5q2Y: 1
# 1043734: 1
# 22852622: 1
# 1182096: 1
# 800000: 1

# %%
print(keys_by_value[keys_list[21]])
# Out:
# ['*\n\xa0Legal First Name', 'First Name', 'First Name*', 'First Name37410', 'First Name: *', 'First name ', 'First name:', 'Given Name(s)\n*', 'Given Name*', 'Legal First Name *', 'Legal first name *', 'Pronouns']

# %%
print(len(keys_list))
keys_by_value['2024']
# Out:
# 243
# ['Year of Graduation',
#  'Year of Passing37441',
#  'education-28--lastYearAttended-dateSectionYear-input',
#  'education-47--lastYearAttended-dateSectionYear-input',
#  'education-66--lastYearAttended-dateSectionYear-input',
#  'education-73--lastYearAttended-dateSectionYear-input',
#  'education-93--lastYearAttended-dateSectionYear-input',
#  'input-104-dateSectionYear-input',
#  'input-21-dateSectionYear-input',
#  'input-23-dateSectionYear-input',
#  'input-24-dateSectionYear-input',
#  'input-28-dateSectionYear-input',
#  'input-35-dateSectionYear-input',
#  'input-45-dateSectionYear-input',
#  'input-46-dateSectionYear-input',
#  'workExperience-33--startDate-dateSectionYear-input',
#  'workExperience-38--startDate-dateSectionYear-input',
#  'workExperience-5--startDate-dateSectionYear-input',
#  'workExperience-57--startDate-dateSectionYear-input',
#  'input-80-dateSectionYear-input']

# %%
map = defaultdict(list)
# asd 0.3717099130153656 0.3717099130153656
# 0 0
# mean : 0.9154024124145508 0.0
# asd 0.9154024124145508 0.9154024124145508
# 0 0
# mean : 0.3383605182170868 0.0
# asd 0.3383605182170868 0.3383605182170868
# 0 0
# mean : 0.7593081659740872 0.17790038966184096
# asd 0.4375954940915108 1.2169939950108528
# 0 3
# mean : 0.7183181657602913 0.17151764033684846
# asd 0.2397836223244667 1.289382018148899
# 0 0
# mean : 0.13584241271018982 0.0
# asd 0.13584241271018982 0.13584241271018982
# 0 0
# mean : 0.6909728050231934 0.0
# asd 0.6909728050231934 0.6909728050231934
# 0 0
# mean : 0.26386189460754395 0.0
# asd 0.26386189460754395 0.26386189460754395
# 0 0
# mean : 0.22280672192573547 0.0
# asd 0.22280672192573547 0.22280672192573547
# 0 0
# mean : 0.8717116713523865 0.0
# asd 0.8717116713523865 0.8717116713523865
# 0 0
# mean : 0.29331108679374057 0.4360702195277928
# asd -0.7110222540795803 1.1449506916105747
# 0 0
# mean : 0.18154418468475342 0.0
# asd 0.18154418468475342 0.18154418468475342
# 0 0
# defaultdict(list,
#             {'9': [np.float64(0.23247310519218445), np.float64(0.0), 0, 0],
#              '3': [np.float64(0.3291667451461156),
#               np.float64(0.29275934383064783),
#               3,
#               0],
#              '6': [np.float64(0.24713859210411707),
#               np.float64(0.14554185060989167),
#               2,
#               1],
#              '4': [np.float64(0.1327511478215456),
#               np.float64(0.10987400019195676),
#               0,
#               0],
#              '': [np.float64(0.16985680215238105),
#               np.float64(0.12909660634373002),
#               2,
#               0],
#              'C:\\fakepath\\Anirudh_Kashibhatla_Resume__.pdf': [np.float64(0.30537797612222756),
#               np.float64(0.19714611702295595),
#               1,
#               0],
#              'Hyderabad': [np.float64(0.446357957813341),
#               np.float64(0.28761027361724284),
#               0,
#               0],
#              'India': [np.float64(0.5928062200546265), np.float64(0.0), 0, 0],
#              'anirudhkashibhatla@gmail.com': [np.float64(0.6897576829313716),
#               np.float64(0.1459283651178467),
#               0,
#               0],
#              'No': [np.float64(0.17593248896300792),
#               np.float64(0.153464668418833),
#               1,
#               0],
#              'Anirudh': [np.float64(0.6427653280623031),
#               np.float64(0.21101574906662615),
#               0,
#               0],
#              'Kashibhatla': [np.float64(0.71114571624332),
#               np.float64(0.14700809439840784),
#               0,
#               0],
#              '+917093615572': [np.float64(0.4782140076160431),
#               np.float64(0.15065831916241318),
#               0,
#               0],
#              'on': [np.float64(0.13931254063476334),
#               np.float64(0.15058950797176834),
#               63,
#               0],
#              '1': [np.float64(0.2112739596826335),
#               np.float64(0.2469914524783013),
#               26,
#               0],
#              '2': [np.float64(0.1110793628419439),
#               np.float64(0.13554339458772816),
#               1,
#               0],
#              'Flat 201, Daffodils Appt, B61, B lane, DD Colony, Amberpet': [np.float64(0.7693112428699221),
#               np.float64(0.16640107905115553),
#               0,
#               0],
#              'Yes': [np.float64(0.24084443116471882),
#               np.float64(0.2206684827881102),
#               5,
#               0],
#              '38': [np.float64(0.2484733769226642),
#               np.float64(0.11996459843203729),
#               0,
#               0],
#              'yes': [np.float64(0.36844027042388916), np.float64(0.0), 0, 0],
#              '37': [np.float64(0.25628876375655335),
#               np.float64(0.1585176332634282),
#               0,
#               0],
#              'Engineering': [np.float64(0.24874623119831085),
#               np.float64(0.0),
#               0,
#               0],
#              '0': [np.float64(0.3064062540295223),
#               np.float64(0.2609034887938224),
#               0,
#               0],
#              '7.19': [np.float64(0.5559752583503723),
#               np.float64(0.08986907818099679),
#               0,
#               0],
#              '10.2': [np.float64(0.7245697102376393),
#               np.float64(0.12197163211915554),
#               2,
#               2],
#              '-': [np.float64(0.22664974008997282),
#               np.float64(0.3437589123135088),
#               1,
#               0],
#              '07093615572': [np.float64(0.4962645277380943),
#               np.float64(0.2259812084335846),
#               0,
#               0],
#              '7093615572': [np.float64(0.5080144469936688),
#               np.float64(0.2175925885509006),
#               0,
#               2],
#              'Guruji$1': [np.float64(0.678578108549118),
#               np.float64(0.10749079347879581),
#               0,
#               0],
#              'C:\\fakepath\\Anirudh_Kashibhatla_Resume_.pdf': [np.float64(0.3963930308818817),
#               np.float64(0.21542546900472417),
#               0,
#               0],
#              'Hyderabad ': [np.float64(0.6347305178642273),
#               np.float64(0.0),
#               0,
#               0],
#              'Futures First': [np.float64(0.4855605860551198),
#               np.float64(0.1325540803513616),
#               0,
#               1],
#              'IN': [np.float64(0.4760094920794169),
#               np.float64(0.16695653753099413),
#               0,
#               0],
#              'C:\\fakepath\\Anirudh_Kashibhatla_CV_.pdf': [np.float64(0.3321341276168823),
#               np.float64(0.0),
#               0,
#               0],
#              '1020000': [np.float64(0.3831697813856105),
#               np.float64(0.26408248186385513),
#               0,
#               0],
#              '10,20,000': [np.float64(0.6030983924865723),
#               np.float64(0.0),
#               0,
#               0],
#              '234': [np.float64(0.2429327517747879),
#               np.float64(0.11812864053754582),
#               0,
#               0],
#              'Market Analyst': [np.float64(0.418232890466849),
#               np.float64(0.17688303067834765),
#               0,
#               0],
#              'Kashibhatla ': [np.float64(0.6539015968640646),
#               np.float64(0.0872389469551215),
#               0,
#               0],
#              'Metallurgical Engineering': [np.float64(0.43841869533061983),
#               np.float64(0.2675235234404145),
#               2,
#               0],
#              'Anirudh ': [np.float64(0.544177899758021),
#               np.float64(0.12937068526426493),
#               0,
#               0],
#              'Anirudh Kashibhatla': [np.float64(0.6019074420134226),
#               np.float64(0.15438887781840446),
#               2,
#               0],
#              'Male': [np.float64(0.3403259515762329),
#               np.float64(0.07473376058268259),
#               0,
#               0],
#              '0.5': [np.float64(0.428201227930064),
#               np.float64(0.24014320576972054),
#               0,
#               0],
#              '7': [np.float64(0.6653510204383305),
#               np.float64(0.2881638892143242),
#               0,
#               0],
#              'National Institute of Technology Warangal': [np.float64(0.4656237264474233),
#               np.float64(0.04671949952636098),
#               0,
#               0],
#              '+91': [np.float64(0.6348115702470144),
#               np.float64(0.09503063315936111),
#               0,
#               0],
#              '417894747994': [np.float64(0.17035073041915894),
#               np.float64(0.0),
#               0,
#               0],
#              'https://www.linkedin.com/in/anirudhkashibhatla/': [np.float64(0.5285243528584639),
#               np.float64(0.3145456814284006),
#               0,
#               0],
#              'com.taleo.systemcomponent.olf.entity.NetworkLocation__54300': [np.float64(0.28762394189834595),
#               np.float64(0.0),
#               0,
#               0],
#              'anirudhbzgh': [np.float64(0.5281941692034403),
#               np.float64(0.02534484916535282),
#               0,
#               0],
#              '453': [np.float64(0.286990225315094), np.float64(0.0), 0, 0],
#              'Mobile': [np.float64(1.0), np.float64(0.0), 0, 0],
#              '500013': [np.float64(0.8750312407811482),
#               np.float64(0.06920972306251955),
#               0,
#               0],
#              'C:\\fakepath\\Anirudh_Kashibhatla__Resume_.pdf': [np.float64(0.3717049615723746),
#               np.float64(0.21186570162374002),
#               0,
#               0],
#              'data science': [np.float64(0.6723054647445679),
#               np.float64(0.0),
#               0,
#               0],
#              '8': [np.float64(0.16732726544141768),
#               np.float64(0.10812374637211526),
#               1,
#               0],
#              '2020': [np.float64(0.7690961080970187),
#               np.float64(0.14166064658812993),
#               0,
#               0],
#              '102103896453': [np.float64(0.4683835506439209),
#               np.float64(0.3759095963299984),
#               0,
#               0],
#              'C:\\fakepath\\Anirudh_Kashibhatla_CV _.pdf': [np.float64(0.320626437664032),
#               np.float64(0.0),
#               0,
#               0],
#              '10': [np.float64(0.6405101964871088),
#               np.float64(0.2335008935336315),
#               0,
#               0],
#              'Bangalore': [np.float64(0.3717099130153656),
#               np.float64(0.0),
#               0,
#               0],
#              'aditya.rama-kamalanath-polepeddi@michelin.com': [np.float64(0.9154024124145508),
#               np.float64(0.0),
#               0,
#               0],
#              'NITW': [np.float64(0.3383605182170868), np.float64(0.0), 0, 0],
#              '2025': [np.float64(0.7593081659740872),
#               np.float64(0.17790038966184096),
#               0,
#               3],
#              '2024': [np.float64(0.7183181657602913),
#               np.float64(0.17151764033684846),
#               0,
#               0],
#              '0453': [np.float64(0.13584241271018982), np.float64(0.0), 0, 0],
#              'Guruji$1234567': [np.float64(0.6909728050231934),
#               np.float64(0.0),
#               0,
#               0],
#              'C:\\fakepath\\1722027181207.jpeg': [np.float64(0.26386189460754395),
#               np.float64(0.0),
#               0,
#               0],
#              'https://wsdc.nitw.ac.in/home/': [np.float64(0.22280672192573547),
#               np.float64(0.0),
#               0,
#               0],
#              '2078': [np.float64(0.8717116713523865), np.float64(0.0), 0, 0],
#              '9030077232': [np.float64(0.29331108679374057),
#               np.float64(0.4360702195277928),
#               0,
#               0],
#              'true': [np.float64(0.18154418468475342), np.float64(0.0), 0, 0]})

# %%
data_list = []
for key, value in map.items():
    data_list.append({'Key': key, 'Mean': value[0], 'Std': value[1], 'High_Confidence': value[2], 'Low_Confidence': value[3]})

dfmap = pd.DataFrame(data_list)
dfmap.set_index('Key', inplace=True)
dfmap.sort_values(by='Mean', ascending=False, inplace=True)
dfmap
# Out:
#                                                         Mean       Std  \
# Key
# Mobile                                              1.000000  0.000000
# aditya.rama-kamalanath-polepeddi@michelin.com       0.915402  0.000000
# 500013                                              0.875031  0.069210
# 2078                                                0.871712  0.000000
# Flat 201, Daffodils Appt, B61, B lane, DD Colon...  0.769311  0.166401
# ...                                                      ...       ...
# 8                                                   0.167327  0.108124
# on                                                  0.139313  0.150590
# 0453                                                0.135842  0.000000
# 4                                                   0.132751  0.109874
# 2                                                   0.111079  0.135543
#
#                                                     High_Confidence  \
# Key
# Mobile                                                            0
# aditya.rama-kamalanath-polepeddi@michelin.com                     0
# 500013                                                            0
# 2078                                                              0
# Flat 201, Daffodils Appt, B61, B lane, DD Colon...                0
# ...                                                             ...
# 8                                                                 1
# on                                                               63
# 0453                                                              0
# 4                                                                 0
# 2                                                                 1
#
#                                                     Low_Confidence
# Key
# Mobile                                                           0
# aditya.rama-kamalanath-polepeddi@michelin.com                    0
# 500013                                                           0
# 2078                                                             0
# Flat 201, Daffodils Appt, B61, B lane, DD Colon...               0
# ...                                                            ...
# 8                                                                0
# on                                                               0
# 0453                                                             0
# 4                                                                0
# 2                                                                0
#
# [73 rows x 4 columns]

# %%
for key,value in keys_by_value.items():
  print(similarity_list(value))
# Out:
# [0.23247310519218445]
# [0.2881011366844177, -0.0010506696999073029, 0.2790120840072632, 0.36680227518081665, 0.2891983389854431, 0.0366072915494442, 0.19734828174114227, 0.2441662847995758, 0.2309902012348175, 0.1221284419298172, 0.11697723716497421, 0.12078537046909332, 0.9059735536575317, 0.8677979707717896, 0.8726633787155151]
# [0.2450522929430008, 0.1249811202287674, 0.26541703939437866, 0.23221975564956665, 0.1920594722032547, 0.0023288503289222717, 0.13403157889842987, 0.19056203961372375, 0.21681120991706848, 0.27126455307006836, 0.13051185011863708, 0.5174843668937683, 0.6059602499008179, 0.3266943693161011, 0.25170013308525085]
# [0.2911004424095154, 0.11094601452350616, 0.16707897186279297, 0.31668251752853394, 0.1904752552509308, -0.009369846433401108, 0.10323939472436905, -0.044686950743198395, 0.06737165153026581, 0.13467402756214142]
# []
# [0.4709843397140503, 0.10921996831893921, 0.0391678661108017, 0.06322383135557175, 0.3539942502975464, 0.08178568631410599, 0.17261576652526855, 0.07635823637247086, 0.08222769945859909, 0.08727561682462692, 0.01124764233827591, 0.05986334756016731, 0.10500171035528183, 0.04474940523505211, -0.03952515497803688, 0.06655711680650711, 0.16168546676635742, 0.3548070192337036, 0.14201045036315918, 0.06690385937690735, 0.13552001118659973, 0.033795714378356934, 0.09715662151575089, 0.14346812665462494, 0.025536108762025833, -0.02211844176054001, 0.03998769819736481, 0.18376824259757996, 0.05010123550891876, -0.003070313483476639, -0.046555399894714355, 0.1506316065788269, 0.1916576772928238, 0.20329228043556213, 0.17711210250854492, 0.10436519235372543, 0.29498597979545593, 0.3425814211368561, 0.2298855185508728, 0.37566840648651123, 0.054532814770936966, 0.16606223583221436, 0.22541369497776031, 0.5263946056365967, 0.324710875749588, 0.2553441524505615, 0.2887934446334839, 0.16364099085330963, 0.159245103597641, 0.18776226043701172, 0.06088557839393616, 0.25411438941955566, 0.6372798681259155, 0.40779659152030945, 0.2999839782714844, 0.24786369502544403, 0.23560912907123566, 0.18099990487098694,

# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [0.13584241271018982]
# [0.6909728050231934]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [0.26386189460754395]
# []
# []
# []
# []
# []
# []
# [0.22280672192573547]
# []
# []
# []
# []
# [0.8717116713523865]
# [0.9099980592727661, -0.01207638531923294, -0.0179884135723114]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [0.18154418468475342]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
import pandas as pd

d = []
for key, value in keys_by_value.items():
    d.append({'Key': key, 'Value_List_Length': len(value)})

df = pd.DataFrame(d)
df.set_index('Key', inplace=True)

c = df.sort_values(by='Value_List_Length', ascending=False)
c.head(75)
# Out:
#                                          Value_List_Length
# Key
# 0                                                       51
# on                                                      49
# anirudhkashibhatla@gmail.com                            22
# 1                                                       21
# 2024                                                    20
# ...                                                    ...
# C:\fakepath\Anirudh_Kashibhatla_CV_.pdf                  2
# Engineering                                              2
# yes                                                      2
# sr922003@student.nitw.ac.in                              1
# sample                                                   1
#
# [75 rows x 1 columns]

# %%
x = keys_by_value[keys_list[21]]
evaluate(x)
# Out:
# mean : 0.6427653280623031 0.21101574906662615
# asd 0.19417303055524826 1.1226050779223442
# 0 0
# [np.float64(0.6427653280623031), np.float64(0.21101574906662615), 0, 0]

# %%
x = keys_by_value[keys_list[21]]
cos = []
for i in range(len(x)):
  for j in range(i+1,len(x)):
    embedding1 = embedding_store[key_to_index[x[i]]]
    embedding2 = embedding_store[key_to_index[x[j]]]
    similarity_score = util.pytorch_cos_sim(embedding1, embedding2).item()
    cos.append(similarity_score)
val = np.mean(cos)
print(val)
plt.hist(cos,bins = 20)
plt.xlabel("Cosine Similarity")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of Cosine Similarity")
plt.show()
# Out:
# 0.6427653280623031

# %%
x = keys_by_value['0']
cos = []
for i in range(len(x)):
  for j in range(i+1,len(x)):
    embedding1 = embedding_store[key_to_index[x[i]]]
    embedding2 = embedding_store[key_to_index[x[j]]]
    similarity_score = util.pytorch_cos_sim(embedding1, embedding2).item()
    cos.append(similarity_score)
val = np.mean(cos)
print(val)
plt.hist(cos,bins = 50)
plt.xlabel("Cosine Similarity")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of Cosine Similarity")
plt.show()
print(len(cos))
# Out:
# 0.3064062540295223
# 1275

# %%
x = keys_by_value['anirudhkashibhatla@gmail.com']
cos = []
for i in range(len(x)):
  for j in range(i+1,len(x)):
    embedding1 = embedding_store[key_to_index[x[i]]]
    embedding2 = embedding_store[key_to_index[x[j]]]
    similarity_score = util.pytorch_cos_sim(embedding1, embedding2).item()
    cos.append(similarity_score)
val = np.mean(cos)
print(val)
plt.hist(cos,bins = 40)
plt.xlabel("Cosine Similarity")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of Cosine Similarity")
plt.show()
print(len(cos))
# Out:
# 0.6897576829313716
# 231

# %%
def kde (values)
# Out:
#   File "<ipython-input-31-b6afee37b317>", line 1
#     def kde (values)
#                     ^
# SyntaxError: expected ':'
